# %% [markdown]
# # **ĐANG SUY NGHĨ XEM NÊN VIẾT CÁI GÌ ĐỂ GIỚI THIỆU**

# %% [markdown]
# # **Mount to Gdrive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # **Import requirement lib**

# %%
import os # used to handle files using system commands.
import pickle # used to store numpy features extracted
import numpy as np  # used to perform a wide variety of mathematical operations 
                    # on arrays
from tqdm.notebook import tqdm  # progress bar decorator for iterators. 
                                # Includes a default range iterator printing to 
                                # stderr.

from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input 
    # imported modules for feature extraction from the image data
from tensorflow.keras.preprocessing.image import load_img, img_to_array
    # used for loading the image and converting the image to a numpy array
from tensorflow.keras.preprocessing.text import Tokenizer
    # used for loading the text as convert them into a token
from tensorflow.keras.preprocessing.sequence import pad_sequences
    # used for equal distribution of words in sentences filling the remaining 
    # spaces with zeros
from tensorflow.keras.models import Model
    # stored model
from tensorflow.keras.utils import to_categorical, plot_model
    # used to visualize the architecture of the model through different images
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add
    # operation for advanced model option

# %% [markdown]
# # **Prepare Captions Data for Generator**

# %% [markdown]
# ## **Load caption with imgID**

# %%
with open('/content/gdrive/MyDrive/Đồ án/Machine learning/Image captioning/Caption with imgID/caption_with_imgID_flickr.pkl', 'rb') as f:
    mapping = pickle.load(f)

# %%
mapping
# Out:
# {'1000268201_693b08cb0e': ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#   'startseq girl going into wooden building endseq',
#   'startseq little girl climbing into wooden playhouse endseq',
#   'startseq little girl climbing the stairs to her playhouse endseq',
#   'startseq little girl in pink dress going into wooden cabin endseq'],
#  '1001773457_577c3a7d70': ['startseq black dog and spotted dog are fighting endseq',
#   'startseq black dog and tricolored dog playing with each other on the road endseq',
#   'startseq black dog and white dog with brown spots are staring at each other in the street endseq',
#   'startseq two dogs of different breeds looking at each other on the road endseq',
#   'startseq two dogs on pavement moving toward each other endseq'],
#  '1002674143_1b742ab4b8': ['startseq little girl covered in paint sits in front of painted rainbow with her hands in bowl endseq',
#   'startseq little girl is sitting in front of large painted rainbow endseq',
#   'startseq small girl in the grass plays with fingerpaints in front of white canvas with rainbow on it endseq',
#   'startseq there is girl with pigtails sitting in front of rainbow painting endseq',
#   'startseq young girl with pigtails painting outside in the grass endseq'],
#  '1003163366_44323f5815': ['startseq man lays on bench while his dog sits by him endseq',
#   'startseq man lays on the bench to which white dog is also tied endseq',
#   'startseq man sleeping on bench outside with white and black dog sitting next to him endseq',
#   'startseq shirtless man lies on park bench with his dog endseq',
#   'startseq man laying on bench holding leash of dog sitting on ground endseq'],
#  '1007129816_e794419615': ['startseq man in an orange hat starring at something endseq',
#   'startseq man wears an orange hat and glasses endseq',
#   'startseq man with gauges and glasses is wearing blitz hat endseq',
#   'startseq man with glasses is wearing beer can crocheted hat endseq',
#   'startseq the man with pierced ears is wearing glasses and an orange hat endseq'],
#  '1007320043_627395c3d8': ['startseq child playing on rope net endseq',
#   'startseq little girl climbing on red roping endseq',
#   'startseq little girl in pink climbs rope bridge at the park endseq',
#   'startseq small child grips onto the red ropes at the playground endseq',
#   'startseq the small child climbs on red ropes on playground endseq'],
#  '1009434119_febe49276a': ['startseq black and white dog is running in grassy garden surrounded by white fence endseq',
#   'startseq black and white dog is running through the grass endseq',
#   'startseq boston terrier is running in the grass endseq',
#   'startseq boston terrier is running on lush green grass in front of white fence endseq',
#   'startseq dog runs on the green grass near wooden fence endseq'],
#  '1012212859_01547e3f17': ['startseq dog shakes its head near the shore red ball next to it endseq',
#   'startseq white dog shakes on the edge of beach with an orange ball endseq',
#   'startseq dog with orange ball at feet stands on shore shaking off water endseq',
#   'startseq white dog playing with red ball on the shore near the water endseq',
#   'startseq white dog with brown ears standing near water with head turned to one side endseq'],
#  '1015118661_980735411b': ['startseq boy smiles in front of stony wall in city endseq',
#   'startseq little boy is standing on the street while man in overalls is working on stone wall endseq',
#   'startseq young boy runs aross the street endseq',
#   'startseq young child is walking on stone paved street with metal pole and man behind him endseq',
#   'startseq smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him endseq'],
#  '1015584366_dfcec3c85a': ['startseq black dog leaps over log endseq',
#   'startseq grey dog is leaping over fallen tree endseq',
#   'startseq large black dog leaps fallen log endseq',
#   'startseq mottled black and grey dog in blue collar jumping over fallen tree endseq',
#   'startseq the black dog jumped the tree stump endseq'],
#  '101654506_8eb26cfb60': ['startseq brown and white dog is running through the snow endseq',
#   'startseq dog is running in the snow endseq',
#   'startseq dog running through snow endseq',
#   'startseq white and brown dog is running through snow covered field endseq',
#   'startseq the white and brown dog is running over the surface of the snow endseq'],
#  '101669240_b2d3e7f17b': ['startseq man in hat is displaying pictures next to skier in blue hat endseq',
#   'startseq man skis past another man displaying paintings in the snow endseq',
#   'startseq person wearing skis looking at framed pictures set up in the snow endseq',
#   'startseq skier looks at framed pictures in the snow next to trees endseq',
#   'startseq man on skis looking at artwork for sale in the snow endseq'],
#  '1016887272_03199f49c4': ['startseq collage of one person climbing cliff endseq',
#   'startseq group of people are rock climbing on rock climbing wall endseq',
#   'startseq group of people climbing rock while one man belays endseq',
#   'startseq seven climbers are ascending rock face whilst another man stands holding the rope endseq',
#   'startseq several climbers in row are climbing the rock while the man in red watches and holds the line endseq'],
#  '1019077836_6fc9b15408': ['startseq brown dog chases the water from sprinkler on lawn endseq',
#   'startseq brown dog plays with the hose endseq',
#   'startseq brown dog running on lawn near garden hose endseq',
#   'startseq dog is playing with hose endseq',
#   'startseq large brown dog running away from the sprinkler in the grass endseq'],
#  '1019604187_d087bf9a5f': ['startseq dog prepares to catch thrown object in field with nearby cars endseq',
#   'startseq white dog is about to catch yellow ball in its mouth endseq',
#   'startseq white dog is about to catch yellow dog toy endseq',
#   'startseq white dog is ready to catch yellow ball flying through the air endseq',
#   'startseq white dog running after yellow ball endseq'],
#  '1020651753_06077ec457': ['startseq black and white dog jumping in the air to get toy endseq',
#   'startseq black and white dog jumps up towards yellow toy endseq',
#   'startseq dog leaps to catch ball in field endseq',
#   'startseq white dog is trying to catch ball in midair over grassy field endseq',
#   'startseq the white dog is playing in green field with yellow toy endseq'],
#  '1022454332_6af2c1449a': ['startseq child and woman are at waters edge in big city endseq',
#   'startseq large lake with lone duck swimming in it with several people around the edge of it endseq',
#   'startseq little boy at lake watching duck endseq',
#   'startseq young boy waves his hand at the duck in the water surrounded by green park endseq',
#   'startseq two people are at the edge of lake facing the water and the city skyline endseq'],
#  '1022454428_b6b660a67b': ['startseq couple and an infant being held by the male sitting next to pond with near by stroller endseq',
#   'startseq couple sit on the grass with baby and stroller endseq',
#   'startseq couple with their newborn baby sitting under tree facing lake endseq',
#   'startseq man and woman care for an infant along the side of body of water endseq',
#   'startseq couple with baby sit outdoors next to their stroller endseq'],
#  '1022975728_75515238d8': ['startseq black dog running in the surf endseq',
#   'startseq black lab with tags frolicks in the water endseq',
#   'startseq dog splashes in the water endseq',
#   'startseq the black dog runs through the water endseq',
#   'startseq this is black dog splashing in the water endseq'],
#  '102351840_323e3de834': ['startseq man drilling hole in the ice endseq',
#   'startseq man is drilling through the frozen ice of pond endseq',
#   'startseq person in the snow drilling hole in the ice endseq',
#   'startseq person standing on frozen lake endseq',
#   'startseq two men are ice fishing endseq'],
#  '1024138940_f1fefbdce1': ['startseq two different breeds of brown and white dogs play on the beach endseq',
#   'startseq two dogs are making turn on soft sand beach endseq',
#   'startseq two dogs playing in the sand at the beach endseq',
#   'startseq two dogs playing together on beach endseq',
#   'startseq two large tan dogs play along sandy beach endseq'],
#  '102455176_5f8ead62d5': ['startseq man uses ice picks and crampons to scale ice endseq',
#   'startseq an ice climber in blue jacket and black pants is scaling frozen ice wall endseq',
#   'startseq an ice climber scaling frozen waterfall endseq',
#   'startseq person in blue and red ice climbing with two picks endseq',
#   'startseq climber climbing an ice wall endseq'],
#  '1026685415_0431cbf574': ['startseq black dog carries green toy in his mouth as he walks through the grass endseq',
#   'startseq black dog carrying something through the grass endseq',
#   'startseq black dog has blue toy in its mouth endseq',
#   'startseq dog in grass with blue item in his mouth endseq',
#   'startseq wet black dog is carrying green toy through the grass endseq'],
#  '1028205764_7e8df9a2ea': ['startseq man and baby are in yellow kayak on water endseq',
#   'startseq man and little boy in blue life jackets are rowing yellow canoe endseq',
#   'startseq man and child kayak through gentle waters endseq',
#   'startseq man and young boy ride in yellow kayak endseq',
#   'startseq man and child in yellow kayak endseq'],
#  '1030985833_b0902ea560': ['startseq black dog and brown dog are jumping up to catch red toy endseq',
#   'startseq black dog and brown dog play with red toy on courtyard endseq',
#   'startseq brown and black lab are outside and the black lab is catching toy in its mouth endseq',
#   'startseq black dog snaps at red and black object as brown dog lunges endseq',
#   'startseq the chocolate lab jumps too late to get the toy as the black lab captures it in the driveway endseq'],
#  '103106960_e8a41d64f8': ['startseq boy with stick kneeling in front of goalie net endseq',
#   'startseq child in red jacket playing street hockey guarding goal endseq',
#   'startseq young kid playing the goalie in hockey rink endseq',
#   'startseq young male kneeling in front of hockey goal with hockey stick in his right hand endseq',
#   'startseq hockey goalie boy in red jacket crouches by goal with stick endseq'],
#  '103195344_5d2dc613a3': ['startseq man in black is sitting next to modern art structure in front of glass building endseq',
#   'startseq man sits and reads newspaper by sculpture outside of an office building endseq',
#   'startseq man sits near large statue endseq',
#   'startseq man sitting in front of metal sculpture in front of building endseq',
#   'startseq the man with the backpack is sitting in buildings courtyard in front of an art sculpture reading endseq'],
#  '103205630_682ca7285b': ['startseq tent is being set up on the ice endseq',
#   'startseq two men are about to enter an ice fishing tent on snow covered lake endseq',
#   'startseq two men setting up blue ice fishing hut on an iced over lake endseq',
#   'startseq two men standing on an ice looking into something covered with blue tarp endseq',
#   'startseq two people standing outside blue tent structure on snowy surface endseq'],
#  '1032122270_ea6f0beedb': ['startseq woman crouches near three dogs in field endseq',
#   'startseq three dogs are playing on grassy hill with blue sky endseq',
#   'startseq three dogs are standing in the grass and person is sitting next to them endseq',
#   'startseq three dogs on grassy hill endseq',
#   'startseq three dogs stand in grassy field while person kneels nearby endseq'],
#  '1032460886_4a598ed535': ['startseq man is standing in front of skyscraper endseq',
#   'startseq man stands in front of skyscraper endseq',
#   'startseq man stands in front of very tall building endseq',
#   'startseq behind the man in red shirt stands large skyscraper endseq',
#   'startseq there is skyscraper in the distance with man walking in front of the camera endseq'],
#  '1034276567_49bb87c51c': ['startseq boy bites hard into treat while he sits outside endseq',
#   'startseq child biting into baked good endseq',
#   'startseq small boy putting something in his mouth with both hands endseq',
#   'startseq the boy eats his food outside at the table endseq',
#   'startseq the boy is eating pizza over tin dish endseq'],
#  '104136873_5b5d41be75': ['startseq people sit on the mountainside and check out the view endseq',
#   'startseq three people are on hilltop overlooking green valley endseq',
#   'startseq three people hang out on top of big hill endseq',
#   'startseq three people overlook green valley endseq',
#   'startseq three people rest on ledge above the moutains endseq'],
#  '1042020065_fb3d3ba5ba': ['startseq boy in green shirt is looking down at many inflatable boats endseq',
#   'startseq boy in green shirt watches kayakers endseq',
#   'startseq boy looks over railing at the many boats and rafts below in the water endseq',
#   'startseq young boy overlooking crowd of inflatable boats endseq',
#   'startseq young boy wearing jersey looks down over ledge at many boats in the water endseq'],
#  '1042590306_95dea0916c': ['startseq man and woman pose for the camera while another man looks on endseq',
#   'startseq man is holding the hand of woman up to his mouth in front of some buildings while another man looks on endseq',
#   'startseq multiracial couple posing for picture endseq',
#   'startseq asian man and blond woman holding hands outdoors man in background watches endseq',
#   'startseq guy in blue shirt biting hand of girl in black striped jacket while another guy watches endseq'],
#  '1045521051_108ebc19be': ['startseq person eats takeout while watching small television endseq',
#   'startseq person sits on the floor and eats in front of television endseq',
#   'startseq television with picture of girl on it endseq',
#   'startseq young man sits on the floor by the television with fast food meal in front of him endseq',
#   'startseq someone is laying in front of the tv eating food endseq'],
#  '1048710776_bb5b0a5c7c': ['startseq couple of several people sitting on ledge overlooking the beach endseq',
#   'startseq group of people sit on wall at the beach endseq',
#   'startseq group of teens sit on wall by beach endseq',
#   'startseq crowd of people at the beach endseq',
#   'startseq several young people sitting on rail above crowded beach endseq'],
#  '1052358063_eae6744153': ['startseq boy takes jump on his skateboard while another boy with skateboard watches endseq',
#   'startseq child is performing skateboard trick while another child with skateboard leans on wall endseq',
#   'startseq little boy skateboarder is doing trick on his board while another young skateboarder watches endseq',
#   'startseq young boy skateboarder jumping on platform on skateboard endseq',
#   'startseq two skateboarders endseq'],
#  '105342180_4d4a40b47f': ['startseq girl paddling down large river as seen from behind her endseq',
#   'startseq woman kayaking down river endseq',
#   'startseq woman paddles boat down river endseq',
#   'startseq woman with paddle endseq',
#   'startseq woman with paddle sits in boat on the water endseq'],
#  '1053804096_ad278b25f1': ['startseq girl in pigtails splashes in the shallow water endseq',
#   'startseq girls plays in the surf endseq',
#   'startseq girl with pigtails is playing in the ocean by the beach endseq',
#   'startseq girl with pigtails plays in the water endseq',
#   'startseq young girl in pigtails plays in the water endseq'],
#  '1055623002_8195a43714': ['startseq group of four children wearing pajamas have pillow fight endseq',
#   'startseq group of kids have pillowfight endseq',
#   'startseq group of young children playing pillow fight on bed endseq',
#   'startseq children having pillow fight endseq',
#   'startseq four children are having pillow fight endseq'],
#  '1055753357_4fa3d8d693': ['startseq two constructions workers sit on beam taking break endseq',
#   'startseq two construction workers are sitting up on the side of building endseq',
#   'startseq two construction workers sitting on an ibeam endseq',
#   'startseq two construction workers take seat on steel beam endseq',
#   'startseq two men take break from construction endseq'],
#  '1056249424_ef2a2e041c': ['startseq the children are playing in the water endseq',
#   'startseq two boys one with yellow and orange ball play in some water in front of field endseq',
#   'startseq two boys play in puddle endseq',
#   'startseq two children play with balloon in mud on sunny day endseq',
#   'startseq two kids are running and playing in some water endseq'],
#  '1056338697_4f7d7ce270': ['startseq blond woman in blue shirt appears to wait for ride endseq',
#   'startseq blond woman is on the street hailing taxi endseq',
#   'startseq woman is signaling is to traffic as seen from behind endseq',
#   'startseq woman with blonde hair wearing blue tube top is waving on the side of the street endseq',
#   'startseq the woman in the blue dress is holding out her arm at oncoming traffic endseq'],
#  '1056359656_662cee0814': ['startseq little girl looking at brochure on train rides endseq',
#   'startseq young blond girl with magizine in her hands endseq',
#   'startseq young girl on train reads book about train rides endseq',
#   'startseq young girl sits on seat and looks at train pamphlet endseq',
#   'startseq child sitting down looking at train ride brochure endseq'],
#  '1056873310_49c665eb22': ['startseq brown dog is running after black dog on rocky shore endseq',
#   'startseq brown dog is running after the black dog endseq',
#   'startseq two dogs playing on beach endseq',
#   'startseq two dogs run across stones near body of water endseq',
#   'startseq two dogs run towards each other on rocky area with water in the background endseq'],
#  '1057089366_ca83da0877': ['startseq boy descends off the end of high diving board endseq',
#   'startseq child jumps off high diving board into the pool endseq',
#   'startseq kid jumps off the diving board and into the swimming pool below endseq',
#   'startseq little kid is jumping off high dive at the pool endseq',
#   'startseq the boy is jumping off high diving board into the pool endseq'],
#  '1057210460_09c6f4c6c1': ['startseq guy stands by window taking his overshirt off endseq',
#   'startseq man in tank top stands next to chrome door endseq',
#   'startseq man puts his shirt on near an elevator endseq',
#   'startseq man stands by an elevator with his head down endseq',
#   'startseq the man is putting on his shirt near an elevator endseq'],
#  '1057251835_6ded4ada9c': ['startseq lightcolored dog runs on the beach endseq',
#   'startseq small yellow dog runs on beach endseq',
#   'startseq tan dog runs on sandy beach endseq',
#   'startseq white dog is running down rocky beach endseq',
#   'startseq light brown dog running along the beach endseq'],
#  '106490881_5a2dd9b7bd': ['startseq boy in his blue swim shorts at the beach endseq',
#   'startseq boy smiles for the camera at beach endseq',
#   'startseq young boy in swimming trunks is walking with his arms outstretched on the beach endseq',
#   'startseq children playing on the beach endseq',
#   'startseq the boy is playing on the shore of an ocean endseq'],
#  '106514190_bae200f463': ['startseq hiker standing high on bluff overlooking the mountains below endseq',
#   'startseq person on ski looks from hill over snow covered landscape endseq',
#   'startseq skier is overlooking snowcovered mountain endseq',
#   'startseq skier is overlooking the beautiful white snow covered landscape endseq',
#   'startseq skier pauses on mountaintop endseq'],
#  '1067180831_a59dc64344': ['startseq black and white dog is attempting to catch yellow and purple object in low cut yard endseq',
#   'startseq black and white dog jumps after yellow toy endseq',
#   'startseq black and white dog jumps to get the frisbee endseq',
#   'startseq black dog is jumping up to catch purple and green toy endseq',
#   'startseq dog jumps to catch toy endseq'],
#  '1067675215_7336a694d6': ['startseq man in blue shorts is laying in the street endseq',
#   'startseq man in blue shorts lays down outside in parking lot endseq',
#   'startseq man laying down in middle of street during heavy traffic endseq',
#   'startseq man lies on mat in parking lot between brown suv and yellow pickup with an open door endseq',
#   'startseq shirtless man is laying down in the middle of busy street endseq'],
#  '1067790824_f3cc97239b': ['startseq white and black dog and brown dog in sandy terrain endseq',
#   'startseq woolly dog chases doberman on beach endseq',
#   'startseq one dog is chasing another one on the beach endseq',
#   'startseq the two large dogs are running through sand endseq',
#   'startseq two large dogs chasing each other at the beach endseq'],
#  '1072153132_53d2bb1b60': ['startseq black and white dog catches toy in midair endseq',
#   'startseq dog and tennis ball endseq',
#   'startseq dog is jumping to catch object thrown at it endseq',
#   'startseq dog leaps while chasing tennis ball through grassy field endseq',
#   'startseq multicolor dog jumping to catch tennis ball in grassy field endseq'],
#  '107318069_e9f2ef32de': ['startseq crowd watching air balloons at night endseq',
#   'startseq group of hot air balloons lit up at night endseq',
#   'startseq people are watching hot air balloons in the park endseq',
#   'startseq people watching hot air balloons endseq',
#   'startseq seven large balloons are lined up at nighttime near crowd endseq'],
#  '1075716537_62105738b4': ['startseq child with helmet on his head rides bike endseq',
#   'startseq little boy rides bike down hill on miniature dirt bike endseq',
#   'startseq young boy in helmet rides bike on the road endseq',
#   'startseq the little boy rides his bicycle in race endseq',
#   'startseq the young boy pedals quickly at bmx race endseq'],
#  '107582366_d86f2d3347': ['startseq group of eight people are gathered around table at night endseq',
#   'startseq group of people gathered around in the dark endseq',
#   'startseq group of people sit around table outside on porch at night endseq',
#   'startseq group of people sit outdoors together at night endseq',
#   'startseq group of people sitting at table in darkened room endseq'],
#  '1075867198_27ca2e7efe': ['startseq man in brown shirt and dark shorts plays on the beach with his two black dogs endseq',
#   'startseq man in shorts with two black dogs holds ball throwing toy at the beach endseq',
#   'startseq man playing with two black dogs on the beach endseq',
#   'startseq man with two dogs on beach endseq',
#   'startseq man at the beach with two dogs endseq'],
#  '1075881101_d55c46bece': ['startseq boy cleans the bubbles off his face endseq',
#   'startseq boy covered in suds has his face wiped clean endseq',
#   'startseq boy is covered in bubbles endseq',
#   'startseq child covered in foam is climbing on black inflatable ramp endseq',
#   'startseq person covered in soapy water is getting cleaned off endseq'],
#  '1077546505_a4f6c4daa9': ['startseq boy in blue shorts slides down slide into pool endseq',
#   'startseq boy in blue swimming trunks slides down yellow slide into wading pool with inflatable toys floating in the water endseq',
#   'startseq boy rides down slide into small backyard pool endseq',
#   'startseq boy sliding down slide into pool with colorful tubes endseq',
#   'startseq child is falling off slide onto colored balloons floating on pool of water endseq'],
#  '1077931201_1e0bb83105': ['startseq man in wetsuit is throwing baby wearing wetsuit up into the air endseq',
#   'startseq man in wetsuit is throwing toddler up in the air and is ready to catch him endseq',
#   'startseq man in water throwing little boy up in the air and waiting for him to come down so he can catch him endseq',
#   'startseq the man is in the pool and throwing small boy into the air endseq',
#   'startseq while water droplets fly man throws little boy up in the air endseq'],
#  '1079274291_9aaf896cc1': ['startseq little boy sticks his tongue out for the camera another boy looks on endseq',
#   'startseq two boys make faces endseq',
#   'startseq two young boys are looking at the camera one smiling the other sticking his tongue out endseq',
#   'startseq two young boys look up at the camera as one sticks out his tongue endseq',
#   'startseq two young boys making silly faces endseq'],
#  '10815824_2997e03d76': ['startseq blonde horse and blonde girl in black sweatshirt are staring at fire in barrel endseq',
#   'startseq girl and her horse stand by fire endseq',
#   'startseq girl holding horse lead behind fire endseq',
#   'startseq man and girl and two horses are near contained fire endseq',
#   'startseq two people and two horses watching fire endseq'],
#  '1082252566_8c79beef93': ['startseq bulldog sheep dog and boxer standing in yard endseq',
#   'startseq large brown dog is pushing small boston terrier with his face while anouther dog watches endseq',
#   'startseq large skinny dog stands near two smaller dogs int the dirt endseq',
#   'startseq there are three dogs starring at ball in the middle of them endseq',
#   'startseq three dogs of various sizes endseq'],
#  '1082379191_ec1e53f996': ['startseq lady and man with no shirt sit on dock endseq',
#   'startseq man and woman are sitting on dock together endseq',
#   'startseq man and woman sitting on dock endseq',
#   'startseq man and woman sitting on deck next to lake endseq',
#   'startseq shirtless man and woman sitting on dock endseq'],
#  '1084040636_97d9633581': ['startseq closeup of white dog that is laying its head on its paws endseq',
#   'startseq large white dog lying on the floor endseq',
#   'startseq white dog has its head on the ground endseq',
#   'startseq white dog is resting its head on tiled floor with its eyes open endseq',
#   'startseq white dog rests its head on the patio bricks endseq'],
#  '1084104085_3b06223afe': ['startseq woman in yellow shirt and green shorts is climbing an artificial red wall whilst wearing safety harness endseq',
#   'startseq woman in blue shorts and white shirt is indoor rock climbing endseq',
#   'startseq the girl is climbing rock wall endseq',
#   'startseq the girl is in harness climbing rocks endseq',
#   'startseq woman climbing an artificial rock wall endseq'],
#  '1087168168_70280d024a': ['startseq boy is jumping on an inflatable ring and girl is watching him endseq',
#   'startseq boy jumping on water jumphouse endseq',
#   'startseq teenage boy is jumping on an inflatable slide endseq',
#   'startseq young boy jumping and young girl seating in an inflatable pool endseq',
#   'startseq two young kids are playing in the water on an inflated toy endseq'],
#  '1087539207_9f77ab3aaf': ['startseq family playing on tractor on beautiful day endseq',
#   'startseq children ride tractor in field endseq',
#   'startseq several children playing on polaris vehicle outdoors endseq',
#   'startseq the children played on the four wheeler in the field endseq',
#   'startseq the four kids are riding on an atv in field endseq'],
#  '1088767354_2acee738cf': ['startseq woman in red costume to the left of man and woman standing together endseq',
#   'startseq woman wearing red costume looks at two other people standing on street endseq',
#   'startseq young woman in red sequined costume and feather stands on the sidewalk endseq',
#   'startseq the girl in the salmon colored bikini is standing next to two young people one is wearing black outfit and the other is drinking pop endseq',
#   'startseq two young people are approached by flamboyant young woman dressed in red bikini and red feathered headress endseq'],
#  '108898978_7713be88fc': ['startseq skiiers walking up the hill through forest endseq',
#   'startseq two men are skiing in the snow in wooded area endseq',
#   'startseq two people wearing yellow jackets crosscountry skiing endseq',
#   'startseq two skiers are making their way through woodland endseq',
#   'startseq two skiers are sliding down trail in the woods endseq'],
#  '108899015_bf36131a57': ['startseq lone skier is making their way up mountain endseq',
#   'startseq skiiers at the top of snow covered hill endseq',
#   'startseq two hikers climbing snowy hill endseq',
#   'startseq two people are on snowcovered mountain endseq',
#   'startseq two people climbing up snowy mountain endseq'],
#  '1089181217_ee1167f7af': ['startseq brown dog running down paved pathway endseq',
#   'startseq brown dog running next to grass endseq',
#   'startseq dog is running down road endseq',
#   'startseq light brown dog runs down path happily endseq',
#   'startseq energetic brown dog running endseq'],
#  '1089755335_0bfbfd30e6': ['startseq mother and children is fishing on boardwalk at night endseq',
#   'startseq woman and three children stand on deck with fishing pole endseq',
#   'startseq woman stands with children on boardwalk at night overlooking the sea endseq',
#   'startseq some people on pier at night with one girl fishing off it endseq',
#   'startseq woman with three children fishing over boardwalk in the evening endseq'],
#  '109202756_b97fcdc62c': ['startseq woman dressed in blue jacket and blue jeans rides brown horse near frozen lake and snowcovered mountain endseq',
#   'startseq woman in blue jacket rides brown pony near water endseq',
#   'startseq woman rides horse near frozen lake in the wintertime endseq',
#   'startseq young blond woman sitting atop brown draft horse in the snowy mountains endseq',
#   'startseq woman blue jacket sits on daft horse near frozen lake endseq'],
#  '109202801_c6381eef15': ['startseq two draft horses pull cart through the snow endseq',
#   'startseq two golden brown horses pull sleigh driven by woman in blue coat endseq',
#   'startseq two horses are pulling woman in cart endseq',
#   'startseq two horses pull carriage driven by woman over snow covered ground endseq',
#   'startseq two horses pulling sled steered by smiling blond woman endseq'],
#  '109260216_85b0be5378': ['startseq person climbing down sheer rock cliff using rope endseq',
#   'startseq person climbs tall flat mountain while holding onto safety rope endseq',
#   'startseq person is climbing rock while holding onto white rope endseq',
#   'startseq person rappels down steep incline endseq',
#   'startseq person wearing red vest climbs up steep rock endseq'],
#  '109260218_fca831f933': ['startseq people stand inside rock dome endseq',
#   'startseq shaft of light in cave shows three spelunkers endseq',
#   'startseq spelunkers pose inside rock cavern while bathed in sunlight from the surface endseq',
#   'startseq three people sit in cave endseq',
#   'startseq three rock climbers are posing on big rocks endseq'],
#  '1093716555_801aacef79': ['startseq group of backpackers lay on the dry ground endseq',
#   'startseq group of hikers are resting on the ground in front of some mountains endseq',
#   'startseq people camp with the mountains in the background endseq',
#   'startseq several hikers rest with their gear in front of mountain endseq',
#   'startseq the group of hikers is resting in front of mountain endseq'],
#  '1093737381_b313cd49ff': ['startseq woman in blue dress stands with chalk portrait of two children playing by stream endseq',
#   'startseq woman standing in front of chalk drawing endseq',
#   'startseq woman stands next to chalk drawing in front of barnlike structure endseq',
#   'startseq woman stands outside near an elaborate chalk illustration endseq',
#   'startseq woman wearing blue dress is drawing picture of boy and girl on the sidewalk with sidewalk chalk endseq'],
#  '1094462889_f9966dafa6': ['startseq brown dog plays in deep pile of snow endseq',
#   'startseq dog looking at the camera in snow endseq',
#   'startseq dog runs through the snow endseq',
#   'startseq tan dog stand in the snow and looks up endseq',
#   'startseq the brown dog is out in the snow endseq'],
#  '1095476286_87d4f8664e': ['startseq boy jumping in fountain endseq',
#   'startseq boy plays in the fountains endseq',
#   'startseq child plays in fountain endseq',
#   'startseq little boy playing in the water endseq',
#   'startseq young boy is jumping through water being sprayed up from the ground endseq'],
#  '1095580424_76f0aa8a3e': ['startseq corgi runs out of tunnel endseq',
#   'startseq dog runs out of tunnel on course endseq',
#   'startseq dog running out of tunnel on obstacle course endseq',
#   'startseq the dog is running out of the tunnel on dog obedience course endseq',
#   'startseq the small brown and white dog is running out of small tunnel endseq'],
#  '1095590286_c654f7e5a9': ['startseq blond dog and black and white dog run in dirt field endseq',
#   'startseq dog chases another dog endseq',
#   'startseq yellow dog and black and white dog are running in the dirt endseq',
#   'startseq two dogs are running in field endseq',
#   'startseq two dogs running around endseq'],
#  '1095980313_3c94799968': ['startseq little girl in blue swimsuit is walking along wooden fence next to sandy beach endseq',
#   'startseq little girl with arms outstretched is posing at the beach endseq',
#   'startseq young girl walks on railing in front of the beach endseq',
#   'startseq little girl in blue swimsuit standing on handrail near beach endseq',
#   'startseq the little girl in the blue bathing suit is posing at the beach endseq'],
#  '1096097967_ac305887b4': ['startseq black and white dog drinking water from water spray endseq',
#   'startseq black and white dog is being soaked with jet of water in blue paddling pool endseq',
#   'startseq dog sticking its face into the shower from garden hose endseq',
#   'startseq small white dog gets sprayed by water endseq',
#   'startseq white and black dog is jumping into pool endseq'],
#  '1096165011_cc5eb16aa6': ['startseq boy smiles underwater endseq',
#   'startseq redheaded boy swimming underwater endseq',
#   'startseq small boy swimming underwater endseq',
#   'startseq smiling boy swims underwater in pool endseq',
#   'startseq the boys smiles underwater at the pool endseq'],
#  '1096395242_fc69f0ae5a': ['startseq boy with toy gun endseq',
#   'startseq little boy in orange shorts playing with toy endseq',
#   'startseq young boy with his foot outstretched aims toy at the camera in front of fireplace endseq',
#   'startseq young child plays with his new lightup toy endseq',
#   'startseq boy with toy gun pointed at the camera endseq'],
#  '109671650_f7bbc297fa': ['startseq boy in yellow shorts is standing on top of cliff endseq',
#   'startseq boy wearing blue and yellow walking on cliff edge endseq',
#   'startseq little boy standing high in the air on rock endseq',
#   'startseq young child is standing alone on some jagged rocks endseq',
#   'startseq child stands near edge of cliff endseq'],
#  '109738763_90541ef30d': ['startseq person on snowmobile in mid jump endseq',
#   'startseq snowmobiler flies through the air endseq',
#   'startseq snowmobile rider flies through the air on his or her machine in front of tall pine trees endseq',
#   'startseq rider jumps snowmobile high in rural area endseq',
#   'startseq the man is up in the air endseq'],
#  '109738916_236dc456ac': ['startseq people are riding around on snowmobiles endseq',
#   'startseq people pose with helmets and goggles on while riding snowmobiles endseq',
#   'startseq several people are taking break while on snowmobiling ride endseq',
#   'startseq three people and two snowmobiles endseq',
#   'startseq two helmeted men sit on yellow snowmobiles while another man stands behind watching endseq'],
#  '109823394_83fcb735e1': ['startseq three people drive atvs endseq',
#   'startseq three people on atvs in brown field turn their heads to look at the camera endseq',
#   'startseq three people on atv outside endseq',
#   'startseq three people on four wheel atv in field endseq',
#   'startseq three people ride their four wheelers through the field endseq'],
#  '109823395_6fb423a90f': ['startseq four wheeler jumping in an empty field endseq',
#   'startseq man on four wheeler is flying through the air endseq',
#   'startseq person is riding an orange atv in large empty field endseq',
#   'startseq man jumping with all terrain vehicle endseq',
#   'startseq man on an atv catching air endseq'],
#  '109823397_e35154645f': ['startseq man jumps gin the air while riding an atv endseq',
#   'startseq man on fourwheeler jumps near small building endseq',
#   'startseq an atv is airborne over field in front of white structure endseq',
#   'startseq person dressed in tan jacket jumps quad over harvested cornfield in front of small out building endseq',
#   'startseq man on four wheeler in the air endseq'],
#  '1100214449_d10861e633': ['startseq boy in striped shirt is jumping in front of water fountain endseq',
#   'startseq boy is jumping off the side of running stone water fountain in front of building endseq',
#   'startseq happy boy is jumping in front od city fountain endseq',
#   'startseq little boy is jumping in front of fountain endseq',
#   'startseq little boy is playfully jumping off the side of fountain endseq'],
#  '1104133405_c04a00707f': ['startseq boy carrying soccer ball endseq',
#   'startseq boy walks with ball tucked under his arm endseq',
#   'startseq boy walks with soccer ball near fence endseq',
#   'startseq boy wearing white tshirt walks on the grass and carries soccer ball endseq',
#   'startseq small boy carries soccer ball on field endseq'],
#  '1105959054_9c3a738096': ['startseq child painting picture endseq',
#   'startseq an artist paints clouds onto canvas endseq',
#   'startseq young girl painting picture endseq',
#   'startseq young girl with braids is painting with water colors on white paper on the wall endseq',
#   'startseq the child paints on large paper with water colors endseq'],
#  '110595925_f3395c8bd6': ['startseq cyclist is riding bicycle on curved road up hill endseq',
#   'startseq man in aerodynamic gear riding bicycle down road around sharp curve endseq',
#   'startseq man on mountain bike is pedaling up hill endseq',
#   'startseq man bicycle up road while cows graze on hill nearby endseq',
#   'startseq the biker is riding around curve in the road endseq'],
#  '1107246521_d16a476380': ['startseq black dog jumping to catch rope toy endseq',
#   'startseq black dog playing fetch with ball of rope endseq',
#   'startseq black dog pounces to get rope toy endseq',
#   'startseq black dog running after his rope toy endseq',
#   'startseq large black dog is playing in grassy yard endseq'],
#  '1107471216_4336c9b328': ['startseq little girl is holding cine camera in front of her face endseq',
#   'startseq young girl is looking through an old fashioned video camera endseq',
#   'startseq young girl steadies her aim with camera endseq',
#   'startseq girl with rosy cheeks and lips holding black toy gun endseq',
#   'startseq there is kid with gun endseq'],
#  '1110208841_5bb6806afe': ['startseq black and white border collie catches frisbee in front of an audience endseq',
#   'startseq brown and white dog catches frisbee in it mouth in front of group of people endseq',
#   'startseq brown and white dug jumping up to catch frisbee while an audience watches endseq',
#   'startseq dog jumps to catch frisbee while many people watch endseq',
#   'startseq an agile dog catches frisbee while crowd of onlookers watches closely endseq'],
#  '1112212364_0c48235fc2': ['startseq baby is sitting on and playing with smooth rocks endseq',
#   'startseq baby is stacking rocks on the beach endseq',
#   'startseq small boy is playing with rocks endseq',
#   'startseq toddler sitting on pile of rocks holding rock at beach endseq',
#   'startseq toddler sits on pile of rocks endseq'],
#  '111497985_38e9f88856': ['startseq kid rock climbing against the backdrop of green valley endseq',
#   'startseq woman in striped shirt climbs up mountain endseq',
#   'startseq young man climbs rocky hill endseq',
#   'startseq the person has striped shirt on and is holding on to rope on mountain endseq',
#   'startseq the person in the striped shirt is mountain climbing endseq'],
#  '111537217_082a4ba060': ['startseq man climbing rock wall endseq',
#   'startseq man climbing the side of cliff endseq',
#   'startseq man is rock climbing endseq',
#   'startseq man with red shoes white shirt and grey pants climbing endseq',
#   'startseq the young man with the white tshirt and jeans is rappeling up the rock wall endseq'],
#  '111537222_07e56d5a30': ['startseq climber wearing blue helmet and headlamp is attached to rope on the rock face endseq',
#   'startseq man climbs rocky wall endseq',
#   'startseq rock climber climbs large rock endseq',
#   'startseq woman in purple snakeskin pants climbs rock endseq',
#   'startseq person with blue helmet and purple pants is rock climbing endseq'],
#  '1115565519_d976d4b1f1': ['startseq child playing with fountain at the beach endseq',
#   'startseq child plays with fountain endseq',
#   'startseq girl looks at fountain that sprays water endseq',
#   'startseq little girl playing in water on frog sculpture endseq',
#   'startseq the little girl is playing with toy in public fountain endseq'],
#  '1115679311_245eff2f4b': ['startseq black dog is jumping over log along beach endseq',
#   'startseq black dog runs along the beach and jumps over wood barrior endseq',
#   'startseq dog is running on the beach endseq',
#   'startseq dog jumping over small wall at beach near the water endseq',
#   'startseq an animal is running on the beach endseq'],
#  '111766423_4522d36e56': ['startseq black and white bird eating seeds out of someone hand endseq',
#   'startseq black and white bird standing on hand endseq',
#   'startseq small bird sits in person hand and eats seeds endseq',
#   'startseq black and white bird standing on hand of someone holding sunflower seeds endseq',
#   'startseq the small bird is clinging to finger of the hand holding the seeds endseq'],
#  '1117972841_2b9261f95f': ['startseq brown dog is running in the sand endseq',
#   'startseq brown dog playing in the sand endseq',
#   'startseq brown dog plays at the beach endseq',
#   'startseq dog is standing in the sand endseq',
#   'startseq dog running fast in the sand endseq'],
#  '1118557877_736f339752': ['startseq little boy stands in the surf endseq',
#   'startseq small child wades through the water while being guided by another person endseq',
#   'startseq young boy laughs while splashing in the ocean endseq',
#   'startseq young boy wearing colorful bathing suit splashing in the ocean endseq',
#   'startseq young child splashing in water endseq'],
#  '1119015538_e8e796281e': ['startseq little tan dog with large ears running through the grass endseq',
#   'startseq playful dog is running through the grass endseq',
#   'startseq small dogs ears stick up as it runs in the grass endseq',
#   'startseq the small dog is running across the lawn endseq',
#   'startseq this is small beige dog running through grassy field endseq'],
#  '1119418776_58e4b93eac': ['startseq black and white dog is running through the field endseq',
#   'startseq black brown and white dog running through field endseq',
#   'startseq brown black and white dog is running through large field with its mouth open endseq',
#   'startseq dog running in field endseq',
#   'startseq dog with its mouth open running through field torwards the camera endseq'],
#  '1119463452_69d4eecd08': ['startseq girl in pink swimsuit in pool endseq',
#   'startseq girl swimming in pool endseq',
#   'startseq little girl in pink bathing suit swimming in pool endseq',
#   'startseq little girl swimming in pool endseq',
#   'startseq smiling little girl swimming in outdoor pool endseq'],
#  '1121416483_c7902d0d49': ['startseq child is standing on her head endseq',
#   'startseq little girl standing on her head endseq',
#   'startseq small child doing handstand on bed endseq',
#   'startseq young girl does handstand on bed with blue sheets endseq',
#   'startseq the girl is upside down on bed endseq'],
#  '112178718_87270d9b4d': ['startseq guy stands in the sand with snowboard behind him endseq',
#   'startseq man holds surfboard on the beach endseq',
#   'startseq man holds his snowboard in the sand endseq',
#   'startseq man with his surfboard stands in the sand endseq',
#   'startseq man is standing on white sand and holding snowboard endseq'],
#  '112243673_fd68255217': ['startseq people on atvs and dirt bikes are traveling along worn path in field surrounded by trees endseq',
#   'startseq three people are riding around on atv and motorcycles endseq',
#   'startseq three people on motorbikes follow trail through dry grass endseq',
#   'startseq three people on two dirtbikes and one fourwheeler are riding through brown grass endseq',
#   'startseq three people ride offroad bikes through field surrounded by trees endseq'],
#  '1122944218_8eb3607403': ['startseq baby in white garment holds flag with crescent moon and star endseq',
#   'startseq baby is holding small black flag with moon and star on it endseq',
#   'startseq baby wearing white gown waves muslim flag endseq',
#   'startseq little toddler dressed in white is smiling while lady helps him wave flag endseq',
#   'startseq baby in white outfit holding black and white flag endseq'],
#  '1124448967_2221af8dc5': ['startseq half naked man is sleeping on his chair outdoors endseq',
#   'startseq an older man sits back and relaxes on patio outside an adobe building where many bicycles are propped endseq',
#   'startseq shirtless man in white cap relaxes in deck chair close to three parked bicycles endseq',
#   'startseq man relaxing in folding chair on the street endseq',
#   'startseq topless old man wearing slippers navy blue pants and white hat while reclining in chair outside endseq'],
#  '1129704496_4a61441f2c': ['startseq brown and white and black and white dog hauling in floating toy from the ocean endseq',
#   'startseq both dogs retrieve the play toy from the water endseq',
#   'startseq two dogs in the ocean playing with toy endseq',
#   'startseq two dogs run through the water with rope in their mouths endseq',
#   'startseq two dogs tug at chew toy in the surf endseq'],
#  '1130017585_1a219257ac': ['startseq there are three young people one dark haired holding bottled drink one with head tilted back and finger in her mouth and one with spiked hair endseq',
#   'startseq the young people party in the streets endseq',
#   'startseq three girls make faces as one takes drink while they stand in busy street endseq',
#   'startseq three women on the street drinking and posing endseq',
#   'startseq three young women pose for the camera at parade endseq'],
#  '1130369873_d80a1aa59c': ['startseq brown dog is running through neckdeep water carrying tennis ball endseq',
#   'startseq brown dog splashes in the water while carrying ball in its mouth endseq',
#   'startseq brown dog swims through water outdoors with tennis ball in its mouth endseq',
#   'startseq red dog holding ball splashes through vegetation filled water endseq',
#   'startseq brown dog with tennis ball in mouth in water and bushes endseq'],
#  '1130401779_8c30182e3e': ['startseq two brown dogs are creating large splashes as they run in river endseq',
#   'startseq two brown dogs in the water endseq',
#   'startseq two brown dogs running through water endseq',
#   'startseq two brown dogs runs through the water endseq',
#   'startseq two dogs splash through the water endseq'],
#  '1131155939_b4b457b05e': ['startseq black dog runs into the ocean next to pile of seaweed endseq',
#   'startseq black lav runs into the water on the beach with swimmers in the distance and sea kelp in the foreground endseq',
#   'startseq dog at the shore of an ocean with seaweed in foreground endseq',
#   'startseq dog is running in the waves at the beach endseq',
#   'startseq pile of seaweed sits on the sand behind it big black dog is running in the water endseq'],
#  '1131340021_83f46b150a': ['startseq young boy runs while wearing sandals endseq',
#   'startseq little boy in striped shirt and brown shorts is running endseq',
#   'startseq the little boy in short sleeved shirt and shorts is running outside endseq',
#   'startseq the little boy is wearing black pinstripe shirt and walking on deck endseq',
#   'startseq young boy running outside on the pavement endseq'],
#  '1131800850_89c7ffd477': ['startseq brown and white dog stands outside while it snows endseq',
#   'startseq dog is looking at something near the water endseq',
#   'startseq furry dog attempts to dry itself by shaking the water off its coat endseq',
#   'startseq white and brown dog shaking its self dry endseq',
#   'startseq the large brown and white dog shakes off water endseq'],
# ...
#   'startseq man smiles in his blue and green kayak endseq',
#   'startseq man wearing helmet in pyranha kayak floats down some river rapids endseq'],
#  '2087640654_1a84577a44': ['startseq blonde dog is digging deep hole in the ground and its tail is up in the air endseq',
#   'startseq dog half way in hole in the ground endseq',
#   'startseq dog is digging large hole in yard to find something endseq',
#   'startseq dog is digging in the ground and half of his body is under the ground endseq',
#   'startseq the rear end of an animal whose front end is underground endseq'],
#  '2088120475_d6318364f5': ['startseq person dressed up as snowman is walking through crowd of people endseq',
#   'startseq five cold people in the snowstorm one wearing snowman head endseq',
#   'startseq people pose for picture in the snow endseq',
#   'startseq three young people pose by snowman in red tie endseq',
#   'startseq two couples pose with snowman endseq'],
#  '2088460083_42ee8a595a': ['startseq broken down hummer gets towed on truck bed endseq',
#   'startseq damaged vehicle is carried by repair truck in nighttime scene endseq',
#   'startseq flat bed truck in parking lot with an army vehicle on its bed endseq',
#   'startseq an old beatup jeep being towed away endseq',
#   'startseq dirty suv sits on the bed of tow truck at night endseq'],
#  '2088532947_c628e44c4a': ['startseq the girl in the white shirt has bracelet on and has her arm around the girl in the peach shirt endseq',
#   'startseq the two girls laid on the grass together endseq',
#   'startseq two little girls are laying on the grass smiling endseq',
#   'startseq two young girls holding each other on the grassy ground endseq',
#   'startseq two young girls hug each other in the grass endseq'],
#  '2088910854_c6f8d4f5f9': ['startseq large man is wearing headband with mistletoe attached to it endseq',
#   'startseq man in sweatshirt and cap wears flower on his head endseq',
#   'startseq man wearing black knit cap with red and white striped headband with flower on top endseq',
#   'startseq an man with black ski cap and red and white headband looks into the distance endseq',
#   'startseq man wearing black hat with christmas theme endseq'],
#  '2089122314_40d5739aef': ['startseq dog running with newspaper in its mouth endseq',
#   'startseq dog runs down the street carrying newspaper endseq',
#   'startseq dog with newspaper in his mouth runs down paved path endseq',
#   'startseq fluffy tricolored dog is running down the road with paper in its mouth endseq',
#   'startseq an australian shepherd dog carrying newspaper in his mouth endseq'],
#  '2089350172_dc2cf9fcf6': ['startseq three black dogs are swimming through some murky brown water one with yellow object in its mouth endseq',
#   'startseq three black dogs swimming in dirty water endseq',
#   'startseq three dark dogs swimming and one of them has ball endseq',
#   'startseq three dogs are up to their necks in water endseq',
#   'startseq three dogs swim in the water endseq'],
#  '2089426086_7acc98a3a8': ['startseq girl in hooded jacket presents cake with candles endseq',
#   'startseq girl in hood jacket holds birthday cake with many candles endseq',
#   'startseq girl in winter coat with birthday cake endseq',
#   'startseq girl is holding birthday cake endseq',
#   'startseq young girl holding cake with candles dressed in heavy coat endseq'],
#  '2089442007_6fc798548c': ['startseq brown dog is walking in the water endseq',
#   'startseq brown dog takes cautious steps in the calm waters with sandy bottom endseq',
#   'startseq brown dog wades in the water endseq',
#   'startseq dog with red fur stands in body of water endseq',
#   'startseq large golden colored dog is walking through water endseq'],
#  '2089539651_9e518ec7de': ['startseq hiker with two hiking poles stands on hillside with view of the city below him endseq',
#   'startseq hiker with two sticks is standing on path that is high up on hill endseq',
#   'startseq hiking man stands on cliff overlooking city endseq',
#   'startseq man hikes on dirt path high above city endseq',
#   'startseq person holding poles is standing on rock ledge with bushes on each side overlooking mountains endseq'],
#  '2089542487_b4c1ee7025': ['startseq hiker is ready to take on rugged outdoor trail endseq',
#   'startseq lone hiker on dirt hiking trail with hat and sunglasses on with trees in the background endseq',
#   'startseq man in shorts is hiking in dry region endseq',
#   'startseq man stops for picture with the scenery during his hike endseq',
#   'startseq the man is posing for picture in the desert wearing green shirt and hat and holding metal detector endseq'],
#  '2089555297_95cf001fa7': ['startseq man in hat with long sleeves and long pants stands overlooking city endseq',
#   'startseq man stands on cliff overlooking city endseq',
#   'startseq man with backpack and hat is standing by high cliff where you can see for miles endseq',
#   'startseq hiker standing on top of rock overlooking town endseq',
#   'startseq the man wearing backpack and hat stands on ledge overlooking city endseq'],
#  '2090327868_9f99e2740d': ['startseq woman little boy and tiny baby are standing in front of cow statue endseq',
#   'startseq woman and two small children posing in front of large cow statue endseq',
#   'startseq woman gives baby to small child to hold as they stand in front of cow statue endseq',
#   'startseq woman stands with two children near decorated bull statue endseq',
#   'startseq the woman and children are standing next to statue of cow endseq'],
#  '2090339522_d30d2436f9': ['startseq man in green hat is someplace up high endseq',
#   'startseq man in green hat is taking self portrait endseq',
#   'startseq man in hat at scenic overlook endseq',
#   'startseq man wearing green canvas hat with distnat city in the background endseq',
#   'startseq man with green hate and sunglasses on high up peak endseq'],
#  '2090386465_b6ebb7df2c': ['startseq woman and man in winter gear stand endseq',
#   'startseq three adults wearing cold weather gear endseq',
#   'startseq two people are wearing heavy clothing endseq',
#   'startseq two people in winter clothing endseq',
#   'startseq two women bundled up on snowy day endseq'],
#  '2090387793_274ab4cf7d': ['startseq boy wearing black walks down the street with his hands in fists endseq',
#   'startseq teenage boy dressed in black stands on snowy street endseq',
#   'startseq teenage boy wearing all black tries to look tough with cheap jewelry on endseq',
#   'startseq young man wearing black hat and jacket is walking outside endseq',
#   'startseq punk rock teenager walks with mean look on his face endseq'],
#  '2090545563_a4e66ec76b': ['startseq the boy laying face down on skateboard is being pushed along the ground by another boy endseq',
#   'startseq two girls play on skateboard in courtyard endseq',
#   'startseq two people play on long skateboard endseq',
#   'startseq two small children in red shirts playing on skateboard endseq',
#   'startseq two young children on skateboard going across sidewalk endseq'],
#  '2090723611_318031cfa5': ['startseq dogs walking in the grassy field endseq',
#   'startseq large fluffy grey dog standing in grass in front of brown dog endseq',
#   'startseq one dog standing in some grass with his tongue hanging out and tan dog in the background endseq',
#   'startseq two dogs of different breeds are standing in pasture endseq',
#   'startseq two dogs stand in the grass endseq'],
#  '2090997177_76d482b158': ['startseq black dog bounds across the sand endseq',
#   'startseq dog walking across the desert endseq',
#   'startseq short black dog is walking over barren landscape endseq',
#   'startseq small black dog running across the sand endseq',
#   'startseq small black dog walks in the sand endseq'],
#  '2091171488_c8512fec76': ['startseq female wearing pink gloves and brown jacket is smiling in the snow endseq',
#   'startseq woman standing in the snow with people in the background endseq',
#   'startseq young woman in spring coat and purple gloves stands in falling snow endseq',
#   'startseq young woman looks happy in winter clothes while it snows endseq',
#   'startseq young asian woman with pink gloves stands in the snow endseq'],
#  '2092177624_13ab757e8b': ['startseq boy in african clothing runs across concrete wall endseq',
#   'startseq little boy with green shirt is running on rock ledge endseq',
#   'startseq an african boy in large green shirt is running barefoot along wall endseq',
#   'startseq young boy dressed in green running along smooth stone wall near wooded area endseq',
#   'startseq boy in green tunic on rock wall endseq'],
#  '2092419948_eea8001d0f': ['startseq long haired man walking away beside canal whist holding onto railing endseq',
#   'startseq man walks down path next to waterway endseq',
#   'startseq person walks by some bluegreen water while holding rail endseq',
#   'startseq person with long ponytail walks along waterway under tunnel endseq',
#   'startseq the man with long hair is walking along storm drain endseq'],
#  '2092870249_90e3f1855b': ['startseq man lies on street with his head and shoulders under parked car that is jacked up endseq',
#   'startseq man looks under car on wet street endseq',
#   'startseq man works on car endseq',
#   'startseq person lies half under car facedown endseq',
#   'startseq person underneath car with jack endseq'],
#  '2094323311_27d58b1513': ['startseq dog places his head on man face endseq',
#   'startseq dog snuggles with man in sunglasses endseq',
#   'startseq dog with blue collar is licking man who wearing large tinted sunglasses endseq',
#   'startseq large brown dog with blue collar is resting his chin on man face endseq',
#   'startseq an orange dog is licking man wearing red sunglasses endseq'],
#  '2094543127_46d2f1fedf': ['startseq girl holding crocodile mouth closed endseq',
#   'startseq girl is posed over statue of dangerous animal endseq',
#   'startseq girl sits on what appears to be crocodile endseq',
#   'startseq girl sitting on top of crocodile endseq',
#   'startseq girl with red hair is sitting on crocodile holding its jaw endseq'],
#  '2094810449_f8df9dcdf7': ['startseq boy stands in the ocean lifting up his shorts endseq',
#   'startseq child in blue shorts is standing ankle deep in the water endseq',
#   'startseq little boy in blue shorts glasses and coat stands in the surf endseq',
#   'startseq the kid is wearing blue jacket and standing in shallow beach water endseq',
#   'startseq the small child wades ankle deep in the water on the shoreline endseq'],
#  '2095007523_591f255708': ['startseq baby looks through his crib endseq',
#   'startseq baby surrounded by some toys looks out of playpen endseq',
#   'startseq baby in playpen with wide eyes endseq',
#   'startseq baby looking through playpen bars at camera endseq',
#   'startseq the infant is laying on its stomach in crib looking up at the camera endseq'],
#  '2095078658_c14ba89bc2': ['startseq dog runs through snow in front of the woods endseq',
#   'startseq large dog running in snow endseq',
#   'startseq the dog runs through the snow endseq',
#   'startseq the german shepherd dog is running through the snow endseq',
#   'startseq the german shepherd is running through the white snow endseq'],
#  '2095435987_1b7591d214': ['startseq dog lying on its back in the sand endseq',
#   'startseq white and brown dog rolls on its back in the sand endseq',
#   'startseq the dog rolls over to scratch its back in the sand endseq',
#   'startseq the white and brown dog is rolling in the sand endseq',
#   'startseq the white dog is on its back in the sand with paws in the air endseq'],
#  '2095444126_201ff9f222': ['startseq dog is shaking off water endseq',
#   'startseq dog shakes his head endseq',
#   'startseq dog shakes off water endseq',
#   'startseq dog shakes off water and gets contorted endseq',
#   'startseq the dog is shaking water off of his body endseq'],
#  '2095478050_736c4d2d28': ['startseq man and boy play music as little girls watch endseq',
#   'startseq man is playing guitar with child playing harmonica while three young girls watch endseq',
#   'startseq three children watch man onstage playing guitar endseq',
#   'startseq three little girls look on as boy plays the harmonica with an adult guiutarist sitting beside him endseq',
#   'startseq three little girls watch band endseq'],
#  '209605542_ca9cc52e7b': ['startseq climber wearing red headband is pulling himself up some grey rocks high above some green foliage endseq',
#   'startseq man in headband climbing rock endseq',
#   'startseq man with red headband climbing rock cliff looming over greenery endseq',
#   'startseq man climbing sheet rock face endseq',
#   'startseq man in red headband climbing rock endseq'],
#  '2096771662_984441d20d': ['startseq man looks through his binoculars while another man holds drink endseq',
#   'startseq man with thermos is standing next to man who is gazing through binoculars endseq',
#   'startseq two men are standing together while one looks through binoculars endseq',
#   'startseq two men look out as one is holding binoculars endseq',
#   'startseq two people standing next to each other with mountains in the distance endseq'],
#  '2097398349_ff178b3f1b': ['startseq hiker waves to the camera as he standing in front of snowcapped mountains endseq',
#   'startseq man stands on the snow near the mountains endseq',
#   'startseq person poses in the snow endseq',
#   'startseq person stands in the snow at the top of mountian arms raised endseq',
#   'startseq skier in the mountains endseq'],
#  '2097403787_77a154f5b9': ['startseq lone person standing on some rocks with large snowy mountains in the background endseq',
#   'startseq man is standing on the rocky ground in front of the mountain endseq',
#   'startseq man standing in front of an icy mountain endseq',
#   'startseq the person is standing by the water in front of the snow topped mountains endseq',
#   'startseq the traveller pauses in front of the mountain view endseq'],
#  '2097407245_c798e0dcaf': ['startseq man in winter jacket and knit cap stand with his arms up at his side in snow landscape endseq',
#   'startseq man is standing on dirt with his hands in the air with mountains and snow behind him endseq',
#   'startseq man raises his arms on rocky beach endseq',
#   'startseq one lone man with fist in the air with large rocky mountains in the background endseq',
#   'startseq man with outstretched arms standing on snowcovered rocks endseq'],
#  '2097420505_439f63c863': ['startseq male hiker wearing green jacket is posing next to large glacier endseq',
#   'startseq man with camera and an ice structure behind him endseq',
#   'startseq man with camera crouching on ice endseq',
#   'startseq man with camera kneels in front of giant hill of snow endseq',
#   'startseq the mountain climber prepares to take photo endseq'],
#  '2097489021_ca1b9f5c3b': ['startseq girl in ballet fairy costume is touched by wand endseq',
#   'startseq young girl performing the nutcracker endseq',
#   'startseq the little girl is standing on stage dressed up as pink fairy endseq',
#   'startseq the tiny girl dressed in butterfly ballet costume waves her wand near nutcracker statue endseq',
#   'startseq young girl waving turquiose leotard and pink tutu with wings waving wand endseq'],
#  '2098174172_e57d86ea03': ['startseq hiker is posing in front of snowy mountains endseq',
#   'startseq hiker is standing in before the mountain holding two walking sticks endseq',
#   'startseq man stands in front of snow covered mountains endseq',
#   'startseq man with two ski poles stands near mountaintop endseq',
#   'startseq the man wears green hat and jacket while standing in front of mountain endseq'],
#  '2098418613_85a0c9afea': ['startseq brown chow mix dog is standing in front of van with euro plats in the middle of messy yard endseq',
#   'startseq brown dog standing in muddy yard endseq',
#   'startseq brown dogs walks near green van and some junk endseq',
#   'startseq large brown dog stands in front of green van in the yard of house endseq',
#   'startseq yellow dog is standing in front of green car and next to toilet endseq'],
#  ...}

# %% [markdown]
# ## **Stored mapping as list**

# %%
all_captions = []
for key in mapping:
    for caption in mapping[key]:
        all_captions.append(caption)

# %%
all_captions
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq',
#  'startseq black dog and spotted dog are fighting endseq',
#  'startseq black dog and tricolored dog playing with each other on the road endseq',
#  'startseq black dog and white dog with brown spots are staring at each other in the street endseq',
#  'startseq two dogs of different breeds looking at each other on the road endseq',
#  'startseq two dogs on pavement moving toward each other endseq',
#  'startseq little girl covered in paint sits in front of painted rainbow with her hands in bowl endseq',
#  'startseq little girl is sitting in front of large painted rainbow endseq',
#  'startseq small girl in the grass plays with fingerpaints in front of white canvas with rainbow on it endseq',
#  'startseq there is girl with pigtails sitting in front of rainbow painting endseq',
#  'startseq young girl with pigtails painting outside in the grass endseq',
#  'startseq man lays on bench while his dog sits by him endseq',
#  'startseq man lays on the bench to which white dog is also tied endseq',
#  'startseq man sleeping on bench outside with white and black dog sitting next to him endseq',
#  'startseq shirtless man lies on park bench with his dog endseq',
#  'startseq man laying on bench holding leash of dog sitting on ground endseq',
#  'startseq man in an orange hat starring at something endseq',
#  'startseq man wears an orange hat and glasses endseq',
#  'startseq man with gauges and glasses is wearing blitz hat endseq',
#  'startseq man with glasses is wearing beer can crocheted hat endseq',
#  'startseq the man with pierced ears is wearing glasses and an orange hat endseq',
#  'startseq child playing on rope net endseq',
#  'startseq little girl climbing on red roping endseq',
#  'startseq little girl in pink climbs rope bridge at the park endseq',
#  'startseq small child grips onto the red ropes at the playground endseq',
#  'startseq the small child climbs on red ropes on playground endseq',
#  'startseq black and white dog is running in grassy garden surrounded by white fence endseq',
#  'startseq black and white dog is running through the grass endseq',
#  'startseq boston terrier is running in the grass endseq',
#  'startseq boston terrier is running on lush green grass in front of white fence endseq',
#  'startseq dog runs on the green grass near wooden fence endseq',
#  'startseq dog shakes its head near the shore red ball next to it endseq',
#  'startseq white dog shakes on the edge of beach with an orange ball endseq',
#  'startseq dog with orange ball at feet stands on shore shaking off water endseq',
#  'startseq white dog playing with red ball on the shore near the water endseq',
#  'startseq white dog with brown ears standing near water with head turned to one side endseq',
#  'startseq boy smiles in front of stony wall in city endseq',
#  'startseq little boy is standing on the street while man in overalls is working on stone wall endseq',
#  'startseq young boy runs aross the street endseq',
#  'startseq young child is walking on stone paved street with metal pole and man behind him endseq',
#  'startseq smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him endseq',
#  'startseq black dog leaps over log endseq',
#  'startseq grey dog is leaping over fallen tree endseq',
#  'startseq large black dog leaps fallen log endseq',
#  'startseq mottled black and grey dog in blue collar jumping over fallen tree endseq',
#  'startseq the black dog jumped the tree stump endseq',
#  'startseq brown and white dog is running through the snow endseq',
#  'startseq dog is running in the snow endseq',
#  'startseq dog running through snow endseq',
#  'startseq white and brown dog is running through snow covered field endseq',
#  'startseq the white and brown dog is running over the surface of the snow endseq',
#  'startseq man in hat is displaying pictures next to skier in blue hat endseq',
#  'startseq man skis past another man displaying paintings in the snow endseq',
#  'startseq person wearing skis looking at framed pictures set up in the snow endseq',
#  'startseq skier looks at framed pictures in the snow next to trees endseq',
#  'startseq man on skis looking at artwork for sale in the snow endseq',
#  'startseq collage of one person climbing cliff endseq',
#  'startseq group of people are rock climbing on rock climbing wall endseq',
#  'startseq group of people climbing rock while one man belays endseq',
#  'startseq seven climbers are ascending rock face whilst another man stands holding the rope endseq',
#  'startseq several climbers in row are climbing the rock while the man in red watches and holds the line endseq',
#  'startseq brown dog chases the water from sprinkler on lawn endseq',
#  'startseq brown dog plays with the hose endseq',
#  'startseq brown dog running on lawn near garden hose endseq',
#  'startseq dog is playing with hose endseq',
#  'startseq large brown dog running away from the sprinkler in the grass endseq',
#  'startseq dog prepares to catch thrown object in field with nearby cars endseq',
#  'startseq white dog is about to catch yellow ball in its mouth endseq',
#  'startseq white dog is about to catch yellow dog toy endseq',
#  'startseq white dog is ready to catch yellow ball flying through the air endseq',
#  'startseq white dog running after yellow ball endseq',
#  'startseq black and white dog jumping in the air to get toy endseq',
#  'startseq black and white dog jumps up towards yellow toy endseq',
#  'startseq dog leaps to catch ball in field endseq',
#  'startseq white dog is trying to catch ball in midair over grassy field endseq',
#  'startseq the white dog is playing in green field with yellow toy endseq',
#  'startseq child and woman are at waters edge in big city endseq',
#  'startseq large lake with lone duck swimming in it with several people around the edge of it endseq',
#  'startseq little boy at lake watching duck endseq',
#  'startseq young boy waves his hand at the duck in the water surrounded by green park endseq',
#  'startseq two people are at the edge of lake facing the water and the city skyline endseq',
#  'startseq couple and an infant being held by the male sitting next to pond with near by stroller endseq',
#  'startseq couple sit on the grass with baby and stroller endseq',
#  'startseq couple with their newborn baby sitting under tree facing lake endseq',
#  'startseq man and woman care for an infant along the side of body of water endseq',
#  'startseq couple with baby sit outdoors next to their stroller endseq',
#  'startseq black dog running in the surf endseq',
#  'startseq black lab with tags frolicks in the water endseq',
#  'startseq dog splashes in the water endseq',
#  'startseq the black dog runs through the water endseq',
#  'startseq this is black dog splashing in the water endseq',
#  'startseq man drilling hole in the ice endseq',
#  'startseq man is drilling through the frozen ice of pond endseq',
#  'startseq person in the snow drilling hole in the ice endseq',
#  'startseq person standing on frozen lake endseq',
#  'startseq two men are ice fishing endseq',
#  'startseq two different breeds of brown and white dogs play on the beach endseq',
#  'startseq two dogs are making turn on soft sand beach endseq',
#  'startseq two dogs playing in the sand at the beach endseq',
#  'startseq two dogs playing together on beach endseq',
#  'startseq two large tan dogs play along sandy beach endseq',
#  'startseq man uses ice picks and crampons to scale ice endseq',
#  'startseq an ice climber in blue jacket and black pants is scaling frozen ice wall endseq',
#  'startseq an ice climber scaling frozen waterfall endseq',
#  'startseq person in blue and red ice climbing with two picks endseq',
#  'startseq climber climbing an ice wall endseq',
#  'startseq black dog carries green toy in his mouth as he walks through the grass endseq',
#  'startseq black dog carrying something through the grass endseq',
#  'startseq black dog has blue toy in its mouth endseq',
#  'startseq dog in grass with blue item in his mouth endseq',
#  'startseq wet black dog is carrying green toy through the grass endseq',
#  'startseq man and baby are in yellow kayak on water endseq',
#  'startseq man and little boy in blue life jackets are rowing yellow canoe endseq',
#  'startseq man and child kayak through gentle waters endseq',
#  'startseq man and young boy ride in yellow kayak endseq',
#  'startseq man and child in yellow kayak endseq',
#  'startseq black dog and brown dog are jumping up to catch red toy endseq',
#  'startseq black dog and brown dog play with red toy on courtyard endseq',
#  'startseq brown and black lab are outside and the black lab is catching toy in its mouth endseq',
#  'startseq black dog snaps at red and black object as brown dog lunges endseq',
#  'startseq the chocolate lab jumps too late to get the toy as the black lab captures it in the driveway endseq',
#  'startseq boy with stick kneeling in front of goalie net endseq',
#  'startseq child in red jacket playing street hockey guarding goal endseq',
#  'startseq young kid playing the goalie in hockey rink endseq',
#  'startseq young male kneeling in front of hockey goal with hockey stick in his right hand endseq',
#  'startseq hockey goalie boy in red jacket crouches by goal with stick endseq',
#  'startseq man in black is sitting next to modern art structure in front of glass building endseq',
#  'startseq man sits and reads newspaper by sculpture outside of an office building endseq',
#  'startseq man sits near large statue endseq',
#  'startseq man sitting in front of metal sculpture in front of building endseq',
#  'startseq the man with the backpack is sitting in buildings courtyard in front of an art sculpture reading endseq',
#  'startseq tent is being set up on the ice endseq',
#  'startseq two men are about to enter an ice fishing tent on snow covered lake endseq',
#  'startseq two men setting up blue ice fishing hut on an iced over lake endseq',
#  'startseq two men standing on an ice looking into something covered with blue tarp endseq',
#  'startseq two people standing outside blue tent structure on snowy surface endseq',
#  'startseq woman crouches near three dogs in field endseq',
#  'startseq three dogs are playing on grassy hill with blue sky endseq',
#  'startseq three dogs are standing in the grass and person is sitting next to them endseq',
#  'startseq three dogs on grassy hill endseq',
#  'startseq three dogs stand in grassy field while person kneels nearby endseq',
#  'startseq man is standing in front of skyscraper endseq',
#  'startseq man stands in front of skyscraper endseq',
#  'startseq man stands in front of very tall building endseq',
#  'startseq behind the man in red shirt stands large skyscraper endseq',
#  'startseq there is skyscraper in the distance with man walking in front of the camera endseq',
#  'startseq boy bites hard into treat while he sits outside endseq',
#  'startseq child biting into baked good endseq',
#  'startseq small boy putting something in his mouth with both hands endseq',
#  'startseq the boy eats his food outside at the table endseq',
#  'startseq the boy is eating pizza over tin dish endseq',
#  'startseq people sit on the mountainside and check out the view endseq',
#  'startseq three people are on hilltop overlooking green valley endseq',
#  'startseq three people hang out on top of big hill endseq',
#  'startseq three people overlook green valley endseq',
#  'startseq three people rest on ledge above the moutains endseq',
#  'startseq boy in green shirt is looking down at many inflatable boats endseq',
#  'startseq boy in green shirt watches kayakers endseq',
#  'startseq boy looks over railing at the many boats and rafts below in the water endseq',
#  'startseq young boy overlooking crowd of inflatable boats endseq',
#  'startseq young boy wearing jersey looks down over ledge at many boats in the water endseq',
#  'startseq man and woman pose for the camera while another man looks on endseq',
#  'startseq man is holding the hand of woman up to his mouth in front of some buildings while another man looks on endseq',
#  'startseq multiracial couple posing for picture endseq',
#  'startseq asian man and blond woman holding hands outdoors man in background watches endseq',
#  'startseq guy in blue shirt biting hand of girl in black striped jacket while another guy watches endseq',
#  'startseq person eats takeout while watching small television endseq',
#  'startseq person sits on the floor and eats in front of television endseq',
#  'startseq television with picture of girl on it endseq',
#  'startseq young man sits on the floor by the television with fast food meal in front of him endseq',
#  'startseq someone is laying in front of the tv eating food endseq',
#  'startseq couple of several people sitting on ledge overlooking the beach endseq',
#  'startseq group of people sit on wall at the beach endseq',
#  'startseq group of teens sit on wall by beach endseq',
#  'startseq crowd of people at the beach endseq',
#  'startseq several young people sitting on rail above crowded beach endseq',
#  'startseq boy takes jump on his skateboard while another boy with skateboard watches endseq',
#  'startseq child is performing skateboard trick while another child with skateboard leans on wall endseq',
#  'startseq little boy skateboarder is doing trick on his board while another young skateboarder watches endseq',
#  'startseq young boy skateboarder jumping on platform on skateboard endseq',
#  'startseq two skateboarders endseq',
#  'startseq girl paddling down large river as seen from behind her endseq',
#  'startseq woman kayaking down river endseq',
#  'startseq woman paddles boat down river endseq',
#  'startseq woman with paddle endseq',
#  'startseq woman with paddle sits in boat on the water endseq',
#  'startseq girl in pigtails splashes in the shallow water endseq',
#  'startseq girls plays in the surf endseq',
#  'startseq girl with pigtails is playing in the ocean by the beach endseq',
#  'startseq girl with pigtails plays in the water endseq',
#  'startseq young girl in pigtails plays in the water endseq',
#  'startseq group of four children wearing pajamas have pillow fight endseq',
#  'startseq group of kids have pillowfight endseq',
#  'startseq group of young children playing pillow fight on bed endseq',
#  'startseq children having pillow fight endseq',
#  'startseq four children are having pillow fight endseq',
#  'startseq two constructions workers sit on beam taking break endseq',
#  'startseq two construction workers are sitting up on the side of building endseq',
#  'startseq two construction workers sitting on an ibeam endseq',
#  'startseq two construction workers take seat on steel beam endseq',
#  'startseq two men take break from construction endseq',
#  'startseq the children are playing in the water endseq',
#  'startseq two boys one with yellow and orange ball play in some water in front of field endseq',
#  'startseq two boys play in puddle endseq',
#  'startseq two children play with balloon in mud on sunny day endseq',
#  'startseq two kids are running and playing in some water endseq',
#  'startseq blond woman in blue shirt appears to wait for ride endseq',
#  'startseq blond woman is on the street hailing taxi endseq',
#  'startseq woman is signaling is to traffic as seen from behind endseq',
#  'startseq woman with blonde hair wearing blue tube top is waving on the side of the street endseq',
#  'startseq the woman in the blue dress is holding out her arm at oncoming traffic endseq',
#  'startseq little girl looking at brochure on train rides endseq',
#  'startseq young blond girl with magizine in her hands endseq',
#  'startseq young girl on train reads book about train rides endseq',
#  'startseq young girl sits on seat and looks at train pamphlet endseq',
#  'startseq child sitting down looking at train ride brochure endseq',
#  'startseq brown dog is running after black dog on rocky shore endseq',
#  'startseq brown dog is running after the black dog endseq',
#  'startseq two dogs playing on beach endseq',
#  'startseq two dogs run across stones near body of water endseq',
#  'startseq two dogs run towards each other on rocky area with water in the background endseq',
#  'startseq boy descends off the end of high diving board endseq',
#  'startseq child jumps off high diving board into the pool endseq',
#  'startseq kid jumps off the diving board and into the swimming pool below endseq',
#  'startseq little kid is jumping off high dive at the pool endseq',
#  'startseq the boy is jumping off high diving board into the pool endseq',
#  'startseq guy stands by window taking his overshirt off endseq',
#  'startseq man in tank top stands next to chrome door endseq',
#  'startseq man puts his shirt on near an elevator endseq',
#  'startseq man stands by an elevator with his head down endseq',
#  'startseq the man is putting on his shirt near an elevator endseq',
#  'startseq lightcolored dog runs on the beach endseq',
#  'startseq small yellow dog runs on beach endseq',
#  'startseq tan dog runs on sandy beach endseq',
#  'startseq white dog is running down rocky beach endseq',
#  'startseq light brown dog running along the beach endseq',
#  'startseq boy in his blue swim shorts at the beach endseq',
#  'startseq boy smiles for the camera at beach endseq',
#  'startseq young boy in swimming trunks is walking with his arms outstretched on the beach endseq',
#  'startseq children playing on the beach endseq',
#  'startseq the boy is playing on the shore of an ocean endseq',
#  'startseq hiker standing high on bluff overlooking the mountains below endseq',
#  'startseq person on ski looks from hill over snow covered landscape endseq',
#  'startseq skier is overlooking snowcovered mountain endseq',
#  'startseq skier is overlooking the beautiful white snow covered landscape endseq',
#  'startseq skier pauses on mountaintop endseq',
#  'startseq black and white dog is attempting to catch yellow and purple object in low cut yard endseq',
#  'startseq black and white dog jumps after yellow toy endseq',
#  'startseq black and white dog jumps to get the frisbee endseq',
#  'startseq black dog is jumping up to catch purple and green toy endseq',
#  'startseq dog jumps to catch toy endseq',
#  'startseq man in blue shorts is laying in the street endseq',
#  'startseq man in blue shorts lays down outside in parking lot endseq',
#  'startseq man laying down in middle of street during heavy traffic endseq',
#  'startseq man lies on mat in parking lot between brown suv and yellow pickup with an open door endseq',
#  'startseq shirtless man is laying down in the middle of busy street endseq',
#  'startseq white and black dog and brown dog in sandy terrain endseq',
#  'startseq woolly dog chases doberman on beach endseq',
#  'startseq one dog is chasing another one on the beach endseq',
#  'startseq the two large dogs are running through sand endseq',
#  'startseq two large dogs chasing each other at the beach endseq',
#  'startseq black and white dog catches toy in midair endseq',
#  'startseq dog and tennis ball endseq',
#  'startseq dog is jumping to catch object thrown at it endseq',
#  'startseq dog leaps while chasing tennis ball through grassy field endseq',
#  'startseq multicolor dog jumping to catch tennis ball in grassy field endseq',
#  'startseq crowd watching air balloons at night endseq',
#  'startseq group of hot air balloons lit up at night endseq',
#  'startseq people are watching hot air balloons in the park endseq',
#  'startseq people watching hot air balloons endseq',
#  'startseq seven large balloons are lined up at nighttime near crowd endseq',
#  'startseq child with helmet on his head rides bike endseq',
#  'startseq little boy rides bike down hill on miniature dirt bike endseq',
#  'startseq young boy in helmet rides bike on the road endseq',
#  'startseq the little boy rides his bicycle in race endseq',
#  'startseq the young boy pedals quickly at bmx race endseq',
#  'startseq group of eight people are gathered around table at night endseq',
#  'startseq group of people gathered around in the dark endseq',
#  'startseq group of people sit around table outside on porch at night endseq',
#  'startseq group of people sit outdoors together at night endseq',
#  'startseq group of people sitting at table in darkened room endseq',
#  'startseq man in brown shirt and dark shorts plays on the beach with his two black dogs endseq',
#  'startseq man in shorts with two black dogs holds ball throwing toy at the beach endseq',
#  'startseq man playing with two black dogs on the beach endseq',
#  'startseq man with two dogs on beach endseq',
#  'startseq man at the beach with two dogs endseq',
#  'startseq boy cleans the bubbles off his face endseq',
#  'startseq boy covered in suds has his face wiped clean endseq',
#  'startseq boy is covered in bubbles endseq',
#  'startseq child covered in foam is climbing on black inflatable ramp endseq',
#  'startseq person covered in soapy water is getting cleaned off endseq',
#  'startseq boy in blue shorts slides down slide into pool endseq',
#  'startseq boy in blue swimming trunks slides down yellow slide into wading pool with inflatable toys floating in the water endseq',
#  'startseq boy rides down slide into small backyard pool endseq',
#  'startseq boy sliding down slide into pool with colorful tubes endseq',
#  'startseq child is falling off slide onto colored balloons floating on pool of water endseq',
#  'startseq man in wetsuit is throwing baby wearing wetsuit up into the air endseq',
#  'startseq man in wetsuit is throwing toddler up in the air and is ready to catch him endseq',
#  'startseq man in water throwing little boy up in the air and waiting for him to come down so he can catch him endseq',
#  'startseq the man is in the pool and throwing small boy into the air endseq',
#  'startseq while water droplets fly man throws little boy up in the air endseq',
#  'startseq little boy sticks his tongue out for the camera another boy looks on endseq',
#  'startseq two boys make faces endseq',
#  'startseq two young boys are looking at the camera one smiling the other sticking his tongue out endseq',
#  'startseq two young boys look up at the camera as one sticks out his tongue endseq',
#  'startseq two young boys making silly faces endseq',
#  'startseq blonde horse and blonde girl in black sweatshirt are staring at fire in barrel endseq',
#  'startseq girl and her horse stand by fire endseq',
#  'startseq girl holding horse lead behind fire endseq',
#  'startseq man and girl and two horses are near contained fire endseq',
#  'startseq two people and two horses watching fire endseq',
#  'startseq bulldog sheep dog and boxer standing in yard endseq',
#  'startseq large brown dog is pushing small boston terrier with his face while anouther dog watches endseq',
#  'startseq large skinny dog stands near two smaller dogs int the dirt endseq',
#  'startseq there are three dogs starring at ball in the middle of them endseq',
#  'startseq three dogs of various sizes endseq',
#  'startseq lady and man with no shirt sit on dock endseq',
#  'startseq man and woman are sitting on dock together endseq',
#  'startseq man and woman sitting on dock endseq',
#  'startseq man and woman sitting on deck next to lake endseq',
#  'startseq shirtless man and woman sitting on dock endseq',
#  'startseq closeup of white dog that is laying its head on its paws endseq',
#  'startseq large white dog lying on the floor endseq',
#  'startseq white dog has its head on the ground endseq',
#  'startseq white dog is resting its head on tiled floor with its eyes open endseq',
#  'startseq white dog rests its head on the patio bricks endseq',
#  'startseq woman in yellow shirt and green shorts is climbing an artificial red wall whilst wearing safety harness endseq',
#  'startseq woman in blue shorts and white shirt is indoor rock climbing endseq',
#  'startseq the girl is climbing rock wall endseq',
#  'startseq the girl is in harness climbing rocks endseq',
#  'startseq woman climbing an artificial rock wall endseq',
#  'startseq boy is jumping on an inflatable ring and girl is watching him endseq',
#  'startseq boy jumping on water jumphouse endseq',
#  'startseq teenage boy is jumping on an inflatable slide endseq',
#  'startseq young boy jumping and young girl seating in an inflatable pool endseq',
#  'startseq two young kids are playing in the water on an inflated toy endseq',
#  'startseq family playing on tractor on beautiful day endseq',
#  'startseq children ride tractor in field endseq',
#  'startseq several children playing on polaris vehicle outdoors endseq',
#  'startseq the children played on the four wheeler in the field endseq',
#  'startseq the four kids are riding on an atv in field endseq',
#  'startseq woman in red costume to the left of man and woman standing together endseq',
#  'startseq woman wearing red costume looks at two other people standing on street endseq',
#  'startseq young woman in red sequined costume and feather stands on the sidewalk endseq',
#  'startseq the girl in the salmon colored bikini is standing next to two young people one is wearing black outfit and the other is drinking pop endseq',
#  'startseq two young people are approached by flamboyant young woman dressed in red bikini and red feathered headress endseq',
#  'startseq skiiers walking up the hill through forest endseq',
#  'startseq two men are skiing in the snow in wooded area endseq',
#  'startseq two people wearing yellow jackets crosscountry skiing endseq',
#  'startseq two skiers are making their way through woodland endseq',
#  'startseq two skiers are sliding down trail in the woods endseq',
#  'startseq lone skier is making their way up mountain endseq',
#  'startseq skiiers at the top of snow covered hill endseq',
#  'startseq two hikers climbing snowy hill endseq',
#  'startseq two people are on snowcovered mountain endseq',
#  'startseq two people climbing up snowy mountain endseq',
#  'startseq brown dog running down paved pathway endseq',
#  'startseq brown dog running next to grass endseq',
#  'startseq dog is running down road endseq',
#  'startseq light brown dog runs down path happily endseq',
#  'startseq energetic brown dog running endseq',
#  'startseq mother and children is fishing on boardwalk at night endseq',
#  'startseq woman and three children stand on deck with fishing pole endseq',
#  'startseq woman stands with children on boardwalk at night overlooking the sea endseq',
#  'startseq some people on pier at night with one girl fishing off it endseq',
#  'startseq woman with three children fishing over boardwalk in the evening endseq',
#  'startseq woman dressed in blue jacket and blue jeans rides brown horse near frozen lake and snowcovered mountain endseq',
#  'startseq woman in blue jacket rides brown pony near water endseq',
#  'startseq woman rides horse near frozen lake in the wintertime endseq',
#  'startseq young blond woman sitting atop brown draft horse in the snowy mountains endseq',
#  'startseq woman blue jacket sits on daft horse near frozen lake endseq',
#  'startseq two draft horses pull cart through the snow endseq',
#  'startseq two golden brown horses pull sleigh driven by woman in blue coat endseq',
#  'startseq two horses are pulling woman in cart endseq',
#  'startseq two horses pull carriage driven by woman over snow covered ground endseq',
#  'startseq two horses pulling sled steered by smiling blond woman endseq',
#  'startseq person climbing down sheer rock cliff using rope endseq',
#  'startseq person climbs tall flat mountain while holding onto safety rope endseq',
#  'startseq person is climbing rock while holding onto white rope endseq',
#  'startseq person rappels down steep incline endseq',
#  'startseq person wearing red vest climbs up steep rock endseq',
#  'startseq people stand inside rock dome endseq',
#  'startseq shaft of light in cave shows three spelunkers endseq',
#  'startseq spelunkers pose inside rock cavern while bathed in sunlight from the surface endseq',
#  'startseq three people sit in cave endseq',
#  'startseq three rock climbers are posing on big rocks endseq',
#  'startseq group of backpackers lay on the dry ground endseq',
#  'startseq group of hikers are resting on the ground in front of some mountains endseq',
#  'startseq people camp with the mountains in the background endseq',
#  'startseq several hikers rest with their gear in front of mountain endseq',
#  'startseq the group of hikers is resting in front of mountain endseq',
#  'startseq woman in blue dress stands with chalk portrait of two children playing by stream endseq',
#  'startseq woman standing in front of chalk drawing endseq',
#  'startseq woman stands next to chalk drawing in front of barnlike structure endseq',
#  'startseq woman stands outside near an elaborate chalk illustration endseq',
#  'startseq woman wearing blue dress is drawing picture of boy and girl on the sidewalk with sidewalk chalk endseq',
#  'startseq brown dog plays in deep pile of snow endseq',
#  'startseq dog looking at the camera in snow endseq',
#  'startseq dog runs through the snow endseq',
#  'startseq tan dog stand in the snow and looks up endseq',
#  'startseq the brown dog is out in the snow endseq',
#  'startseq boy jumping in fountain endseq',
#  'startseq boy plays in the fountains endseq',
#  'startseq child plays in fountain endseq',
#  'startseq little boy playing in the water endseq',
#  'startseq young boy is jumping through water being sprayed up from the ground endseq',
#  'startseq corgi runs out of tunnel endseq',
#  'startseq dog runs out of tunnel on course endseq',
#  'startseq dog running out of tunnel on obstacle course endseq',
#  'startseq the dog is running out of the tunnel on dog obedience course endseq',
#  'startseq the small brown and white dog is running out of small tunnel endseq',
#  'startseq blond dog and black and white dog run in dirt field endseq',
#  'startseq dog chases another dog endseq',
#  'startseq yellow dog and black and white dog are running in the dirt endseq',
#  'startseq two dogs are running in field endseq',
#  'startseq two dogs running around endseq',
#  'startseq little girl in blue swimsuit is walking along wooden fence next to sandy beach endseq',
#  'startseq little girl with arms outstretched is posing at the beach endseq',
#  'startseq young girl walks on railing in front of the beach endseq',
#  'startseq little girl in blue swimsuit standing on handrail near beach endseq',
#  'startseq the little girl in the blue bathing suit is posing at the beach endseq',
#  'startseq black and white dog drinking water from water spray endseq',
#  'startseq black and white dog is being soaked with jet of water in blue paddling pool endseq',
#  'startseq dog sticking its face into the shower from garden hose endseq',
#  'startseq small white dog gets sprayed by water endseq',
#  'startseq white and black dog is jumping into pool endseq',
#  'startseq boy smiles underwater endseq',
#  'startseq redheaded boy swimming underwater endseq',
#  'startseq small boy swimming underwater endseq',
#  'startseq smiling boy swims underwater in pool endseq',
#  'startseq the boys smiles underwater at the pool endseq',
#  'startseq boy with toy gun endseq',
#  'startseq little boy in orange shorts playing with toy endseq',
#  'startseq young boy with his foot outstretched aims toy at the camera in front of fireplace endseq',
#  'startseq young child plays with his new lightup toy endseq',
#  'startseq boy with toy gun pointed at the camera endseq',
#  'startseq boy in yellow shorts is standing on top of cliff endseq',
#  'startseq boy wearing blue and yellow walking on cliff edge endseq',
#  'startseq little boy standing high in the air on rock endseq',
#  'startseq young child is standing alone on some jagged rocks endseq',
#  'startseq child stands near edge of cliff endseq',
#  'startseq person on snowmobile in mid jump endseq',
#  'startseq snowmobiler flies through the air endseq',
#  'startseq snowmobile rider flies through the air on his or her machine in front of tall pine trees endseq',
#  'startseq rider jumps snowmobile high in rural area endseq',
#  'startseq the man is up in the air endseq',
#  'startseq people are riding around on snowmobiles endseq',
#  'startseq people pose with helmets and goggles on while riding snowmobiles endseq',
#  'startseq several people are taking break while on snowmobiling ride endseq',
#  'startseq three people and two snowmobiles endseq',
#  'startseq two helmeted men sit on yellow snowmobiles while another man stands behind watching endseq',
#  'startseq three people drive atvs endseq',
#  'startseq three people on atvs in brown field turn their heads to look at the camera endseq',
#  'startseq three people on atv outside endseq',
#  'startseq three people on four wheel atv in field endseq',
#  'startseq three people ride their four wheelers through the field endseq',
#  'startseq four wheeler jumping in an empty field endseq',
#  'startseq man on four wheeler is flying through the air endseq',
#  'startseq person is riding an orange atv in large empty field endseq',
#  'startseq man jumping with all terrain vehicle endseq',
#  'startseq man on an atv catching air endseq',
#  'startseq man jumps gin the air while riding an atv endseq',
#  'startseq man on fourwheeler jumps near small building endseq',
#  'startseq an atv is airborne over field in front of white structure endseq',
#  'startseq person dressed in tan jacket jumps quad over harvested cornfield in front of small out building endseq',
#  'startseq man on four wheeler in the air endseq',
#  'startseq boy in striped shirt is jumping in front of water fountain endseq',
#  'startseq boy is jumping off the side of running stone water fountain in front of building endseq',
#  'startseq happy boy is jumping in front od city fountain endseq',
#  'startseq little boy is jumping in front of fountain endseq',
#  'startseq little boy is playfully jumping off the side of fountain endseq',
#  'startseq boy carrying soccer ball endseq',
#  'startseq boy walks with ball tucked under his arm endseq',
#  'startseq boy walks with soccer ball near fence endseq',
#  'startseq boy wearing white tshirt walks on the grass and carries soccer ball endseq',
#  'startseq small boy carries soccer ball on field endseq',
#  'startseq child painting picture endseq',
#  'startseq an artist paints clouds onto canvas endseq',
#  'startseq young girl painting picture endseq',
#  'startseq young girl with braids is painting with water colors on white paper on the wall endseq',
#  'startseq the child paints on large paper with water colors endseq',
#  'startseq cyclist is riding bicycle on curved road up hill endseq',
#  'startseq man in aerodynamic gear riding bicycle down road around sharp curve endseq',
#  'startseq man on mountain bike is pedaling up hill endseq',
#  'startseq man bicycle up road while cows graze on hill nearby endseq',
#  'startseq the biker is riding around curve in the road endseq',
#  'startseq black dog jumping to catch rope toy endseq',
#  'startseq black dog playing fetch with ball of rope endseq',
#  'startseq black dog pounces to get rope toy endseq',
#  'startseq black dog running after his rope toy endseq',
#  'startseq large black dog is playing in grassy yard endseq',
#  'startseq little girl is holding cine camera in front of her face endseq',
#  'startseq young girl is looking through an old fashioned video camera endseq',
#  'startseq young girl steadies her aim with camera endseq',
#  'startseq girl with rosy cheeks and lips holding black toy gun endseq',
#  'startseq there is kid with gun endseq',
#  'startseq black and white border collie catches frisbee in front of an audience endseq',
#  'startseq brown and white dog catches frisbee in it mouth in front of group of people endseq',
#  'startseq brown and white dug jumping up to catch frisbee while an audience watches endseq',
#  'startseq dog jumps to catch frisbee while many people watch endseq',
#  'startseq an agile dog catches frisbee while crowd of onlookers watches closely endseq',
#  'startseq baby is sitting on and playing with smooth rocks endseq',
#  'startseq baby is stacking rocks on the beach endseq',
#  'startseq small boy is playing with rocks endseq',
#  'startseq toddler sitting on pile of rocks holding rock at beach endseq',
#  'startseq toddler sits on pile of rocks endseq',
#  'startseq kid rock climbing against the backdrop of green valley endseq',
#  'startseq woman in striped shirt climbs up mountain endseq',
#  'startseq young man climbs rocky hill endseq',
#  'startseq the person has striped shirt on and is holding on to rope on mountain endseq',
#  'startseq the person in the striped shirt is mountain climbing endseq',
#  'startseq man climbing rock wall endseq',
#  'startseq man climbing the side of cliff endseq',
#  'startseq man is rock climbing endseq',
#  'startseq man with red shoes white shirt and grey pants climbing endseq',
#  'startseq the young man with the white tshirt and jeans is rappeling up the rock wall endseq',
#  'startseq climber wearing blue helmet and headlamp is attached to rope on the rock face endseq',
#  'startseq man climbs rocky wall endseq',
#  'startseq rock climber climbs large rock endseq',
#  'startseq woman in purple snakeskin pants climbs rock endseq',
#  'startseq person with blue helmet and purple pants is rock climbing endseq',
#  'startseq child playing with fountain at the beach endseq',
#  'startseq child plays with fountain endseq',
#  'startseq girl looks at fountain that sprays water endseq',
#  'startseq little girl playing in water on frog sculpture endseq',
#  'startseq the little girl is playing with toy in public fountain endseq',
#  'startseq black dog is jumping over log along beach endseq',
#  'startseq black dog runs along the beach and jumps over wood barrior endseq',
#  'startseq dog is running on the beach endseq',
#  'startseq dog jumping over small wall at beach near the water endseq',
#  'startseq an animal is running on the beach endseq',
#  'startseq black and white bird eating seeds out of someone hand endseq',
#  'startseq black and white bird standing on hand endseq',
#  'startseq small bird sits in person hand and eats seeds endseq',
#  'startseq black and white bird standing on hand of someone holding sunflower seeds endseq',
#  'startseq the small bird is clinging to finger of the hand holding the seeds endseq',
#  'startseq brown dog is running in the sand endseq',
#  'startseq brown dog playing in the sand endseq',
#  'startseq brown dog plays at the beach endseq',
#  'startseq dog is standing in the sand endseq',
#  'startseq dog running fast in the sand endseq',
#  'startseq little boy stands in the surf endseq',
#  'startseq small child wades through the water while being guided by another person endseq',
#  'startseq young boy laughs while splashing in the ocean endseq',
#  'startseq young boy wearing colorful bathing suit splashing in the ocean endseq',
#  'startseq young child splashing in water endseq',
#  'startseq little tan dog with large ears running through the grass endseq',
#  'startseq playful dog is running through the grass endseq',
#  'startseq small dogs ears stick up as it runs in the grass endseq',
#  'startseq the small dog is running across the lawn endseq',
#  'startseq this is small beige dog running through grassy field endseq',
#  'startseq black and white dog is running through the field endseq',
#  'startseq black brown and white dog running through field endseq',
#  'startseq brown black and white dog is running through large field with its mouth open endseq',
#  'startseq dog running in field endseq',
#  'startseq dog with its mouth open running through field torwards the camera endseq',
#  'startseq girl in pink swimsuit in pool endseq',
#  'startseq girl swimming in pool endseq',
#  'startseq little girl in pink bathing suit swimming in pool endseq',
#  'startseq little girl swimming in pool endseq',
#  'startseq smiling little girl swimming in outdoor pool endseq',
#  'startseq child is standing on her head endseq',
#  'startseq little girl standing on her head endseq',
#  'startseq small child doing handstand on bed endseq',
#  'startseq young girl does handstand on bed with blue sheets endseq',
#  'startseq the girl is upside down on bed endseq',
#  'startseq guy stands in the sand with snowboard behind him endseq',
#  'startseq man holds surfboard on the beach endseq',
#  'startseq man holds his snowboard in the sand endseq',
#  'startseq man with his surfboard stands in the sand endseq',
#  'startseq man is standing on white sand and holding snowboard endseq',
#  'startseq people on atvs and dirt bikes are traveling along worn path in field surrounded by trees endseq',
#  'startseq three people are riding around on atv and motorcycles endseq',
#  'startseq three people on motorbikes follow trail through dry grass endseq',
#  'startseq three people on two dirtbikes and one fourwheeler are riding through brown grass endseq',
#  'startseq three people ride offroad bikes through field surrounded by trees endseq',
#  'startseq baby in white garment holds flag with crescent moon and star endseq',
#  'startseq baby is holding small black flag with moon and star on it endseq',
#  'startseq baby wearing white gown waves muslim flag endseq',
#  'startseq little toddler dressed in white is smiling while lady helps him wave flag endseq',
#  'startseq baby in white outfit holding black and white flag endseq',
#  'startseq half naked man is sleeping on his chair outdoors endseq',
#  'startseq an older man sits back and relaxes on patio outside an adobe building where many bicycles are propped endseq',
#  'startseq shirtless man in white cap relaxes in deck chair close to three parked bicycles endseq',
#  'startseq man relaxing in folding chair on the street endseq',
#  'startseq topless old man wearing slippers navy blue pants and white hat while reclining in chair outside endseq',
#  'startseq brown and white and black and white dog hauling in floating toy from the ocean endseq',
#  'startseq both dogs retrieve the play toy from the water endseq',
#  'startseq two dogs in the ocean playing with toy endseq',
#  'startseq two dogs run through the water with rope in their mouths endseq',
#  'startseq two dogs tug at chew toy in the surf endseq',
#  'startseq there are three young people one dark haired holding bottled drink one with head tilted back and finger in her mouth and one with spiked hair endseq',
#  'startseq the young people party in the streets endseq',
#  'startseq three girls make faces as one takes drink while they stand in busy street endseq',
#  'startseq three women on the street drinking and posing endseq',
#  'startseq three young women pose for the camera at parade endseq',
#  'startseq brown dog is running through neckdeep water carrying tennis ball endseq',
#  'startseq brown dog splashes in the water while carrying ball in its mouth endseq',
#  'startseq brown dog swims through water outdoors with tennis ball in its mouth endseq',
#  'startseq red dog holding ball splashes through vegetation filled water endseq',
#  'startseq brown dog with tennis ball in mouth in water and bushes endseq',
#  'startseq two brown dogs are creating large splashes as they run in river endseq',
#  'startseq two brown dogs in the water endseq',
#  'startseq two brown dogs running through water endseq',
#  'startseq two brown dogs runs through the water endseq',
#  'startseq two dogs splash through the water endseq',
#  'startseq black dog runs into the ocean next to pile of seaweed endseq',
#  'startseq black lav runs into the water on the beach with swimmers in the distance and sea kelp in the foreground endseq',
#  'startseq dog at the shore of an ocean with seaweed in foreground endseq',
#  'startseq dog is running in the waves at the beach endseq',
#  'startseq pile of seaweed sits on the sand behind it big black dog is running in the water endseq',
#  'startseq young boy runs while wearing sandals endseq',
#  'startseq little boy in striped shirt and brown shorts is running endseq',
#  'startseq the little boy in short sleeved shirt and shorts is running outside endseq',
#  'startseq the little boy is wearing black pinstripe shirt and walking on deck endseq',
#  'startseq young boy running outside on the pavement endseq',
#  'startseq brown and white dog stands outside while it snows endseq',
#  'startseq dog is looking at something near the water endseq',
#  'startseq furry dog attempts to dry itself by shaking the water off its coat endseq',
#  'startseq white and brown dog shaking its self dry endseq',
#  'startseq the large brown and white dog shakes off water endseq',
#  'startseq two men are sitting on the ground and going through their backpacks endseq',
#  'startseq two men sitting in front of railing are looking at something endseq',
#  'startseq two men with backpacks placed in front of them sitting in front of railing endseq',
#  'startseq two men with backpacks are sitting on cardboard along railing endseq',
#  'startseq two older men with backpacks sit at bus station endseq',
#  'startseq boy is jumping on bed endseq',
#  'startseq boy jumped up from the green bed endseq',
#  'startseq boy jumps from one bed to another endseq',
#  'startseq small child is jumping on bed endseq',
#  'startseq the boy in blue shorts is bouncing on the bed endseq',
#  'startseq child leaping from bed to bed behind the back of man endseq',
#  'startseq man is standing with his arms folded looking at something while the person behind him is jumping onto one of the two beds in the room endseq',
#  'startseq man wearing yellow shirt standing in the middle of two beds that boy is jumping on in the background endseq',
#  'startseq young child jumping on the bed as man looks the other way endseq',
#  'startseq man standing in the bedroom with little boy jumping into bed endseq',
#  'startseq snowboarder sits on slope with skiers and boarders nearby endseq',
#  'startseq snowboarder takes rest on the mountainside endseq',
#  'startseq snowboarders sitting in the snow while skiers take the hill endseq',
#  'startseq the snowboarder is sitting down endseq',
#  'startseq two skiers stand two sit on slopes endseq',
#  'startseq girl in green walks down city street endseq',
#  'startseq small child in green clothing walks past store opening and woman in pink pants endseq',
#  'startseq small child walks down sidewalk endseq',
#  'startseq young boy is walking in front of some stores endseq',
#  'startseq the child in the green one piece suit is walking past store window endseq',
#  'startseq boy dressed in soccer attire and holding his shoes getting out of car endseq',
#  'startseq boy in red soccer strip is holding his boots in his hand whilst stepping out of car endseq',
#  'startseq boy in glasses is wearing red shirt endseq',
#  'startseq child getting out of the car wearing soccer shoes endseq',
#  'startseq young boy gets out of the van and prepares his shoes for wear during soccer game endseq',
#  'startseq bridge through high green plants man and woman on it endseq',
#  'startseq man and woman are crossing over rope bridge with greenery all over them endseq',
#  'startseq man and woman are walking across rope bridge endseq',
#  'startseq man and woman crossing suspension bridge in tropical setting endseq',
#  'startseq woman and man walking across wooden rope bridge with caution sign beside it endseq',
#  'startseq family gathered at painted van endseq',
#  'startseq girl climbing down from the side of bright blue truck while others watch endseq',
#  'startseq man is helping girl step down from colorful truck whilst woman and three children watch endseq',
#  'startseq very colorful bus is pulled off to the side of the road as its passengers load endseq',
#  'startseq two women and four children standing next to brightly painted truck endseq',
#  'startseq blond woman poses with person in pink costume endseq',
#  'startseq smiling woman holds person dressed in pig costume endseq',
#  'startseq young woman hugs young man who wearing pink costume endseq',
#  'startseq blond embracing young man in pink costume at event endseq',
#  'startseq two people are hugging and one is wearing pinkhooded stretch top endseq',
#  'startseq bicyclist riding on city street endseq',
#  'startseq woman in blue helmet and brown shorts rides her bike on busy street endseq',
#  'startseq woman is riding blue bike endseq',
#  'startseq woman is riding her bicycle in traffic endseq',
#  'startseq woman wearing blue helmet rides her bicycle in parking lot endseq',
# ...
#  'startseq man stands next to bank of computer gambling machines endseq',
#  'startseq man stands next to three video game machines and beer sign endseq',
#  'startseq man stands next to three video machines endseq',
#  'startseq big brown dog plays with smaller grey dog on the grass endseq',
#  'startseq the dark brown dog is playing with the light brown dog endseq',
#  'startseq two brown dogs are running through the grass endseq',
#  'startseq two brown dogs run side by side endseq',
#  'startseq two dogs running and playing rough in the grass endseq',
#  'startseq girl in blue is jumping on the shore as small waves approach her endseq',
#  'startseq girl leaps into the air while standing by the ocean endseq',
#  'startseq young longhaired girl on the beach is jumping in the air endseq',
#  'startseq the girl is running into the ocean from the shore endseq',
#  'startseq the girls is jumping into the air on the beach endseq',
#  'startseq crowd of people walk down busy sidewalk endseq',
#  'startseq group of different people are walking in all different directions in city endseq',
#  'startseq group of people walking city street in warm weather endseq',
#  'startseq busy intersection in the summer time in city endseq',
#  'startseq people in summer clothes are walking on the sidewalk of large city endseq',
#  'startseq big dog catches ball on his nose endseq',
#  'startseq brown and black dog is jumping to catch red ball endseq',
#  'startseq brown and black dog jumps for red ball endseq',
#  'startseq dog jumps to get orange ball on his head endseq',
#  'startseq the brown and black dog is jumping up to catch red ball endseq',
#  'startseq two blonde boys one in camouflage shirt and the other in blue are having water fight endseq',
#  'startseq two boys are squirting water guns at each other endseq',
#  'startseq two boys spraying each other with water endseq',
#  'startseq two children wearing jeans squirt water at each other endseq',
#  'startseq two young boys are squirting water at each other endseq',
#  'startseq brown dog jumping into pool after bloe ball endseq',
#  'startseq dog in the air above the swimming pool endseq',
#  'startseq dog jumps into backyard pool endseq',
#  'startseq tan colored dog is jumping into an outdoor pool endseq',
#  'startseq tan colored dog leaps into the inground pool endseq',
#  'startseq parents are pushing little children in red car carts endseq',
#  'startseq twin boys being pushed in small car shaped strollers in parade endseq',
#  'startseq twin toddlers dressed alike being pushed in plastic car strollers in parade endseq',
#  'startseq two children ride in toy cars endseq',
#  'startseq two kids being pushed in car shaped strollers in parade endseq',
#  'startseq boys baseball team wear their uniforms endseq',
#  'startseq small boy smiles as he stands with others wearing the same black hats endseq',
#  'startseq children sporting their florida dolphin caps endseq',
#  'startseq the boys are all wearing the same baseball hats endseq',
#  'startseq three boys wearing florida marlins hats endseq',
#  'startseq brown dog running through the grass and flowers endseq',
#  'startseq dog in field endseq',
#  'startseq dog running in field of grass and flowers endseq',
#  'startseq dog running in shrubbery along stream endseq',
#  'startseq dog walks through field endseq',
#  'startseq small brown and black dog endseq',
#  'startseq small brown and black dog playing with toy endseq',
#  'startseq small dog plays with toy on top of white blanket endseq',
#  'startseq small shaggy dog playing with toy on blanket endseq',
#  'startseq terrier dog playing with toy on blanket endseq',
#  'startseq big tan dog runs on grass with big stick in his mouth endseq',
#  'startseq dog running across grassy field with stick in its mouth endseq',
#  'startseq dog running with stick in his mouth endseq',
#  'startseq dog runs toward the camera with stick in its mouth endseq',
#  'startseq the dog carrying long stick in its mouth endseq',
#  'startseq dog jumping into swimming pool endseq',
#  'startseq grey dog runs alongside pool while yellow dog jumps into the pool endseq',
#  'startseq one dog is jumping into pool while another runs alongside the pool edge endseq',
#  'startseq one tan dog jumping in pool while the other grey dog is on the deck endseq',
#  'startseq two dogs jumping into swimming pool endseq',
#  'startseq little old lady sitting next to an advertisement endseq',
#  'startseq an asian woman waiting at an underground train stop endseq',
#  'startseq an old woman sits in transit station next to backlit advertisement endseq',
#  'startseq woman sits in subway station endseq',
#  'startseq woman with an umbrella is sitting at station with an aquos commercial on the wall endseq',
#  'startseq girl rides unicycle as another rides scooter next to her endseq',
#  'startseq girl rides unicycle with child who rides scooter endseq',
#  'startseq young girl rides unicycle next to another riding scooter on busy street endseq',
#  'startseq the girl on the unicycle reaches out for the child on the scooter endseq',
#  'startseq there is girl on unicycle and child on scooter endseq',
#  'startseq man in brown shirt sitting on dock and reading endseq',
#  'startseq man is sitting next to the water reading endseq',
#  'startseq man reading book on the dock near post endseq',
#  'startseq person in brown jacket is sitting on pier by the water reading endseq',
#  'startseq person sitting on concrete landing next to body of water endseq',
#  'startseq person sits at table behind tree endseq',
#  'startseq person wearing purple jacket stands behind tall tree endseq',
#  'startseq woman in purple jacket is eating snack at table behind the tree endseq',
#  'startseq woman sits at picnic table eating with luggage endseq',
#  'startseq people eat under green trees endseq',
#  'startseq couple walking along on sidewalk endseq',
#  'startseq man and woman walk outside endseq',
#  'startseq man and woman standing in front of refreshment stand endseq',
#  'startseq man in black shirt and jeans walks beside woman in black pants and flowery shirt in front of refreshment stand with others walking nearby endseq',
#  'startseq woman with floral shirt and purse and man with black shirt are walking while another man walks behind them endseq',
#  'startseq boy lays on picnic table bench endseq',
#  'startseq child is laying down on wooden bench endseq',
#  'startseq child is on bench with arms stretched out endseq',
#  'startseq little boy in red shirt sitting on wooden picnic table bench endseq',
#  'startseq little boy lies down on picnic table bench endseq',
#  'startseq dogs fight in grass over toy endseq',
#  'startseq on grass two brown dogs tussle for orange toy endseq',
#  'startseq two dogs are playing rough in green field of grass endseq',
#  'startseq two dogs play with an orange toy in tall grass endseq',
#  'startseq two large brown dogs are playing in the grass endseq',
#  'startseq boy and person suspended above dome structure endseq',
#  'startseq boy in blue shirt is posing in front of an igloo type building with person dangling from rope above the building endseq',
#  'startseq boy poses for picture and in the background man is hanging by rope endseq',
#  'startseq boy stands near structure outside endseq',
#  'startseq young man wearing blue shirt with strange white building in the background endseq',
#  'startseq girl in brown dress surrounded by children closes her eyes endseq',
#  'startseq girl in yellow dress with the sun shining on her face endseq',
#  'startseq girl in yellow dress is standing with her eyes closed in busy park endseq',
#  'startseq young girl in white dress endseq',
#  'startseq children at park endseq',
#  'startseq man in black jacket is taking photo of man in red jacket endseq',
#  'startseq man in black outfit is taking photograph of man in red jacket endseq',
#  'startseq man takes picture of another man in an open area just off of busy street endseq',
#  'startseq young man taking picture of another young man outdoors endseq',
#  'startseq young man takes picture of another young man in front of church endseq',
#  'startseq family sits on bench near beach endseq',
#  'startseq family sits on bench overlooking the beach endseq',
#  'startseq man woman girl and boy sit on concrete bench by beach endseq',
#  'startseq family sitting on bench near the beach endseq',
#  'startseq taking break while vacationing at the beach endseq',
#  'startseq group of climbers begin up sheer rock face endseq',
#  'startseq group of rock climbers climb rock wall in forest endseq',
#  'startseq many people are climbing the mountain surrounded by pretty green trees endseq',
#  'startseq people at distance trying to climb cliff endseq',
#  'startseq the flat side of large rocky mountain endseq',
#  'startseq two men cleaning the outside windows of yacht endseq',
#  'startseq two men climb the side of boat endseq',
#  'startseq two men on the side of barge endseq',
#  'startseq two people outside cleaning windows while on ledge of boat endseq',
#  'startseq two people stand on the side of large white and red boat endseq',
#  'startseq two children are laughing in the grass endseq',
#  'startseq two girls laughing outside in yard endseq',
#  'startseq two girls standing on grass face each other endseq',
#  'startseq two young girls are playing and laughing in green grassy yard endseq',
#  'startseq two young girls playing together endseq',
#  'startseq boy in red and white shirt is on swing endseq',
#  'startseq child looking back on fast moving swing endseq',
#  'startseq litlle boy playing on swing endseq',
#  'startseq young boy in orange and white swings in playground at park endseq',
#  'startseq young boy plays on swing endseq',
#  'startseq boy eats with spoon endseq',
#  'startseq little boy holds spoon up to his mouth endseq',
#  'startseq little boy is eating his food off of spoon while sitting on patio endseq',
#  'startseq small child dressed in green is eating with spoon endseq',
#  'startseq young child holds spoon to its mouth while sitting in chair endseq',
#  'startseq girl walking alone at night on street endseq',
#  'startseq woman in blue coat and blue heels walks down city sidewalk at night endseq',
#  'startseq woman walking down brick sidewalk endseq',
#  'startseq woman walks down brick sidewalk at night endseq',
#  'startseq woman walks down city sidewalk at night endseq',
#  'startseq black dog and brown dog playing in tall weeds endseq',
#  'startseq brown dog and black dog are standing against each other in some grass endseq',
#  'startseq two dogs are playing outside in field endseq',
#  'startseq two dogs play in tall grass endseq',
#  'startseq two dogs wrestle together in the long grass endseq',
#  'startseq brown dog jumping in the air on brown plain endseq',
#  'startseq brown dog jumping into the air to catch ball endseq',
#  'startseq brown dog leaping to catch ball endseq',
#  'startseq coppery dog leaps to catch ball endseq',
#  'startseq dog leaps into the air in grassy field surrounded by trees endseq',
#  'startseq child in gray clothes is sleeping on red cushion endseq',
#  'startseq little boy has fallen asleep on miniature sofa and pacifier in his mouth endseq',
#  'startseq sleeping child sucking on pacifier endseq',
#  'startseq toddler wearing pacifier is sleeping on red blanket with teddy bear at his side endseq',
#  'startseq young baby sucking binky asleep in chair endseq',
#  'startseq baby girl playing at park endseq',
#  'startseq closeup of child on playground with adult supervision endseq',
#  'startseq young boy poses for picture in front of playground endseq',
#  'startseq young girl is smiling in front of the camera at park endseq',
#  'startseq there is little blond hair girl with green sweatshirt and red shirt playing on playground endseq',
#  'startseq girl in helmet rides horse endseq',
#  'startseq girl rides horse endseq',
#  'startseq young girl wearing helmet and riding brown horse endseq',
#  'startseq girl with black helmet riding brown dappled horse endseq',
#  'startseq the little girl is riding in brown horse endseq',
#  'startseq korean man sells soda endseq',
#  'startseq man is sitting at an outside bar near many soda and beer cans endseq',
#  'startseq man wearing glasses with aluminum cans lined up in front of him endseq',
#  'startseq an elderly man is smiling while sitting in front of row of soda cans endseq',
#  'startseq vendor selling drinks in stall endseq',
#  'startseq the hatted males pose for picture endseq',
#  'startseq the two men are wearing tall hats one hat is red print and the other is gold colored endseq',
#  'startseq two men in tall hats frown at the camera endseq',
#  'startseq two men wear silly stove pipe hats and wear makeup endseq',
#  'startseq two people wearing hats sit and look at the camera endseq',
#  'startseq person in blue shirt sits behind two people sitting on wood bench endseq',
#  'startseq people sit on benches endseq',
#  'startseq people sitting on benches in public area endseq',
#  'startseq three people sit on wood benches set on white and orange tile endseq',
#  'startseq three people sit waiting in lobby endseq',
#  'startseq man in sunglasses on an overpass endseq',
#  'startseq man looking at the camera with another man wearing mask endseq',
#  'startseq man wearing sunglasses is standing next to person who is wearing hat and breathing mask endseq',
#  'startseq the man is wearing white shirt and sunglasses endseq',
#  'startseq there are two men with sunglasses one of which is wearing hat and backpack endseq',
#  'startseq boy in wetsuit jumps into pool with bald man endseq',
#  'startseq boy with goggles jumping into pool containing man endseq',
#  'startseq child is jumping into pool while man is watching the child endseq',
#  'startseq swimming person is watching child jump into pool with blue water endseq',
#  'startseq young boy jumps in swimming pool towards bald man in the water endseq',
#  'startseq boy flips off diving board into pool endseq',
#  'startseq boy is diving off diving board into swimming pool endseq',
#  'startseq child is diving into pool endseq',
#  'startseq child jumping into swimming pool from the diving board endseq',
#  'startseq child flips off pool diving board man and another tumbling child at poolside endseq',
#  'startseq lady holds little girl who is trying to catch bubbles endseq',
#  'startseq woman is holding little girl who is trying to catch bubbles endseq',
#  'startseq woman with holding young girl playing with bubbles at picnic endseq',
#  'startseq young woman in blue shirt stands holding young girl in denim dress endseq',
#  'startseq there is woman holding her baby daughter while the daughter claps endseq',
#  'startseq brown dog biting gray dogs ear endseq',
#  'startseq brown dog biting grey dogs ear endseq',
#  'startseq tan dog on grass with mouth open about to bite gray dog ear endseq',
#  'startseq two dogs are playing in grassy field one dog is biting the ear of the other dog endseq',
#  'startseq two dogs are playing together on green grass endseq',
#  'startseq girls wearing sports uniforms and eye protection endseq',
#  'startseq several female lacrosse players are going after ball endseq',
#  'startseq these girls are in uniforms and are playing field hockey endseq',
#  'startseq the woman lacrosse player in blue is about to catch the ball endseq',
#  'startseq women play lacrosse endseq',
#  'startseq dog in number six jersey is running through field endseq',
#  'startseq dog is leaping through the grass endseq',
#  'startseq dog is wearing red number and running through field of green grass while being chased by bird endseq',
#  'startseq white and tan dog leaps through the air endseq',
#  'startseq the dog in vest leaps in the air and there is bird flying endseq',
#  'startseq brown horse and black foal on the beach endseq',
#  'startseq brown horse stands near black horse that is sitting on the ground endseq',
#  'startseq large brown horse stands over small black colt that is kneeling on the sand endseq',
#  'startseq an adult horse approaching foal on sandy plain endseq',
#  'startseq thin brown horse standing and small black horse sitting on sand endseq',
#  ...]

# %%
len(all_captions)
# Out:
# 40455

# %% [markdown]
# ## **Create a vocabulary**

# %%
# tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)
vocab_size = len(tokenizer.word_index) + 1

# %%
vocab_size
# Out:
# 8768

# %% [markdown]
# ## **Define a batch and include the padding sequence**

# %%
# get maximum length of the caption available
max_length = max(len(caption.split()) for caption in all_captions)
max_length
# Out:
# 34

# %%
# Explanatory example of the sequence split into pairs

# startseq girl going into wooden building endseq
#        X                   y
# startseq                   girl
# startseq girl              going
# startseq girl going        into
# ...........
# startseq girl going into wooden building      endseq

# %%
# create data generator to get data in batch (avoids session crash)
def data_generator(data_keys, mapping, features, tokenizer, max_length, vocab_size, batch_size):
  # data_keys: imgID
  # mapping: map of caption with imgID (mapping above)
  # features: fetures of image are extracted
  # tokenizer: a vocab save with name "tokenizer" (tokenizer varible)
  # max_length: max length caption we got
  # vocab size: SIze of vocabulary (vocab_size varible)
  # batch_size: batch size of data training for each epoch

  # loop over images
  X1, X2, y = list(), list(), list()
  n = 0
  while 1:
    for key in data_keys:
      n += 1
      # get caption with key
      captions = mapping[key]

      # process each caption
      for caption in captions:
        # encode caption to the sequence
        seq = tokenizer.texts_to_sequences([caption])[0]

        # split the sequence into X, y pairs
        for i in range(1, len(seq)):
          # split into input and output pairs
          in_seq, out_seq = seq[:i], seq[i]
          # pad input sequence
          in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
          # encode output sequence
          out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
          # store the sequences
          X1.append(features[key][0])
          X2.append(in_seq)
          y.append(out_seq)
      if n == batch_size:
          X1, X2, y = np.array(X1), np.array(X2), np.array(y)
          yield [X1, X2], y
          X1, X2, y = list(), list(), list()
          n = 0

# %% [markdown]
# # **Model creation**

# %%
# encoder model
# image feature layers
inputs1 = Input(shape=(4096,))
fe1 = Dropout(0.4)(inputs1)
fe2 = Dense(256, activation='relu')(fe1)
# sequence feature layers
inputs2 = Input(shape=(max_length,))
se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
se2 = Dropout(0.4)(se1)
se3 = LSTM(256)(se2)

# decoder model
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)

model = Model(inputs=[inputs1, inputs2], outputs=outputs)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# plot the model
plot_model(model, show_shapes=True)

# %% [markdown]
# # **Training**

# %% [markdown]
# ## **Load feature img**

# %%
import pickle

# Load
with open('/content/gdrive/MyDrive/Đồ án/Machine learning/Image captioning/Extracted feature/featured_extracted_flickr.pkl', 'rb') as f:
    features = pickle.load(f)

# %%
features
# Out:
# {'300577375_26cc2773a1': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3468694409_a51571d621': array([[4.0797954 , 0.        , 0.        , ..., 0.39524114, 0.        ,
#          0.46249932]], dtype=float32),
#  '357725852_6f55cb9abc': array([[3.9487529, 3.4432902, 0.       , ..., 0.       , 1.1390073,
#          0.       ]], dtype=float32),
#  '2449446913_28fa5b7c75': array([[0.       , 0.       , 0.       , ..., 0.       , 0.5456462,
#          0.       ]], dtype=float32),
#  '191003285_edd8d0cf58': array([[1.0855836, 1.2068305, 0.       , ..., 0.       , 0.       ,
#          4.1206703]], dtype=float32),
#  '3209966887_5b744bd050': array([[0.        , 0.        , 0.        , ..., 0.        , 0.5690081 ,
#          0.67263347]], dtype=float32),
#  '371522748_dc557bcd6c': array([[0.02463943, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '3534046564_4f8546e364': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '1456393634_74022d9056': array([[0.40348613, 0.24309501, 1.1818912 , ..., 0.        , 1.617017  ,
#          2.6511805 ]], dtype=float32),
#  '3417143124_6feb8290cc': array([[1.2832459 , 1.5575055 , 1.3383462 , ..., 0.        , 2.1045647 ,
#          0.55768126]], dtype=float32),
#  '3237760601_5334f3f3b5': array([[0.       , 0.       , 6.6210227, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2206600240_f65df56a09': array([[3.1536512, 3.197069 , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3543378438_47e2712486': array([[0.9614326, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '1122944218_8eb3607403': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.6317852]], dtype=float32),
#  '534200447_b0f3ff02be': array([[3.50219   , 2.0655942 , 5.257271  , ..., 0.        , 5.1204143 ,
#          0.44994754]], dtype=float32),
#  '3251906388_c09d44340e': array([[0.       , 0.       , 0.       , ..., 0.       , 3.3256114,
#          0.       ]], dtype=float32),
#  '3435653630_3b6cca2c40': array([[0.15438586, 0.        , 0.        , ..., 0.        , 0.        ,
#          8.9972725 ]], dtype=float32),
#  '2211593099_4a4f1c85d2': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.66355973]], dtype=float32),
#  '494907021_321e82877a': array([[1.0276973, 1.1971291, 0.       , ..., 0.       , 1.4957557,
#          0.       ]], dtype=float32),
#  '2359784186_36c9746d02': array([[1.3883193 , 1.129633  , 0.        , ..., 0.        , 0.        ,
#          0.10021555]], dtype=float32),
#  '2275029674_6d4891c20e': array([[0.       , 1.1921618, 1.3890421, ..., 1.0038915, 0.       ,
#          0.       ]], dtype=float32),
#  '2980445969_a86f4e6a0e': array([[0.7073867 , 0.        , 0.48333845, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2222186636_85e03e0b75': array([[0.       , 0.2894447, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3633396324_c4b24b1f51': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3122497129_d08f5729b8': array([[0.       , 0.       , 7.9995503, ..., 0.       , 2.3712857,
#          0.       ]], dtype=float32),
#  '1248734482_3038218f3b': array([[0.7123004, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2549968784_39bfbe44f9': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.070978]],
#        dtype=float32),
#  '2664103423_c539f61016': array([[0.8360437, 0.       , 2.0376952, ..., 0.       , 0.       ,
#          1.5888851]], dtype=float32),
#  '3459419203_cd7c68ce4d': array([[1.9102764 , 0.        , 0.        , ..., 0.        , 2.2737443 ,
#          0.82911456]], dtype=float32),
#  '3374054694_fa56f29267': array([[0.        , 0.3348266 , 0.        , ..., 0.        , 1.8522274 ,
#          0.75097793]], dtype=float32),
#  '3332467180_d72f9b067d': array([[0.14820173, 0.        , 0.6785284 , ..., 0.        , 1.9248576 ,
#          0.        ]], dtype=float32),
#  '2256133102_e2c8314ecb': array([[0.       , 1.9945529, 0.       , ..., 0.       , 4.1246414,
#          0.       ]], dtype=float32),
#  '3559374748_f18c7caa55': array([[0.        , 0.        , 0.44151437, ..., 0.3831431 , 0.        ,
#          1.0944768 ]], dtype=float32),
#  '2471297228_b784ff61a2': array([[0.       , 2.3535645, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2689358407_9932f1b20c': array([[0.        , 1.3006551 , 0.8477958 , ..., 0.        , 2.2660673 ,
#          0.33726332]], dtype=float32),
#  '3217893350_57be430d06': array([[2.1223865, 0.9608811, 0.       , ..., 0.       , 5.133988 ,
#          0.       ]], dtype=float32),
#  '3181599388_68559cfc17': array([[1.4092634, 0.       , 2.409157 , ..., 0.       , 1.3758175,
#          0.5215889]], dtype=float32),
#  '543264612_c53cc163b4': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.8441384]], dtype=float32),
#  '315436114_6d386b8c36': array([[0.7979928, 0.       , 1.5721583, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2139519215_8ca16dd192': array([[2.4266698 , 0.18785068, 0.        , ..., 0.        , 0.        ,
#          0.5121355 ]], dtype=float32),
#  '2773682293_3b712e47ff': array([[0.       , 1.2273861, 0.       , ..., 0.       , 0.3549897,
#          0.       ]], dtype=float32),
#  '3004823335_9b82cbd8a7': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3449170348_34dac4a380': array([[0.      , 4.744071, 0.      , ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '3042173467_14394234da': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 8.332061]],
#        dtype=float32),
#  '2838085973_42b6e9b5b1': array([[0.       , 0.       , 1.6722239, ..., 0.       , 0.       ,
#          2.327643 ]], dtype=float32),
#  '1523800748_a59e980eee': array([[0.       , 0.       , 0.       , ..., 0.       , 1.6934836,
#          1.7916808]], dtype=float32),
#  '3156406419_38fbd52007': array([[0.883913 , 0.       , 5.6742516, ..., 0.       , 1.718049 ,
#          0.       ]], dtype=float32),
#  '720208977_f44c2bba5b': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3649916507_b88a3d2082': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.02773011]], dtype=float32),
#  '3298199743_d8dd8f94a0': array([[0.        , 0.        , 5.207864  , ..., 0.        , 0.14562333,
#          0.390535  ]], dtype=float32),
#  '3326588088_172d1b2584': array([[3.8578033, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2439154641_bbf985aa57': array([[0.       , 1.3458363, 6.6531153, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2908466042_bf07cb52c7': array([[0.       , 0.       , 1.0885451, ..., 0.       , 2.071105 ,
#          0.1985023]], dtype=float32),
#  '3442540072_b22ca2410f': array([[1.1444099 , 0.        , 0.        , ..., 1.9119873 , 0.        ,
#          0.00850463]], dtype=float32),
#  '3325578605_afa7f662ec': array([[0.        , 0.        , 0.05256468, ..., 1.1175535 , 0.        ,
#          0.        ]], dtype=float32),
#  '2108799322_e25aa6e185': array([[1.5013146, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2223382277_9efa58ec45': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 7.501869]],
#        dtype=float32),
#  '2057160636_6e9cf3b5f0': array([[0.        , 0.18100709, 0.        , ..., 1.3099592 , 0.10018671,
#          0.        ]], dtype=float32),
#  '3569406219_f37ebf7b92': array([[0.11808491, 2.726409  , 0.        , ..., 0.        , 5.1174517 ,
#          0.        ]], dtype=float32),
#  '3523819210_99782628fc': array([[0.       , 0.       , 0.       , ..., 0.       , 0.4017979,
#          0.       ]], dtype=float32),
#  '1227655020_b11a1bb112': array([[0.       , 0.       , 2.7508698, ..., 0.       , 1.3441964,
#          0.       ]], dtype=float32),
#  '3500136982_bf7a85531e': array([[0.        , 0.38865098, 0.        , ..., 0.        , 4.7163463 ,
#          1.9052866 ]], dtype=float32),
#  '36422830_55c844bc2d': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2676184321_858eff416b': array([[0.        , 0.        , 0.62737983, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2255338013_566127590b': array([[0.        , 1.8578975 , 0.        , ..., 0.        , 2.9134347 ,
#          0.19537601]], dtype=float32),
#  '2949880800_ca9a1bb7e6': array([[0.       , 0.       , 0.       , ..., 0.       , 2.1577709,
#          3.1233923]], dtype=float32),
#  '3307978046_92fef4dfa9': array([[0.       , 0.       , 0.6278804, ..., 0.       , 1.8265612,
#          1.677943 ]], dtype=float32),
#  '2638981862_6b23833f37': array([[0.68817025, 1.1322336 , 0.        , ..., 0.        , 3.3239617 ,
#          0.        ]], dtype=float32),
#  '3227148358_f152303584': array([[0.        , 1.0702869 , 0.76301587, ..., 0.95591074, 0.7802333 ,
#          0.        ]], dtype=float32),
#  '1445123245_c7b9db0e0c': array([[0.       , 0.       , 4.932581 , ..., 0.       , 1.2919581,
#          0.       ]], dtype=float32),
#  '3014546644_d53db746ec': array([[0.        , 1.1701957 , 0.19848159, ..., 0.        , 3.4038918 ,
#          0.        ]], dtype=float32),
#  '2590207488_ddd89037ba': array([[0.       , 0.       , 2.3468714, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2578289278_01516d23a0': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3055716848_b253324afc': array([[0.        , 0.7505945 , 0.90094674, ..., 0.        , 0.        ,
#          2.1936479 ]], dtype=float32),
#  '1305564994_00513f9a5b': array([[0.       , 0.       , 3.873344 , ..., 0.       , 0.       ,
#          1.8092587]], dtype=float32),
#  '241347300_7c84ecf764': array([[0.3603959 , 0.        , 0.65810674, ..., 0.        , 1.238883  ,
#          0.        ]], dtype=float32),
#  '3513265399_a32e8cfd18': array([[2.3446486, 3.0894148, 2.339035 , ..., 0.       , 1.0463629,
#          0.4019575]], dtype=float32),
#  '2067362863_59577f9d4d': array([[0.44197518, 0.        , 0.709931  , ..., 0.        , 2.535557  ,
#          0.        ]], dtype=float32),
#  '1312020846_5abb4a9be2': array([[3.5874443, 0.       , 0.       , ..., 0.       , 1.3821702,
#          0.       ]], dtype=float32),
#  '3228793611_8f260ea500': array([[1.1521337 , 0.        , 1.7684366 , ..., 0.58476967, 1.3328472 ,
#          0.        ]], dtype=float32),
#  '2198494923_8159551be4': array([[0.        , 0.        , 0.6300175 , ..., 0.        , 0.02858585,
#          1.6759882 ]], dtype=float32),
#  '3359587274_4a2b140b84': array([[0.40401384, 0.34198344, 4.1170244 , ..., 0.7050306 , 0.        ,
#          0.        ]], dtype=float32),
#  '3484070900_3e76d7fd30': array([[5.4571376 , 0.6895499 , 7.043102  , ..., 1.6622632 , 1.9447048 ,
#          0.29862043]], dtype=float32),
#  '2832487464_2d30634e1e': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3017656907_c3b137e070': array([[0.9864311, 0.       , 2.7662024, ..., 0.       , 0.       ,
#          7.3172727]], dtype=float32),
#  '514431934_9cf78f05a9': array([[0.       , 0.       , 0.       , ..., 2.604872 , 1.1172757,
#          0.       ]], dtype=float32),
#  '2301867590_98c0ecb0cb': array([[0.        , 0.29713327, 4.664172  , ..., 0.        , 0.        ,
#          2.335886  ]], dtype=float32),
#  '3326376344_3306bf439e': array([[1.645248 , 0.       , 6.490572 , ..., 0.       , 3.1848276,
#          1.3562317]], dtype=float32),
#  '3540598210_972f0ff573': array([[0.48696458, 0.        , 0.57186866, ..., 0.        , 0.3752083 ,
#          1.4062216 ]], dtype=float32),
#  '3472364264_dbde5a8d0a': array([[0.        , 0.        , 0.        , ..., 0.        , 3.7634008 ,
#          0.26204303]], dtype=float32),
#  '3534668485_6887629ff0': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2525716531_e6dedee421': array([[0.       , 0.6276206, 2.710688 , ..., 0.       , 0.2851563,
#          0.       ]], dtype=float32),
#  '3415287719_3c776f370e': array([[0.        , 0.        , 0.19218531, ..., 0.        , 0.        ,
#          2.5996938 ]], dtype=float32),
#  '3355827928_c96c0c3e88': array([[0.       , 6.0858083, 2.8022637, ..., 0.       , 1.7100055,
#          0.       ]], dtype=float32),
#  '3726730085_2468ee9220': array([[0.        , 0.944993  , 0.89725214, ..., 0.        , 0.33003312,
#          0.02918112]], dtype=float32),
#  '72964268_d532bb8ec7': array([[0.       , 0.       , 0.       , ..., 0.       , 3.3192432,
#          1.4637899]], dtype=float32),
#  '498957941_f0eda42787': array([[0.       , 0.       , 1.842443 , ..., 0.       , 1.6745663,
#          0.3115394]], dtype=float32),
#  '3658427967_6e2e57458d': array([[0.       , 0.       , 0.       , ..., 0.       , 3.222975 ,
#          0.2200822]], dtype=float32),
#  '3054997030_797096dd12': array([[0.       , 0.       , 0.8767317, ..., 0.       , 0.       ,
#          1.9435418]], dtype=float32),
#  '2300168895_a9b83e16fc': array([[0.7505993, 0.       , 2.912201 , ..., 0.       , 0.6043275,
#          0.       ]], dtype=float32),
#  '3188044631_ca3a9cc737': array([[6.3616343, 6.139205 , 0.       , ..., 0.       , 2.6714554,
#          0.       ]], dtype=float32),
#  '3097196395_ec06075389': array([[0.       , 0.       , 0.6990694, ..., 0.       , 5.484781 ,
#          0.       ]], dtype=float32),
#  '2955985301_e4139bc772': array([[0.79138124, 0.        , 0.        , ..., 0.        , 0.53930867,
#          1.2486438 ]], dtype=float32),
#  '2899276965_a20b839cfd': array([[2.686255  , 2.8598285 , 4.451947  , ..., 0.        , 0.29701906,
#          2.8605812 ]], dtype=float32),
#  '3030824089_e5a840265e': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2381583688_a6dd0a7279': array([[0.9157115 , 0.        , 0.        , ..., 0.        , 1.1687936 ,
#          0.74180126]], dtype=float32),
#  '2705947033_5999147842': array([[1.4087186, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2640153227_57cf1a3d92': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '1433397131_8634fa6664': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3006093003_c211737232': array([[0.       , 3.5293772, 0.       , ..., 0.       , 0.       ,
#          3.5458498]], dtype=float32),
#  '2939475047_84585ea45c': array([[0.       , 1.5031837, 1.2089536, ..., 0.       , 0.       ,
#          6.7628574]], dtype=float32),
#  '368954110_821ccf005c': array([[4.937385 , 0.       , 3.2302694, ..., 0.       , 0.4801507,
#          0.       ]], dtype=float32),
#  '3042381160_ffe2b16808': array([[3.0069594 , 2.9637191 , 0.42337567, ..., 0.        , 0.        ,
#          1.7141092 ]], dtype=float32),
#  '172092464_d9eb4f4f2f': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          6.5136724]], dtype=float32),
#  '334768700_51c439b9ee': array([[5.0278673, 2.1077754, 0.       , ..., 0.       , 0.4821777,
#          0.       ]], dtype=float32),
#  '3429351964_531de1bf16': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2195887578_3ba2f29b48': array([[0.        , 0.        , 0.        , ..., 0.12444228, 1.6303184 ,
#          0.        ]], dtype=float32),
#  '3139837262_fe5ee7ccd9': array([[0.       , 0.       , 3.4229922, ..., 0.       , 0.       ,
#          2.94029  ]], dtype=float32),
#  '523985664_c866af4850': array([[2.7665133, 0.3841495, 0.       , ..., 0.       , 0.       ,
#          3.2294655]], dtype=float32),
#  '3593538248_dffa1a5ed4': array([[1.4924027, 5.6718893, 0.       , ..., 0.       , 3.3563821,
#          2.9127872]], dtype=float32),
#  '2862481071_86c65d46fa': array([[0.76117337, 0.        , 1.5187917 , ..., 0.        , 0.        ,
#          1.982115  ]], dtype=float32),
#  '482882719_165722082d': array([[0.29831615, 0.        , 0.        , ..., 0.        , 0.        ,
#          3.5854614 ]], dtype=float32),
#  '3256272547_5ae6c66293': array([[0.7296621, 0.       , 0.       , ..., 0.       , 2.177382 ,
#          3.492926 ]], dtype=float32),
#  '2955099064_1815b00825': array([[0.96326303, 1.3764175 , 0.        , ..., 0.        , 0.        ,
#          5.506377  ]], dtype=float32),
#  '2993167183_2bda95fa3d': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.230359]],
#        dtype=float32),
#  '1540631615_8b42c1b160': array([[0.72282016, 1.1604766 , 1.0703907 , ..., 0.        , 0.7231134 ,
#          0.        ]], dtype=float32),
#  '3694071771_ce760db4c7': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.8794804]], dtype=float32),
#  '1807169176_7f5226bf5a': array([[0.        , 0.        , 0.4094807 , ..., 0.96152914, 1.36903   ,
#          1.1912757 ]], dtype=float32),
#  '3285180819_a9712fd2bc': array([[0.       , 2.7052042, 0.       , ..., 0.       , 0.       ,
#          1.4014233]], dtype=float32),
#  '2100046085_69b59b6645': array([[0.        , 0.51559466, 0.        , ..., 1.6335065 , 5.131342  ,
#          0.        ]], dtype=float32),
#  '3597146852_3d000a5d5f': array([[1.26556   , 2.1117852 , 0.90308505, ..., 0.        , 0.        ,
#          0.0973022 ]], dtype=float32),
#  '3477672764_7f07657a26': array([[5.372512  , 0.50058126, 2.3867025 , ..., 0.        , 1.9339628 ,
#          0.48331153]], dtype=float32),
#  '2305437797_e6c3460190': array([[0.        , 1.0967726 , 0.96359754, ..., 0.        , 4.3644376 ,
#          0.        ]], dtype=float32),
#  '3287963317_186491ee78': array([[0.18761754, 0.        , 0.        , ..., 0.9237355 , 0.16444689,
#          0.        ]], dtype=float32),
#  '496971341_22782195f0': array([[0.       , 0.       , 4.911099 , ..., 1.3892641, 0.       ,
#          0.       ]], dtype=float32),
#  '3696246123_99d4d10140': array([[0.        , 2.5992568 , 1.0006531 , ..., 0.        , 0.        ,
#          0.69820774]], dtype=float32),
#  '1798209205_77dbf525b0': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3193511842_82549c21fb': array([[2.5266705, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.8147118]], dtype=float32),
#  '3164347907_2813f8ff0b': array([[5.276259 , 1.5329758, 2.569763 , ..., 0.       , 0.       ,
#          2.5603366]], dtype=float32),
#  '3515451715_ac5ac04efa': array([[0.22020108, 0.        , 0.        , ..., 0.        , 1.0265834 ,
#          0.        ]], dtype=float32),
#  '1926129518_4350f4f552': array([[1.864961  , 2.989968  , 0.19833648, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '3484832904_08619300d9': array([[0.        , 2.7318337 , 1.8611938 , ..., 0.        , 0.        ,
#          0.33128506]], dtype=float32),
#  '2570365455_41cc9a7d2b': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.18446329]], dtype=float32),
#  '448252603_7d928c900e': array([[0.        , 0.12003902, 0.        , ..., 0.        , 1.9278784 ,
#          0.74167687]], dtype=float32),
#  '2453990033_df53f0d8c8': array([[0.        , 3.5643585 , 0.83643794, ..., 0.        , 2.2242548 ,
#          1.9151261 ]], dtype=float32),
#  '2344875609_8e172d682b': array([[0.       , 0.       , 0.       , ..., 0.       , 1.9133558,
#          2.8302221]], dtype=float32),
#  '3471117376_40585c3fd1': array([[0.       , 6.857179 , 0.       , ..., 0.       , 1.0758461,
#          0.       ]], dtype=float32),
#  '2337809114_899ba61330': array([[0.       , 1.5835872, 0.       , ..., 0.       , 0.       ,
#          1.9387667]], dtype=float32),
#  '3502459991_fdec2da131': array([[0.6773935 , 0.        , 2.663096  , ..., 0.        , 0.        ,
#          0.20880291]], dtype=float32),
#  '2124040721_bffc0a091a': array([[0.        , 0.        , 0.81927264, ..., 0.1738314 , 0.        ,
#          0.6292127 ]], dtype=float32),
#  '2909875716_25c8652614': array([[0.        , 0.01870841, 3.2155824 , ..., 0.01463956, 0.        ,
#          0.        ]], dtype=float32),
#  '229978782_3c690f5a0e': array([[0.        , 0.65099895, 2.3975759 , ..., 0.        , 0.        ,
#          1.848798  ]], dtype=float32),
#  '3480052428_c034b98a08': array([[0.05644453, 0.        , 0.        , ..., 0.        , 2.2566762 ,
#          0.        ]], dtype=float32),
#  '3317073508_7e13565c1b': array([[0.        , 3.4748929 , 0.        , ..., 0.        , 1.6813893 ,
#          0.22794393]], dtype=float32),
#  '2450486758_a66fd296ea': array([[5.538168 , 3.910247 , 0.7402126, ..., 0.       , 1.7947791,
#          1.679148 ]], dtype=float32),
#  '3737492755_bcfb800ed1': array([[0.       , 0.       , 0.       , ..., 0.       , 2.9323447,
#          0.       ]], dtype=float32),
#  '297169473_d3974e0275': array([[2.5921144, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2196050115_e236d91f52': array([[2.8417234 , 0.35761118, 1.7936364 , ..., 0.        , 0.        ,
#          0.3371426 ]], dtype=float32),
#  '3249597269_935e0a375a': array([[1.8747376 , 0.        , 4.273926  , ..., 0.59586304, 1.0324697 ,
#          0.        ]], dtype=float32),
#  '2744321686_8811d8428c': array([[0.23183823, 0.        , 0.24240637, ..., 0.        , 1.7399254 ,
#          0.        ]], dtype=float32),
#  '3685372942_6ae935b34e': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.1437004]], dtype=float32),
#  '2148695079_9ae6a9b1c7': array([[1.270985 , 0.       , 2.8988314, ..., 2.9972596, 0.       ,
#          0.       ]], dtype=float32),
#  '3191805046_77c334b506': array([[0.        , 0.        , 0.        , ..., 0.        , 0.71359843,
#          0.19102603]], dtype=float32),
#  '2354792215_eef2bdc753': array([[0.        , 0.        , 0.77712363, ..., 0.        , 4.3494616 ,
#          3.5323405 ]], dtype=float32),
#  '3085973779_29f44fbdaa': array([[3.8949423 , 0.        , 0.65981597, ..., 0.        , 0.        ,
#          4.211859  ]], dtype=float32),
#  '2885111681_dc328ecfff': array([[0.        , 1.9710476 , 0.        , ..., 0.        , 2.3407478 ,
#          0.66535556]], dtype=float32),
#  '2543247940_083f1b7969': array([[0.06772834, 0.        , 4.2896814 , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2650485780_29d89268d7': array([[2.706016  , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.33314395]], dtype=float32),
#  '1482960952_95f2d419cb': array([[0.       , 0.       , 0.       , ..., 0.       , 6.1883492,
#          0.       ]], dtype=float32),
#  '2704362232_7d84503433': array([[2.1431706, 0.       , 1.5252614, ..., 0.       , 3.7986941,
#          0.       ]], dtype=float32),
#  '2629027962_9cc3b46527': array([[0.42339534, 0.        , 0.        , ..., 0.        , 0.18170868,
#          0.04031801]], dtype=float32),
#  '3720366614_dfa8fe1088': array([[1.5608747 , 0.        , 0.        , ..., 0.46290317, 1.024267  ,
#          0.        ]], dtype=float32),
#  '3600909823_ce72c26e66': array([[1.3197906, 0.       , 0.       , ..., 0.583131 , 0.       ,
#          3.771024 ]], dtype=float32),
#  '2695085632_10c4e6ea78': array([[4.2621975, 3.041343 , 0.       , ..., 0.       , 0.7055547,
#          2.1378076]], dtype=float32),
#  '3626642428_3396568c3c': array([[0.       , 2.7991996, 0.       , ..., 0.       , 3.5008938,
#          0.       ]], dtype=float32),
#  '241346709_23204cc2bc': array([[0.        , 0.11552513, 0.        , ..., 0.        , 0.        ,
#          1.4480388 ]], dtype=float32),
#  '1363924449_487f0733df': array([[0.        , 0.        , 0.13890925, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2973638173_0dc21fd443': array([[0.        , 0.82747805, 4.7877126 , ..., 0.        , 0.49279177,
#          0.        ]], dtype=float32),
#  '3248752274_96740ed073': array([[0.        , 0.        , 0.44769448, ..., 0.        , 4.7339244 ,
#          0.        ]], dtype=float32),
#  '2715289538_d77c8d0a85': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.3038344]], dtype=float32),
#  '3544573946_e03aebbfde': array([[0.5876263 , 0.        , 0.25878003, ..., 0.        , 0.        ,
#          1.9846799 ]], dtype=float32),
#  '3249891130_b241591e89': array([[0.        , 0.7806761 , 0.        , ..., 0.        , 0.52381486,
#          2.5002344 ]], dtype=float32),
#  '2677614492_792023b928': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '1263801010_5c74bf1715': array([[0.       , 0.       , 0.       , ..., 0.       , 1.321489 ,
#          3.0581436]], dtype=float32),
#  '2135502491_a15c6b5eae': array([[0.        , 0.        , 1.1274507 , ..., 0.        , 0.13789198,
#          0.        ]], dtype=float32),
#  '2332540384_4cf26406a9': array([[2.6187801, 1.0069059, 1.9355347, ..., 0.       , 0.       ,
#          1.0221795]], dtype=float32),
#  '3556598205_86c180769d': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.726967]],
#        dtype=float32),
#  '2991993027_36ac04e9a0': array([[0.      , 0.      , 0.      , ..., 0.      , 5.390366, 3.425758]],
#        dtype=float32),
#  '217838128_1f0a84ddc1': array([[0.        , 4.0010576 , 3.2384071 , ..., 0.        , 0.20700565,
#          0.        ]], dtype=float32),
#  '3432637363_3ba357e2da': array([[4.526197 , 0.       , 0.       , ..., 2.5185978, 3.3779323,
#          0.       ]], dtype=float32),
#  '143688895_e837c3bc76': array([[0.3073622, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3724487641_d2096f10e5': array([[0.       , 0.       , 0.       , ..., 0.       , 1.4783995,
#          3.5440948]], dtype=float32),
#  '2257631407_1529b9db39': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2735158990_56ff6bf9b0': array([[1.2845488 , 1.7253    , 0.62839097, ..., 0.        , 1.8671136 ,
#          0.        ]], dtype=float32),
#  '1858963639_4588cd4be9': array([[0.       , 2.2322855, 0.       , ..., 0.       , 0.       ,
#          1.9052851]], dtype=float32),
#  '3383388869_a14552e551': array([[0.       , 2.418345 , 2.6051707, ..., 2.827367 , 0.8287092,
#          0.       ]], dtype=float32),
#  '2596876977_b61ee7ee78': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.1105924]], dtype=float32),
#  '3565021218_d2bc1aa644': array([[0.       , 0.       , 0.       , ..., 0.       , 1.4867766,
#          0.       ]], dtype=float32),
#  '3296226598_1c892c4351': array([[1.4248754, 0.       , 0.       , ..., 0.       , 1.5742252,
#          1.2131102]], dtype=float32),
#  '3424934891_69f18da66e': array([[0.       , 0.       , 2.8856797, ..., 0.       , 0.       ,
#          0.6433668]], dtype=float32),
#  '3258396041_69717247f7': array([[0.        , 0.        , 0.        , ..., 0.        , 3.6073258 ,
#          0.28642878]], dtype=float32),
#  '1020651753_06077ec457': array([[0.       , 0.       , 1.1434922, ..., 0.       , 0.2015797,
#          3.2388356]], dtype=float32),
#  '3427301653_4ff0d6fd93': array([[1.1856447, 0.       , 1.6025254, ..., 0.       , 0.       ,
#          2.0933688]], dtype=float32),
#  '3229730008_63f8ca2de2': array([[3.7217317, 0.       , 2.291841 , ..., 0.       , 0.6017964,
#          2.6176782]], dtype=float32),
#  '607339469_af851c4119': array([[0.04558808, 4.2678204 , 0.70695543, ..., 0.        , 1.9619758 ,
#          2.6297822 ]], dtype=float32),
#  '458213442_12c59e61a0': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2802337003_56e555cd30': array([[0.47381955, 0.        , 1.1772565 , ..., 0.        , 0.        ,
#          0.91873366]], dtype=float32),
#  '3524519277_bd0c3e7382': array([[0.        , 0.        , 0.05549449, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2094543127_46d2f1fedf': array([[1.862347 , 3.6774528, 2.9274821, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3139895886_5a6d495b13': array([[0.        , 0.        , 0.        , ..., 0.90982157, 0.        ,
#          0.        ]], dtype=float32),
#  '3154813159_58a195236d': array([[1.0425961 , 0.12476942, 0.        , ..., 0.        , 0.65804577,
#          0.        ]], dtype=float32),
#  '3398276602_c7d106c34f': array([[0.09748226, 0.        , 0.        , ..., 0.        , 2.2578123 ,
#          3.4074595 ]], dtype=float32),
#  '3725814794_30db172f67': array([[0.        , 0.        , 0.67484015, ..., 0.        , 0.        ,
#          2.013196  ]], dtype=float32),
#  '3240090389_97a8c5d386': array([[0.6110642, 0.       , 2.2332458, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3518126579_e70e0cbb2b': array([[0.22648597, 0.        , 0.8603391 , ..., 0.        , 0.9862427 ,
#          0.        ]], dtype=float32),
#  '2638369467_8fc251595b': array([[1.9432834 , 0.        , 0.15478012, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '782401952_5bc5d3413a': array([[0.5453277 , 0.        , 0.04854673, ..., 0.        , 0.7202402 ,
#          2.1256819 ]], dtype=float32),
#  '3451345621_fe470d4cf8': array([[0.       , 0.2625656, 0.       , ..., 0.       , 1.5024242,
#          1.2943604]], dtype=float32),
#  '211295363_49010ca38d': array([[0.       , 0.       , 1.0362688, ..., 0.       , 1.426095 ,
#          0.       ]], dtype=float32),
#  '3271252073_0a1b9525fc': array([[0.47322142, 0.        , 0.        , ..., 0.        , 0.        ,
#          2.0612319 ]], dtype=float32),
#  '3163273640_8d3ef22eaf': array([[0.       , 0.       , 0.       , ..., 0.       , 2.2492383,
#          0.       ]], dtype=float32),
#  '1307635496_94442dc21a': array([[1.1724403 , 0.        , 1.3351352 , ..., 0.        , 0.47886539,
#          1.548543  ]], dtype=float32),
#  '3405113041_4b72c24801': array([[0.        , 4.9611487 , 0.05098188, ..., 1.0305486 , 1.1002351 ,
#          0.        ]], dtype=float32),
#  '2393911878_68afe6e6c1': array([[0.47390512, 0.        , 5.1416135 , ..., 0.        , 0.8699037 ,
#          1.7192602 ]], dtype=float32),
#  '264859622_f3a00ab409': array([[0.53158003, 0.01265579, 0.        , ..., 0.        , 2.075716  ,
#          0.        ]], dtype=float32),
#  '847782643_57248bbdab': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '1800601130_1c0f248d12': array([[0.       , 0.       , 1.7827178, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2632111399_b3c1630f8e': array([[0.        , 1.7855735 , 0.26875746, ..., 0.        , 0.        ,
#          4.9582305 ]], dtype=float32),
#  '3610687607_895fdc94bd': array([[0.38943034, 0.33620232, 1.4128524 , ..., 0.        , 3.1100574 ,
#          0.        ]], dtype=float32),
#  '3422458549_f3f3878dbf': array([[1.5651019 , 0.15413707, 0.        , ..., 0.        , 0.        ,
#          3.9693115 ]], dtype=float32),
#  '3107513635_fe8a21f148': array([[0.781249  , 0.        , 0.        , ..., 0.        , 0.66736585,
#          0.        ]], dtype=float32),
#  '2252635585_b48b3485b0': array([[0.       , 0.       , 1.559082 , ..., 4.0615845, 1.8564091,
#          0.       ]], dtype=float32),
#  '3155451946_c0862c70cb': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          4.0016055]], dtype=float32),
#  '2999735171_87ca43c225': array([[4.2099347, 0.       , 0.       , ..., 0.       , 3.0995338,
#          0.       ]], dtype=float32),
#  '772403830_08b72c7da9': array([[0.        , 0.        , 0.42694837, ..., 0.        , 0.        ,
#          0.6378388 ]], dtype=float32),
#  '2914737181_0c8e052da8': array([[0.6685029, 0.       , 2.880381 , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '1352410176_af6b139734': array([[0.89950854, 1.2985166 , 0.6001243 , ..., 0.7631706 , 3.370552  ,
#          0.9968426 ]], dtype=float32),
#  '3065560742_f6e266ccd9': array([[1.9238006, 0.3717821, 0.       , ..., 0.       , 3.3639283,
#          3.6544607]], dtype=float32),
#  '3578914491_36019ba703': array([[0.       , 0.       , 0.       , ..., 0.       , 1.6437678,
#          0.       ]], dtype=float32),
#  '1562392511_522a26063b': array([[1.5703559, 0.       , 0.       , ..., 0.       , 2.0263076,
#          1.8334258]], dtype=float32),
#  '3542771548_fcb8fa0cba': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.0150051]], dtype=float32),
#  '310715139_7f05468042': array([[0.       , 0.       , 0.       , ..., 4.5619574, 0.       ,
#          0.       ]], dtype=float32),
#  '3349528565_0bc013b70a': array([[2.2760816, 0.       , 0.       , ..., 0.       , 1.4115256,
#          0.       ]], dtype=float32),
#  '3323419265_7fefaa9d5d': array([[0.08730203, 0.30536318, 0.        , ..., 0.        , 0.        ,
#          1.7489634 ]], dtype=float32),
#  '3427233064_6af01bfc5c': array([[0.       , 2.3881054, 0.       , ..., 0.       , 0.9471594,
#          0.       ]], dtype=float32),
#  '2893515010_4a3d9dcc67': array([[0.       , 0.       , 2.812583 , ..., 0.       , 0.       ,
#          6.5801992]], dtype=float32),
#  '489134459_1b3f46fc03': array([[0.       , 0.       , 0.       , ..., 0.       , 1.9879582,
#          2.4391115]], dtype=float32),
#  '2511762757_bd0ab0a017': array([[2.3942697, 4.4233537, 0.5279294, ..., 0.       , 3.5119882,
#          1.0987012]], dtype=float32),
#  '1478294229_7e1c822fea': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.1470156]], dtype=float32),
#  '3111482098_11c0f4f309': array([[0.        , 0.        , 0.        , ..., 0.20447761, 0.        ,
#          0.        ]], dtype=float32),
#  '757332692_6866ae545c': array([[0.2401754, 1.8122582, 3.791377 , ..., 0.       , 0.       ,
#          1.0211757]], dtype=float32),
#  '271660510_dd4ba34b35': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2076865206_53918c820c': array([[0.       , 1.6806226, 0.       , ..., 0.1842624, 1.4930944,
#          0.       ]], dtype=float32),
#  '3549583146_3e8bb2f7e9': array([[1.5848761 , 0.0386737 , 0.        , ..., 0.        , 0.11116895,
#          0.        ]], dtype=float32),
#  '3563668905_689ed479c5': array([[1.6044283, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.7287159]], dtype=float32),
#  '2061397486_53a61e17c5': array([[0.12270153, 0.        , 0.        , ..., 0.        , 3.0310636 ,
#          0.24453023]], dtype=float32),
#  '3352791995_8db4979aca': array([[1.5261005, 0.5873442, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3051341320_1d0166e775': array([[1.1267543 , 6.482439  , 0.56611764, ..., 0.        , 0.6787486 ,
#          0.        ]], dtype=float32),
#  '3524612244_64f00afec5': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3304712466_18cbdb85fe': array([[1.9820203, 0.       , 0.       , ..., 0.       , 5.926493 ,
#          2.8200767]], dtype=float32),
#  '2399219552_bbba0a9a59': array([[0.       , 3.4259863, 0.       , ..., 0.       , 2.833136 ,
#          0.3291291]], dtype=float32),
#  '3582465732_78f77f34ae': array([[1.9334375, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '990890291_afc72be141': array([[0.       , 0.       , 0.       , ..., 0.       , 2.6436098,
#          4.0546403]], dtype=float32),
#  '2994107810_af56326389': array([[0.       , 1.1560662, 0.       , ..., 0.       , 0.       ,
#          3.6591885]], dtype=float32),
#  '2788628994_61123c03d2': array([[1.2516291, 0.569011 , 0.       , ..., 0.       , 3.0865326,
#          0.       ]], dtype=float32),
#  '3364796213_b8948913b5': array([[1.221653, 0.      , 0.      , ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '2676648667_cb055b4fc6': array([[1.3102719, 0.       , 0.       , ..., 0.       , 0.       ,
#          1.488509 ]], dtype=float32),
#  '2422482455_b98d9c2120': array([[0.30096346, 2.908452  , 1.782218  , ..., 0.        , 2.329285  ,
#          0.        ]], dtype=float32),
#  '241346402_5c070a0c6d': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '475313618_bdb2f72be5': array([[2.9202585 , 3.5298316 , 0.        , ..., 0.        , 0.70107085,
#          1.1643    ]], dtype=float32),
#  '3439331800_e71e1d808f': array([[0.       , 0.       , 1.8915503, ..., 0.       , 0.       ,
#          5.4023275]], dtype=float32),
#  '3562470436_6e193643ce': array([[0.       , 0.       , 3.5168567, ..., 0.       , 1.0622607,
#          0.       ]], dtype=float32),
#  '2546667441_bbe87a6285': array([[0.       , 0.       , 0.       , ..., 0.       , 1.3447642,
#          0.       ]], dtype=float32),
#  '2358561039_e215a8d6cd': array([[3.7171164, 0.       , 0.       , ..., 0.       , 4.3601565,
#          0.       ]], dtype=float32),
#  '140377584_12bdbdf2f8': array([[0.       , 0.       , 1.4254006, ..., 0.       , 1.95806  ,
#          0.       ]], dtype=float32),
#  '2466420387_86fe77c966': array([[0.26593125, 0.18157402, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2769731772_18c44c18e2': array([[2.139512, 0.      , 0.      , ..., 0.      , 0.      , 2.036544]],
#        dtype=float32),
#  '2375924666_fee50f1cba': array([[0.       , 0.       , 1.2172322, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2221818690_9003756d33': array([[0.       , 0.       , 0.9298805, ..., 0.       , 0.       ,
#          0.3071241]], dtype=float32),
#  '2968182121_b3b491df85': array([[0.        , 0.        , 1.7992239 , ..., 0.        , 0.        ,
#          0.58679837]], dtype=float32),
#  '2063277300_f7ff476914': array([[0.        , 3.0695138 , 0.        , ..., 0.        , 0.04466504,
#          1.4387076 ]], dtype=float32),
#  '3141293960_74459f0a24': array([[3.0812526 , 0.59262806, 0.        , ..., 0.        , 0.        ,
#          4.481554  ]], dtype=float32),
#  '1836335410_de8313a64e': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '468608014_09fd20eb9b': array([[0.       , 2.0131106, 5.4219446, ..., 3.2568216, 0.       ,
#          0.       ]], dtype=float32),
#  '1580671272_3e99d94305': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '535529555_583d89b7f2': array([[0.       , 0.       , 3.0222259, ..., 0.       , 1.2029933,
#          0.       ]], dtype=float32),
#  '374103776_0de490c1b0': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.3138444]], dtype=float32),
#  '3240094420_a9eea11d39': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          0.6859529]], dtype=float32),
#  '2279496715_8ef3ee6edb': array([[2.7094526, 2.8086066, 0.       , ..., 0.       , 0.       ,
#          1.97649  ]], dtype=float32),
#  '2232518012_8cb0bbc43b': array([[0.97409403, 1.959007  , 1.4922711 , ..., 2.215371  , 2.4768662 ,
#          0.        ]], dtype=float32),
#  '816084977_21c1811c9a': array([[0.71015674, 1.2014632 , 0.6981731 , ..., 0.        , 3.5750337 ,
#          0.38172045]], dtype=float32),
#  '2573667207_a1bf49befc': array([[0.       , 0.3358935, 0.       , ..., 0.3053565, 3.7256005,
#          1.7343414]], dtype=float32),
#  '1799188614_b5189728ba': array([[0.        , 0.64668465, 0.        , ..., 0.        , 2.3899972 ,
#          2.4359534 ]], dtype=float32),
#  '2552949275_b8cdc450cc': array([[0.        , 0.7258339 , 1.8931049 , ..., 0.        , 0.08979905,
#          0.        ]], dtype=float32),
#  '2097420505_439f63c863': array([[1.99137  , 0.       , 0.       , ..., 0.       , 1.4674423,
#          0.       ]], dtype=float32),
#  '1052358063_eae6744153': array([[0.15820172, 0.        , 0.        , ..., 0.        , 0.0226483 ,
#          1.3026177 ]], dtype=float32),
#  '3430100177_5864bf1e73': array([[1.0061729, 0.       , 0.       , ..., 0.       , 1.8363283,
#          2.0093765]], dtype=float32),
#  '3317333893_9d0faa8d30': array([[2.7609487, 0.       , 2.0313122, ..., 0.       , 3.5333989,
#          0.       ]], dtype=float32),
#  '2814028429_561a215259': array([[1.2160443, 0.       , 0.       , ..., 0.       , 0.       ,
#          6.268918 ]], dtype=float32),
#  '3212085754_35fdc9ccaa': array([[1.6518612, 4.8054557, 0.       , ..., 0.       , 0.19187  ,
#          0.9617994]], dtype=float32),
#  '3134586018_ae03ba20a0': array([[1.0101275 , 0.38561484, 0.        , ..., 0.        , 0.        ,
#          2.2919707 ]], dtype=float32),
#  '2913207978_9e9624e249': array([[0.       , 0.       , 0.       , ..., 0.       , 0.9224784,
#          1.9523056]], dtype=float32),
#  '262439544_e71cd26b24': array([[0.60084003, 0.        , 1.7643776 , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '3712742641_641282803e': array([[0.        , 1.6592246 , 0.        , ..., 0.19146359, 0.8475882 ,
#          0.        ]], dtype=float32),
#  '244774022_a12c07afdb': array([[0.        , 0.        , 3.7256289 , ..., 0.        , 0.        ,
#          0.35150573]], dtype=float32),
#  '2447035752_415f4bb152': array([[0.       , 0.       , 0.       , ..., 0.       , 2.5500267,
#          0.       ]], dtype=float32),
#  '3474958471_9106beb07f': array([[2.2571921 , 0.        , 1.799883  , ..., 0.        , 0.        ,
#          0.99741924]], dtype=float32),
#  '461505235_590102a5bf': array([[0.      , 0.      , 0.      , ..., 0.      , 4.531642, 0.      ]],
#        dtype=float32),
#  '2522297487_57edf117f7': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2857609295_16aaa85293': array([[0.5823786, 0.       , 1.5908016, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3512033659_7e8a0c2ffa': array([[0.08514827, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '613900608_2e49415772': array([[0.8386031, 0.       , 0.       , ..., 0.       , 1.3934946,
#          1.563009 ]], dtype=float32),
#  '406901451_7eafd7568a': array([[1.6299107, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3155501473_510f9c9f6b': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3003011417_79b49ff384': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.4982746]], dtype=float32),
#  '1448511770_1a4a9c453b': array([[0.20143422, 3.3552368 , 1.6107297 , ..., 0.        , 0.25664413,
#          0.        ]], dtype=float32),
#  '256439287_990ac4a761': array([[1.2045946 , 2.4139042 , 0.        , ..., 0.        , 0.09534016,
#          0.6748974 ]], dtype=float32),
#  '3549614763_42f34f3d1e': array([[0.36655903, 1.7305748 , 0.        , ..., 0.        , 0.        ,
#          0.12056953]], dtype=float32),
#  '2998024845_1529c11694': array([[0.        , 0.28866148, 0.        , ..., 0.        , 0.        ,
#          8.616794  ]], dtype=float32),
#  '2404692474_37da774368': array([[0.1640889, 0.       , 0.       , ..., 0.       , 1.9762409,
#          0.8649119]], dtype=float32),
#  '2689491604_d8760f57b4': array([[0.70028186, 0.        , 0.1668992 , ..., 0.        , 0.        ,
#          1.1797472 ]], dtype=float32),
#  '374828031_9d087da5cf': array([[0.       , 0.       , 0.       , ..., 0.       , 0.6007115,
#          0.6858827]], dtype=float32),
#  '3472703856_568d9778b5': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 2.354936]],
#        dtype=float32),
#  '3737539561_d1dc161040': array([[1.7572191, 0.       , 0.       , ..., 0.       , 0.       ,
#          1.0759382]], dtype=float32),
#  '496129405_b9feeda1ab': array([[0.       , 0.       , 3.6975117, ..., 0.       , 3.4937952,
#          0.       ]], dtype=float32),
#  '1225443522_1633e7121f': array([[2.9149194, 0.       , 0.       , ..., 0.       , 1.8636923,
#          0.       ]], dtype=float32),
#  '3213622536_31da7f6682': array([[0.93119526, 3.6228945 , 0.        , ..., 0.        , 0.        ,
#          0.27838865]], dtype=float32),
#  '242064301_a9d12f1754': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.6877193]], dtype=float32),
#  '3607489370_92683861f7': array([[2.245701 , 0.       , 0.       , ..., 0.       , 0.       ,
#          6.5840087]], dtype=float32),
#  '3495453699_1c9faedf3c': array([[0.57748896, 0.32321578, 1.4932065 , ..., 0.        , 3.437823  ,
#          0.        ]], dtype=float32),
#  '2470519275_65725fd38d': array([[0.72601265, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2882589788_cb0b407a8d': array([[0.9098327, 0.       , 0.       , ..., 0.       , 0.       ,
#          1.7047112]], dtype=float32),
#  '561417861_8e25d0c0e8': array([[0.7792517 , 0.        , 1.6422082 , ..., 0.        , 0.76287884,
#          0.        ]], dtype=float32),
#  '3567214106_6ece483f8b': array([[0.1689859, 0.       , 3.1154385, ..., 0.       , 3.0216978,
#          0.       ]], dtype=float32),
#  '3708743823_3e3e0554d1': array([[3.529151 , 0.       , 3.5402136, ..., 0.       , 0.       ,
#          2.1010156]], dtype=float32),
#  '2140305708_591d10b54d': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.9192419]], dtype=float32),
#  '527946505_a51ade1578': array([[0.        , 0.        , 1.0358263 , ..., 0.        , 0.02732745,
#          0.        ]], dtype=float32),
#  '186890605_ddff5b694e': array([[0.       , 3.9229286, 1.7497306, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '989754491_7e53fb4586': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.1310532]], dtype=float32),
#  '3170897628_3054087f8c': array([[0.9242716, 0.       , 3.3939867, ..., 0.       , 2.2705786,
#          0.950274 ]], dtype=float32),
#  '2751694538_fffa3d307d': array([[3.581934 , 0.       , 1.9075422, ..., 0.       , 0.       ,
#          0.8216728]], dtype=float32),
#  '2562483332_eb791a3ce5': array([[0.       , 0.       , 0.       , ..., 0.       , 0.8754428,
#          0.       ]], dtype=float32),
#  '121800200_bef08fae5f': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '496555371_3e1ee0d97d': array([[0.        , 0.        , 0.69359374, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '3415311628_c220a65762': array([[0.       , 0.       , 2.1594908, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '485245061_5a5de43e20': array([[0.       , 0.       , 3.7118406, ..., 0.       , 1.5515814,
#          1.0616647]], dtype=float32),
#  '3486154327_8be7c78569': array([[0.        , 2.1374946 , 0.43016195, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '3197981073_3156963446': array([[1.7543141, 0.       , 2.2502146, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2986280913_13fb2d472e': array([[1.3145729, 0.       , 2.3513892, ..., 0.       , 1.9651403,
#          1.4640567]], dtype=float32),
#  '2911658792_6a6ef07e3a': array([[0.        , 0.9401194 , 0.2687153 , ..., 0.38087082, 0.        ,
#          0.        ]], dtype=float32),
#  '3007214949_a4b027f8a3': array([[4.4900694, 0.3179688, 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2061944672_0383e65c8a': array([[0.821     , 3.3056352 , 0.15721947, ..., 2.0688465 , 2.0865986 ,
#          0.        ]], dtype=float32),
#  '311146855_0b65fdb169': array([[0.       , 0.       , 0.       , ..., 0.       , 5.39544  ,
#          1.2963184]], dtype=float32),
#  '1468429623_f001988691': array([[1.426013  , 0.        , 2.706582  , ..., 0.        , 0.        ,
#          0.57383525]], dtype=float32),
#  '3421706363_a3e22a4908': array([[2.5981612, 1.265033 , 0.       , ..., 0.       , 0.6738194,
#          2.6961725]], dtype=float32),
#  '2467853482_17009933e8': array([[2.6036038 , 0.        , 0.38419774, ..., 0.        , 0.        ,
#          3.4415238 ]], dtype=float32),
#  '510791586_3913ade6a7': array([[0.      , 0.      , 0.      , ..., 0.      , 3.430235, 0.      ]],
#        dtype=float32),
#  '2600867924_cd502fc911': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.37188601]], dtype=float32),
#  '2799871904_3b3125518a': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.1576446]], dtype=float32),
#  '3554210976_fbd0ef33a3': array([[0.       , 0.       , 2.2846081, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2604305843_ebe3e8a328': array([[3.7085443, 0.8759606, 0.       , ..., 4.400525 , 0.       ,
#          0.       ]], dtype=float32),
#  '452363869_cad37e609f': array([[2.087377  , 0.19315538, 2.029508  , ..., 0.        , 3.6174383 ,
#          0.        ]], dtype=float32),
#  '1355450069_c0675b0706': array([[0.       , 0.       , 0.       , ..., 0.       , 0.7675169,
#          0.       ]], dtype=float32),
#  '2113530024_5bc6a90e42': array([[0.        , 0.        , 0.25966275, ..., 0.        , 0.        ,
#          2.0357358 ]], dtype=float32),
#  '2308271254_27fb466eb4': array([[2.1452107, 0.       , 1.5557635, ..., 0.       , 1.8474844,
#          0.       ]], dtype=float32),
#  '2438085746_588dce8724': array([[0.7767559 , 0.        , 0.62136173, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '3401437960_7da856e004': array([[0.4513662, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2696394827_7342ced36f': array([[0.       , 0.       , 2.8474903, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
# ...
#  '3132832452_c354c6396c': array([[0.08196157, 0.        , 0.        , ..., 0.        , 1.4534488 ,
#          0.45393997]], dtype=float32),
#  '2502354602_f4d6dcf42d': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.4926233]], dtype=float32),
#  '2371809188_b805497cba': array([[0.        , 0.        , 0.        , ..., 0.        , 1.0112008 ,
#          0.37486076]], dtype=float32),
#  '3218861747_5c5c547b66': array([[1.868573, 0.      , 0.      , ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '3301021288_95935b7a74': array([[2.6361003 , 0.91573966, 0.        , ..., 0.        , 1.4589827 ,
#          0.        ]], dtype=float32),
#  '3656151153_b4ed5d94c4': array([[0.        , 0.26586783, 0.        , ..., 0.        , 1.8670514 ,
#          0.        ]], dtype=float32),
#  '2944362789_aebbc22db4': array([[0.5207301, 0.       , 2.3125825, ..., 1.7462058, 0.       ,
#          0.       ]], dtype=float32),
#  '2759813381_73303113d9': array([[0.        , 0.06130469, 2.810226  , ..., 0.        , 2.450041  ,
#          0.        ]], dtype=float32),
#  '2883907436_82bf4a36b8': array([[0.       , 0.       , 1.0347629, ..., 0.       , 3.212111 ,
#          0.       ]], dtype=float32),
#  '3553374585_25b1bd6970': array([[0.      , 0.      , 0.      , ..., 0.      , 2.392838, 0.      ]],
#        dtype=float32),
#  '394563330_68b566368c': array([[0.16595182, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '3656030945_fa003bd696': array([[2.376068 , 0.4862402, 1.0565383, ..., 0.       , 1.7788885,
#          0.6934136]], dtype=float32),
#  '3686078365_9e655e238f': array([[0.        , 0.        , 0.        , ..., 0.        , 0.24560416,
#          1.2024693 ]], dtype=float32),
#  '1280147517_98767ca3b3': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2484190118_e89363c465': array([[3.3424354, 3.6780543, 0.7322823, ..., 0.       , 3.9595284,
#          0.5843152]], dtype=float32),
#  '2333584535_1eaf9baf3e': array([[0.        , 0.        , 0.        , ..., 0.        , 0.13860539,
#          0.        ]], dtype=float32),
#  '3127142756_bf0bfcb571': array([[0.        , 0.        , 3.279663  , ..., 0.31552666, 2.6207216 ,
#          0.        ]], dtype=float32),
#  '2510029990_7014f907cb': array([[0.        , 0.        , 0.        , ..., 0.24832588, 0.        ,
#          0.        ]], dtype=float32),
#  '1403414927_5f80281505': array([[2.4747412, 3.0091307, 0.       , ..., 0.       , 4.6698337,
#          0.       ]], dtype=float32),
#  '2218907190_5f43bf5e4d': array([[0.21245256, 0.        , 1.4496887 , ..., 0.        , 2.5698667 ,
#          0.        ]], dtype=float32),
#  '3413019648_e787f0cb88': array([[3.304595  , 0.        , 1.193042  , ..., 0.        , 0.        ,
#          0.01972485]], dtype=float32),
#  '1404832008_68e432665b': array([[1.390588 , 0.       , 3.7156801, ..., 0.       , 1.2545067,
#          0.       ]], dtype=float32),
#  '488196964_49159f11fd': array([[0.        , 6.5498357 , 1.7800405 , ..., 0.        , 3.6723046 ,
#          0.55330044]], dtype=float32),
#  '3354075558_3b67eaa502': array([[0.       , 0.       , 0.       , ..., 0.       , 3.8022473,
#          0.       ]], dtype=float32),
#  '691770760_48ce80a674': array([[0.        , 0.        , 0.23748496, ..., 0.        , 0.66857016,
#          0.        ]], dtype=float32),
#  '2623930900_b9df917b82': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '121971540_0a986ee176': array([[0.51160526, 2.9731328 , 0.37745363, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '3596959859_a7cb1e194b': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3423225860_16e26eef74': array([[0.      , 4.812758, 0.      , ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '2460799229_ce45a1d940': array([[0.       , 0.       , 0.       , ..., 2.5200186, 0.       ,
#          0.       ]], dtype=float32),
#  '412101267_7257e6d8c0': array([[1.0332618, 0.       , 4.2872086, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2635400219_2e1a984fd3': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 2.436074]],
#        dtype=float32),
#  '390360326_26f5936189': array([[0.15016004, 0.        , 1.7679806 , ..., 0.        , 1.5039594 ,
#          0.        ]], dtype=float32),
#  '3442272060_f9155194c2': array([[0.37838227, 0.        , 0.9057947 , ..., 0.        , 1.1561959 ,
#          0.        ]], dtype=float32),
#  '78984436_ad96eaa802': array([[0.5064157, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '1311388430_4ab0cd1a1f': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2180480870_dcaf5ac0df': array([[4.4529495, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '308014594_f1d5e75507': array([[0.        , 0.        , 0.07478851, ..., 0.        , 1.4920766 ,
#          1.2172554 ]], dtype=float32),
#  '2694178830_116be6a6a9': array([[0.5172228, 1.8232   , 0.       , ..., 0.       , 0.       ,
#          0.5759744]], dtype=float32),
#  '236730743_0d4fd8de5a': array([[1.0760946 , 3.6484892 , 0.        , ..., 0.23970124, 0.5240771 ,
#          0.        ]], dtype=float32),
#  '384465575_31294122c0': array([[0.45021278, 0.        , 0.        , ..., 0.        , 4.5625377 ,
#          2.3954864 ]], dtype=float32),
#  '3214579977_fa9fb006a6': array([[0.      , 0.      , 4.089096, ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '2322327298_7948338390': array([[0.68324554, 0.        , 0.7786738 , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '241346434_0527ea1c07': array([[0.8859382, 0.       , 0.       , ..., 0.       , 0.       ,
#          2.1922877]], dtype=float32),
#  '197107117_4b438b1872': array([[0.      , 0.      , 0.      , ..., 0.      , 2.241358, 0.      ]],
#        dtype=float32),
#  '2354064281_10afa38206': array([[2.166181 , 0.       , 0.7357615, ..., 0.       , 0.3660516,
#          0.       ]], dtype=float32),
#  '3616638478_641d02183d': array([[1.8537486, 4.4477153, 0.       , ..., 0.       , 0.       ,
#          1.600762 ]], dtype=float32),
#  '2579268572_d78f8436cb': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3599124739_b7e60cf477': array([[0.       , 0.       , 1.5986499, ..., 0.       , 1.0956945,
#          2.0004454]], dtype=float32),
#  '2354829523_9542fc74ba': array([[0.        , 0.        , 0.        , ..., 0.        , 0.26646587,
#          3.6495976 ]], dtype=float32),
#  '237547381_aa17c805e0': array([[2.4952354 , 2.0979023 , 0.        , ..., 0.        , 0.47505608,
#          0.        ]], dtype=float32),
#  '2623146491_b64698b875': array([[1.7826087 , 0.49945733, 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2288530008_4ebcee2174': array([[0.       , 0.       , 0.       , ..., 0.       , 1.3637481,
#          0.       ]], dtype=float32),
#  '517094985_4b9e926936': array([[1.1395681, 0.       , 0.       , ..., 0.       , 2.4765122,
#          3.9164622]], dtype=float32),
#  '2704379125_9c35650d16': array([[0.3426939 , 0.        , 2.6799812 , ..., 0.75190395, 0.        ,
#          0.        ]], dtype=float32),
#  '2309327462_82a24538d4': array([[0.       , 3.4149435, 0.2942005, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3319058642_885d756295': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.34711558]], dtype=float32),
#  '3150440350_b0f2a9e774': array([[0.18957156, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '3168841415_c0705a327a': array([[0.       , 3.9035995, 2.8311272, ..., 0.       , 1.8112855,
#          1.1852446]], dtype=float32),
#  '1461667284_041c8a2475': array([[3.7869072 , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.51366186]], dtype=float32),
#  '3724738804_f00748a137': array([[1.9135178, 1.6918964, 0.       , ..., 0.       , 0.       ,
#          0.3147328]], dtype=float32),
#  '3504479370_ff2d89a043': array([[0.9299418, 0.       , 0.       , ..., 0.       , 0.       ,
#          3.3455794]], dtype=float32),
#  '2601008162_f00eeb5c14': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.0280664]], dtype=float32),
#  '1056338697_4f7d7ce270': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          0.9546603]], dtype=float32),
#  '3286017638_c688c83e3d': array([[0.       , 0.       , 2.4062965, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2797511323_bf20acab45': array([[1.4757059, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.4482501]], dtype=float32),
#  '3541491057_61a49588d9': array([[0.       , 0.       , 1.2347461, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '472535997_0dbf42b9f3': array([[0.       , 1.4005532, 0.       , ..., 0.       , 2.2641425,
#          0.       ]], dtype=float32),
#  '3016759846_062663f8ab': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.06471097]], dtype=float32),
#  '3104690333_4314d979de': array([[1.4079144, 0.       , 1.7402275, ..., 0.       , 3.026403 ,
#          0.       ]], dtype=float32),
#  '3232030272_b2480a5fe7': array([[0.7805396, 0.9942603, 1.2313051, ..., 0.4054247, 0.7425798,
#          0.       ]], dtype=float32),
#  '2180356743_b3a3c9a7f6': array([[0.        , 2.5892463 , 0.        , ..., 0.        , 0.16400224,
#          0.8697639 ]], dtype=float32),
#  '432496659_f01464d9fb': array([[0.        , 0.59879553, 0.85798144, ..., 1.4530153 , 0.18755719,
#          0.        ]], dtype=float32),
#  '1189977786_4f5aaed773': array([[0.98972416, 1.484974  , 5.983516  , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '1428641354_f7453afbea': array([[0.5608761, 0.       , 0.       , ..., 0.       , 0.       ,
#          2.1012807]], dtype=float32),
#  '241346508_0b3907a95b': array([[0.       , 2.2527962, 0.       , ..., 0.       , 0.       ,
#          3.7865593]], dtype=float32),
#  '276356412_dfa01c3c9e': array([[1.5332975, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '353180303_6a24179c50': array([[2.3154175, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2735558076_0d7bbc18fc': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3632842482_482f29e712': array([[0.        , 0.40688848, 0.        , ..., 0.        , 1.8321989 ,
#          0.        ]], dtype=float32),
#  '3640417354_b0b3e4aec9': array([[0.     , 1.04953, 0.     , ..., 0.     , 0.     , 0.     ]],
#        dtype=float32),
#  '2390369143_6523253a73': array([[0.       , 0.       , 0.       , ..., 0.       , 3.0135002,
#          0.       ]], dtype=float32),
#  '2144050118_3e7d2e05b1': array([[0.       , 2.5229833, 0.       , ..., 0.       , 0.       ,
#          1.7536545]], dtype=float32),
#  '3033612929_764d977bd5': array([[0.      , 0.      , 2.036118, ..., 0.      , 0.      , 0.      ]],
#        dtype=float32),
#  '3648081498_76ec091495': array([[0.33093363, 1.2837274 , 0.        , ..., 0.        , 0.        ,
#          0.17374033]], dtype=float32),
#  '3609026563_9c66f2dc41': array([[0.        , 0.        , 0.18760219, ..., 0.        , 0.71166617,
#          0.        ]], dtype=float32),
#  '3119887391_212f379797': array([[0.        , 0.2539823 , 0.        , ..., 0.        , 0.2836179 ,
#          0.39373603]], dtype=float32),
#  '2441815792_43565b1312': array([[0.42073607, 0.        , 0.        , ..., 0.        , 1.3611808 ,
#          0.47212198]], dtype=float32),
#  '3295680663_af21ea648b': array([[0.       , 0.       , 0.       , ..., 3.5274394, 2.8372283,
#          0.       ]], dtype=float32),
#  '3054200086_657d4398e8': array([[0.       , 2.2226388, 0.       , ..., 0.       , 1.5048642,
#          4.3498354]], dtype=float32),
#  '2451114871_8617ae2f16': array([[0.        , 0.        , 0.        , ..., 0.        , 0.18999866,
#          1.8763447 ]], dtype=float32),
#  '2855727603_e917ded363': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '3119913014_688d4997d7': array([[1.4132565, 0.       , 0.       , ..., 0.       , 0.       ,
#          1.1683416]], dtype=float32),
#  '3445544288_68fdb25969': array([[1.0734693, 0.       , 2.824932 , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '457875937_982588d918': array([[0.        , 0.15822339, 3.6238618 , ..., 0.37765115, 0.        ,
#          0.        ]], dtype=float32),
#  '3576060775_d9121519cc': array([[0.8316226 , 0.78109354, 0.21663618, ..., 0.        , 3.1785815 ,
#          0.        ]], dtype=float32),
#  '3473534758_1ae3847781': array([[1.2534277, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '270816949_ffad112278': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2716457668_187a6d2b1c': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.8804207]], dtype=float32),
#  '2062607137_dac194ad02': array([[0.9734568, 0.       , 0.       , ..., 0.       , 2.7459342,
#          0.       ]], dtype=float32),
#  '3595992258_6f192e6ae7': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2131762850_5293a288d9': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 3.559011]],
#        dtype=float32),
#  '369360998_ba56fb436f': array([[1.7601033, 0.       , 3.6281033, ..., 0.       , 0.       ,
#          2.7856367]], dtype=float32),
#  '3431121650_056db85987': array([[1.1516942, 0.       , 0.       , ..., 0.       , 0.7591851,
#          0.       ]], dtype=float32),
#  '3343106500_27176fc544': array([[0.       , 2.5089028, 0.       , ..., 0.       , 2.3358316,
#          2.3063684]], dtype=float32),
#  '3711826708_bba64fb1e1': array([[1.5419365 , 0.35541162, 0.5353296 , ..., 0.        , 2.6831505 ,
#          0.        ]], dtype=float32),
#  '2344699642_4fae2f4e07': array([[1.2079151 , 2.4804354 , 4.566336  , ..., 2.279712  , 3.5268524 ,
#          0.01026148]], dtype=float32),
#  '2472678549_67068a1566': array([[1.2650104 , 0.553479  , 0.75395286, ..., 0.        , 0.11642051,
#          2.5972886 ]], dtype=float32),
#  '656260720_a7db4ce48b': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          2.2574909]], dtype=float32),
#  '2101808682_0d66ef4a08': array([[1.6277175, 0.878759 , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '2573625591_70291c894a': array([[2.6197033, 0.       , 1.245112 , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '1625306051_7099519baa': array([[1.2514157, 0.       , 7.707837 , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3506216254_04d119cac7': array([[0.77179044, 0.73661214, 0.        , ..., 0.        , 0.        ,
#          1.7479081 ]], dtype=float32),
#  '2301379282_5fbcf230d1': array([[0.        , 1.5386428 , 2.181209  , ..., 0.        , 0.        ,
#          0.66519845]], dtype=float32),
#  '542269487_5d77b363eb': array([[0.31980747, 3.2488654 , 3.6305294 , ..., 0.        , 4.4043126 ,
#          2.9625552 ]], dtype=float32),
#  '1402843760_d30f1dbf0f': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2450453051_f1d4a78ab4': array([[0.        , 0.        , 0.34902024, ..., 1.5571055 , 0.        ,
#          2.303726  ]], dtype=float32),
#  '1434607942_da5432c28c': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          1.2226932]], dtype=float32),
#  '3312096605_f458757418': array([[3.6314063 , 0.        , 3.4624348 , ..., 3.895645  , 0.94137585,
#          0.        ]], dtype=float32),
#  '3634400263_c6fcaa48e1': array([[3.7275267 , 1.0034581 , 0.        , ..., 0.        , 0.48050952,
#          3.2258794 ]], dtype=float32),
#  '169490297_b6ff13632a': array([[0.        , 1.8743727 , 0.55188185, ..., 0.        , 0.        ,
#          2.4843261 ]], dtype=float32),
#  '421316045_ae7a1eb4bc': array([[2.7530909 , 0.        , 0.24912941, ..., 0.        , 0.        ,
#          0.4108274 ]], dtype=float32),
#  '2518219912_f47214aa16': array([[0.       , 0.       , 0.       , ..., 0.       , 3.7546675,
#          0.       ]], dtype=float32),
#  ...}

# %% [markdown]
# ## **Check Captions data mapping**

# %%
mapping
# Out:
# {'1000268201_693b08cb0e': ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#   'startseq girl going into wooden building endseq',
#   'startseq little girl climbing into wooden playhouse endseq',
#   'startseq little girl climbing the stairs to her playhouse endseq',
#   'startseq little girl in pink dress going into wooden cabin endseq'],
#  '1001773457_577c3a7d70': ['startseq black dog and spotted dog are fighting endseq',
#   'startseq black dog and tricolored dog playing with each other on the road endseq',
#   'startseq black dog and white dog with brown spots are staring at each other in the street endseq',
#   'startseq two dogs of different breeds looking at each other on the road endseq',
#   'startseq two dogs on pavement moving toward each other endseq'],
#  '1002674143_1b742ab4b8': ['startseq little girl covered in paint sits in front of painted rainbow with her hands in bowl endseq',
#   'startseq little girl is sitting in front of large painted rainbow endseq',
#   'startseq small girl in the grass plays with fingerpaints in front of white canvas with rainbow on it endseq',
#   'startseq there is girl with pigtails sitting in front of rainbow painting endseq',
#   'startseq young girl with pigtails painting outside in the grass endseq'],
#  '1003163366_44323f5815': ['startseq man lays on bench while his dog sits by him endseq',
#   'startseq man lays on the bench to which white dog is also tied endseq',
#   'startseq man sleeping on bench outside with white and black dog sitting next to him endseq',
#   'startseq shirtless man lies on park bench with his dog endseq',
#   'startseq man laying on bench holding leash of dog sitting on ground endseq'],
#  '1007129816_e794419615': ['startseq man in an orange hat starring at something endseq',
#   'startseq man wears an orange hat and glasses endseq',
#   'startseq man with gauges and glasses is wearing blitz hat endseq',
#   'startseq man with glasses is wearing beer can crocheted hat endseq',
#   'startseq the man with pierced ears is wearing glasses and an orange hat endseq'],
#  '1007320043_627395c3d8': ['startseq child playing on rope net endseq',
#   'startseq little girl climbing on red roping endseq',
#   'startseq little girl in pink climbs rope bridge at the park endseq',
#   'startseq small child grips onto the red ropes at the playground endseq',
#   'startseq the small child climbs on red ropes on playground endseq'],
#  '1009434119_febe49276a': ['startseq black and white dog is running in grassy garden surrounded by white fence endseq',
#   'startseq black and white dog is running through the grass endseq',
#   'startseq boston terrier is running in the grass endseq',
#   'startseq boston terrier is running on lush green grass in front of white fence endseq',
#   'startseq dog runs on the green grass near wooden fence endseq'],
#  '1012212859_01547e3f17': ['startseq dog shakes its head near the shore red ball next to it endseq',
#   'startseq white dog shakes on the edge of beach with an orange ball endseq',
#   'startseq dog with orange ball at feet stands on shore shaking off water endseq',
#   'startseq white dog playing with red ball on the shore near the water endseq',
#   'startseq white dog with brown ears standing near water with head turned to one side endseq'],
#  '1015118661_980735411b': ['startseq boy smiles in front of stony wall in city endseq',
#   'startseq little boy is standing on the street while man in overalls is working on stone wall endseq',
#   'startseq young boy runs aross the street endseq',
#   'startseq young child is walking on stone paved street with metal pole and man behind him endseq',
#   'startseq smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him endseq'],
#  '1015584366_dfcec3c85a': ['startseq black dog leaps over log endseq',
#   'startseq grey dog is leaping over fallen tree endseq',
#   'startseq large black dog leaps fallen log endseq',
#   'startseq mottled black and grey dog in blue collar jumping over fallen tree endseq',
#   'startseq the black dog jumped the tree stump endseq'],
#  '101654506_8eb26cfb60': ['startseq brown and white dog is running through the snow endseq',
#   'startseq dog is running in the snow endseq',
#   'startseq dog running through snow endseq',
#   'startseq white and brown dog is running through snow covered field endseq',
#   'startseq the white and brown dog is running over the surface of the snow endseq'],
#  '101669240_b2d3e7f17b': ['startseq man in hat is displaying pictures next to skier in blue hat endseq',
#   'startseq man skis past another man displaying paintings in the snow endseq',
#   'startseq person wearing skis looking at framed pictures set up in the snow endseq',
#   'startseq skier looks at framed pictures in the snow next to trees endseq',
#   'startseq man on skis looking at artwork for sale in the snow endseq'],
#  '1016887272_03199f49c4': ['startseq collage of one person climbing cliff endseq',
#   'startseq group of people are rock climbing on rock climbing wall endseq',
#   'startseq group of people climbing rock while one man belays endseq',
#   'startseq seven climbers are ascending rock face whilst another man stands holding the rope endseq',
#   'startseq several climbers in row are climbing the rock while the man in red watches and holds the line endseq'],
#  '1019077836_6fc9b15408': ['startseq brown dog chases the water from sprinkler on lawn endseq',
#   'startseq brown dog plays with the hose endseq',
#   'startseq brown dog running on lawn near garden hose endseq',
#   'startseq dog is playing with hose endseq',
#   'startseq large brown dog running away from the sprinkler in the grass endseq'],
#  '1019604187_d087bf9a5f': ['startseq dog prepares to catch thrown object in field with nearby cars endseq',
#   'startseq white dog is about to catch yellow ball in its mouth endseq',
#   'startseq white dog is about to catch yellow dog toy endseq',
#   'startseq white dog is ready to catch yellow ball flying through the air endseq',
#   'startseq white dog running after yellow ball endseq'],
#  '1020651753_06077ec457': ['startseq black and white dog jumping in the air to get toy endseq',
#   'startseq black and white dog jumps up towards yellow toy endseq',
#   'startseq dog leaps to catch ball in field endseq',
#   'startseq white dog is trying to catch ball in midair over grassy field endseq',
#   'startseq the white dog is playing in green field with yellow toy endseq'],
#  '1022454332_6af2c1449a': ['startseq child and woman are at waters edge in big city endseq',
#   'startseq large lake with lone duck swimming in it with several people around the edge of it endseq',
#   'startseq little boy at lake watching duck endseq',
#   'startseq young boy waves his hand at the duck in the water surrounded by green park endseq',
#   'startseq two people are at the edge of lake facing the water and the city skyline endseq'],
#  '1022454428_b6b660a67b': ['startseq couple and an infant being held by the male sitting next to pond with near by stroller endseq',
#   'startseq couple sit on the grass with baby and stroller endseq',
#   'startseq couple with their newborn baby sitting under tree facing lake endseq',
#   'startseq man and woman care for an infant along the side of body of water endseq',
#   'startseq couple with baby sit outdoors next to their stroller endseq'],
#  '1022975728_75515238d8': ['startseq black dog running in the surf endseq',
#   'startseq black lab with tags frolicks in the water endseq',
#   'startseq dog splashes in the water endseq',
#   'startseq the black dog runs through the water endseq',
#   'startseq this is black dog splashing in the water endseq'],
#  '102351840_323e3de834': ['startseq man drilling hole in the ice endseq',
#   'startseq man is drilling through the frozen ice of pond endseq',
#   'startseq person in the snow drilling hole in the ice endseq',
#   'startseq person standing on frozen lake endseq',
#   'startseq two men are ice fishing endseq'],
#  '1024138940_f1fefbdce1': ['startseq two different breeds of brown and white dogs play on the beach endseq',
#   'startseq two dogs are making turn on soft sand beach endseq',
#   'startseq two dogs playing in the sand at the beach endseq',
#   'startseq two dogs playing together on beach endseq',
#   'startseq two large tan dogs play along sandy beach endseq'],
#  '102455176_5f8ead62d5': ['startseq man uses ice picks and crampons to scale ice endseq',
#   'startseq an ice climber in blue jacket and black pants is scaling frozen ice wall endseq',
#   'startseq an ice climber scaling frozen waterfall endseq',
#   'startseq person in blue and red ice climbing with two picks endseq',
#   'startseq climber climbing an ice wall endseq'],
#  '1026685415_0431cbf574': ['startseq black dog carries green toy in his mouth as he walks through the grass endseq',
#   'startseq black dog carrying something through the grass endseq',
#   'startseq black dog has blue toy in its mouth endseq',
#   'startseq dog in grass with blue item in his mouth endseq',
#   'startseq wet black dog is carrying green toy through the grass endseq'],
#  '1028205764_7e8df9a2ea': ['startseq man and baby are in yellow kayak on water endseq',
#   'startseq man and little boy in blue life jackets are rowing yellow canoe endseq',
#   'startseq man and child kayak through gentle waters endseq',
#   'startseq man and young boy ride in yellow kayak endseq',
#   'startseq man and child in yellow kayak endseq'],
#  '1030985833_b0902ea560': ['startseq black dog and brown dog are jumping up to catch red toy endseq',
#   'startseq black dog and brown dog play with red toy on courtyard endseq',
#   'startseq brown and black lab are outside and the black lab is catching toy in its mouth endseq',
#   'startseq black dog snaps at red and black object as brown dog lunges endseq',
#   'startseq the chocolate lab jumps too late to get the toy as the black lab captures it in the driveway endseq'],
#  '103106960_e8a41d64f8': ['startseq boy with stick kneeling in front of goalie net endseq',
#   'startseq child in red jacket playing street hockey guarding goal endseq',
#   'startseq young kid playing the goalie in hockey rink endseq',
#   'startseq young male kneeling in front of hockey goal with hockey stick in his right hand endseq',
#   'startseq hockey goalie boy in red jacket crouches by goal with stick endseq'],
#  '103195344_5d2dc613a3': ['startseq man in black is sitting next to modern art structure in front of glass building endseq',
#   'startseq man sits and reads newspaper by sculpture outside of an office building endseq',
#   'startseq man sits near large statue endseq',
#   'startseq man sitting in front of metal sculpture in front of building endseq',
#   'startseq the man with the backpack is sitting in buildings courtyard in front of an art sculpture reading endseq'],
#  '103205630_682ca7285b': ['startseq tent is being set up on the ice endseq',
#   'startseq two men are about to enter an ice fishing tent on snow covered lake endseq',
#   'startseq two men setting up blue ice fishing hut on an iced over lake endseq',
#   'startseq two men standing on an ice looking into something covered with blue tarp endseq',
#   'startseq two people standing outside blue tent structure on snowy surface endseq'],
#  '1032122270_ea6f0beedb': ['startseq woman crouches near three dogs in field endseq',
#   'startseq three dogs are playing on grassy hill with blue sky endseq',
#   'startseq three dogs are standing in the grass and person is sitting next to them endseq',
#   'startseq three dogs on grassy hill endseq',
#   'startseq three dogs stand in grassy field while person kneels nearby endseq'],
#  '1032460886_4a598ed535': ['startseq man is standing in front of skyscraper endseq',
#   'startseq man stands in front of skyscraper endseq',
#   'startseq man stands in front of very tall building endseq',
#   'startseq behind the man in red shirt stands large skyscraper endseq',
#   'startseq there is skyscraper in the distance with man walking in front of the camera endseq'],
#  '1034276567_49bb87c51c': ['startseq boy bites hard into treat while he sits outside endseq',
#   'startseq child biting into baked good endseq',
#   'startseq small boy putting something in his mouth with both hands endseq',
#   'startseq the boy eats his food outside at the table endseq',
#   'startseq the boy is eating pizza over tin dish endseq'],
#  '104136873_5b5d41be75': ['startseq people sit on the mountainside and check out the view endseq',
#   'startseq three people are on hilltop overlooking green valley endseq',
#   'startseq three people hang out on top of big hill endseq',
#   'startseq three people overlook green valley endseq',
#   'startseq three people rest on ledge above the moutains endseq'],
#  '1042020065_fb3d3ba5ba': ['startseq boy in green shirt is looking down at many inflatable boats endseq',
#   'startseq boy in green shirt watches kayakers endseq',
#   'startseq boy looks over railing at the many boats and rafts below in the water endseq',
#   'startseq young boy overlooking crowd of inflatable boats endseq',
#   'startseq young boy wearing jersey looks down over ledge at many boats in the water endseq'],
#  '1042590306_95dea0916c': ['startseq man and woman pose for the camera while another man looks on endseq',
#   'startseq man is holding the hand of woman up to his mouth in front of some buildings while another man looks on endseq',
#   'startseq multiracial couple posing for picture endseq',
#   'startseq asian man and blond woman holding hands outdoors man in background watches endseq',
#   'startseq guy in blue shirt biting hand of girl in black striped jacket while another guy watches endseq'],
#  '1045521051_108ebc19be': ['startseq person eats takeout while watching small television endseq',
#   'startseq person sits on the floor and eats in front of television endseq',
#   'startseq television with picture of girl on it endseq',
#   'startseq young man sits on the floor by the television with fast food meal in front of him endseq',
#   'startseq someone is laying in front of the tv eating food endseq'],
#  '1048710776_bb5b0a5c7c': ['startseq couple of several people sitting on ledge overlooking the beach endseq',
#   'startseq group of people sit on wall at the beach endseq',
#   'startseq group of teens sit on wall by beach endseq',
#   'startseq crowd of people at the beach endseq',
#   'startseq several young people sitting on rail above crowded beach endseq'],
#  '1052358063_eae6744153': ['startseq boy takes jump on his skateboard while another boy with skateboard watches endseq',
#   'startseq child is performing skateboard trick while another child with skateboard leans on wall endseq',
#   'startseq little boy skateboarder is doing trick on his board while another young skateboarder watches endseq',
#   'startseq young boy skateboarder jumping on platform on skateboard endseq',
#   'startseq two skateboarders endseq'],
#  '105342180_4d4a40b47f': ['startseq girl paddling down large river as seen from behind her endseq',
#   'startseq woman kayaking down river endseq',
#   'startseq woman paddles boat down river endseq',
#   'startseq woman with paddle endseq',
#   'startseq woman with paddle sits in boat on the water endseq'],
#  '1053804096_ad278b25f1': ['startseq girl in pigtails splashes in the shallow water endseq',
#   'startseq girls plays in the surf endseq',
#   'startseq girl with pigtails is playing in the ocean by the beach endseq',
#   'startseq girl with pigtails plays in the water endseq',
#   'startseq young girl in pigtails plays in the water endseq'],
#  '1055623002_8195a43714': ['startseq group of four children wearing pajamas have pillow fight endseq',
#   'startseq group of kids have pillowfight endseq',
#   'startseq group of young children playing pillow fight on bed endseq',
#   'startseq children having pillow fight endseq',
#   'startseq four children are having pillow fight endseq'],
#  '1055753357_4fa3d8d693': ['startseq two constructions workers sit on beam taking break endseq',
#   'startseq two construction workers are sitting up on the side of building endseq',
#   'startseq two construction workers sitting on an ibeam endseq',
#   'startseq two construction workers take seat on steel beam endseq',
#   'startseq two men take break from construction endseq'],
#  '1056249424_ef2a2e041c': ['startseq the children are playing in the water endseq',
#   'startseq two boys one with yellow and orange ball play in some water in front of field endseq',
#   'startseq two boys play in puddle endseq',
#   'startseq two children play with balloon in mud on sunny day endseq',
#   'startseq two kids are running and playing in some water endseq'],
#  '1056338697_4f7d7ce270': ['startseq blond woman in blue shirt appears to wait for ride endseq',
#   'startseq blond woman is on the street hailing taxi endseq',
#   'startseq woman is signaling is to traffic as seen from behind endseq',
#   'startseq woman with blonde hair wearing blue tube top is waving on the side of the street endseq',
#   'startseq the woman in the blue dress is holding out her arm at oncoming traffic endseq'],
#  '1056359656_662cee0814': ['startseq little girl looking at brochure on train rides endseq',
#   'startseq young blond girl with magizine in her hands endseq',
#   'startseq young girl on train reads book about train rides endseq',
#   'startseq young girl sits on seat and looks at train pamphlet endseq',
#   'startseq child sitting down looking at train ride brochure endseq'],
#  '1056873310_49c665eb22': ['startseq brown dog is running after black dog on rocky shore endseq',
#   'startseq brown dog is running after the black dog endseq',
#   'startseq two dogs playing on beach endseq',
#   'startseq two dogs run across stones near body of water endseq',
#   'startseq two dogs run towards each other on rocky area with water in the background endseq'],
#  '1057089366_ca83da0877': ['startseq boy descends off the end of high diving board endseq',
#   'startseq child jumps off high diving board into the pool endseq',
#   'startseq kid jumps off the diving board and into the swimming pool below endseq',
#   'startseq little kid is jumping off high dive at the pool endseq',
#   'startseq the boy is jumping off high diving board into the pool endseq'],
#  '1057210460_09c6f4c6c1': ['startseq guy stands by window taking his overshirt off endseq',
#   'startseq man in tank top stands next to chrome door endseq',
#   'startseq man puts his shirt on near an elevator endseq',
#   'startseq man stands by an elevator with his head down endseq',
#   'startseq the man is putting on his shirt near an elevator endseq'],
#  '1057251835_6ded4ada9c': ['startseq lightcolored dog runs on the beach endseq',
#   'startseq small yellow dog runs on beach endseq',
#   'startseq tan dog runs on sandy beach endseq',
#   'startseq white dog is running down rocky beach endseq',
#   'startseq light brown dog running along the beach endseq'],
#  '106490881_5a2dd9b7bd': ['startseq boy in his blue swim shorts at the beach endseq',
#   'startseq boy smiles for the camera at beach endseq',
#   'startseq young boy in swimming trunks is walking with his arms outstretched on the beach endseq',
#   'startseq children playing on the beach endseq',
#   'startseq the boy is playing on the shore of an ocean endseq'],
#  '106514190_bae200f463': ['startseq hiker standing high on bluff overlooking the mountains below endseq',
#   'startseq person on ski looks from hill over snow covered landscape endseq',
#   'startseq skier is overlooking snowcovered mountain endseq',
#   'startseq skier is overlooking the beautiful white snow covered landscape endseq',
#   'startseq skier pauses on mountaintop endseq'],
#  '1067180831_a59dc64344': ['startseq black and white dog is attempting to catch yellow and purple object in low cut yard endseq',
#   'startseq black and white dog jumps after yellow toy endseq',
#   'startseq black and white dog jumps to get the frisbee endseq',
#   'startseq black dog is jumping up to catch purple and green toy endseq',
#   'startseq dog jumps to catch toy endseq'],
#  '1067675215_7336a694d6': ['startseq man in blue shorts is laying in the street endseq',
#   'startseq man in blue shorts lays down outside in parking lot endseq',
#   'startseq man laying down in middle of street during heavy traffic endseq',
#   'startseq man lies on mat in parking lot between brown suv and yellow pickup with an open door endseq',
#   'startseq shirtless man is laying down in the middle of busy street endseq'],
#  '1067790824_f3cc97239b': ['startseq white and black dog and brown dog in sandy terrain endseq',
#   'startseq woolly dog chases doberman on beach endseq',
#   'startseq one dog is chasing another one on the beach endseq',
#   'startseq the two large dogs are running through sand endseq',
#   'startseq two large dogs chasing each other at the beach endseq'],
#  '1072153132_53d2bb1b60': ['startseq black and white dog catches toy in midair endseq',
#   'startseq dog and tennis ball endseq',
#   'startseq dog is jumping to catch object thrown at it endseq',
#   'startseq dog leaps while chasing tennis ball through grassy field endseq',
#   'startseq multicolor dog jumping to catch tennis ball in grassy field endseq'],
#  '107318069_e9f2ef32de': ['startseq crowd watching air balloons at night endseq',
#   'startseq group of hot air balloons lit up at night endseq',
#   'startseq people are watching hot air balloons in the park endseq',
#   'startseq people watching hot air balloons endseq',
#   'startseq seven large balloons are lined up at nighttime near crowd endseq'],
#  '1075716537_62105738b4': ['startseq child with helmet on his head rides bike endseq',
#   'startseq little boy rides bike down hill on miniature dirt bike endseq',
#   'startseq young boy in helmet rides bike on the road endseq',
#   'startseq the little boy rides his bicycle in race endseq',
#   'startseq the young boy pedals quickly at bmx race endseq'],
#  '107582366_d86f2d3347': ['startseq group of eight people are gathered around table at night endseq',
#   'startseq group of people gathered around in the dark endseq',
#   'startseq group of people sit around table outside on porch at night endseq',
#   'startseq group of people sit outdoors together at night endseq',
#   'startseq group of people sitting at table in darkened room endseq'],
#  '1075867198_27ca2e7efe': ['startseq man in brown shirt and dark shorts plays on the beach with his two black dogs endseq',
#   'startseq man in shorts with two black dogs holds ball throwing toy at the beach endseq',
#   'startseq man playing with two black dogs on the beach endseq',
#   'startseq man with two dogs on beach endseq',
#   'startseq man at the beach with two dogs endseq'],
#  '1075881101_d55c46bece': ['startseq boy cleans the bubbles off his face endseq',
#   'startseq boy covered in suds has his face wiped clean endseq',
#   'startseq boy is covered in bubbles endseq',
#   'startseq child covered in foam is climbing on black inflatable ramp endseq',
#   'startseq person covered in soapy water is getting cleaned off endseq'],
#  '1077546505_a4f6c4daa9': ['startseq boy in blue shorts slides down slide into pool endseq',
#   'startseq boy in blue swimming trunks slides down yellow slide into wading pool with inflatable toys floating in the water endseq',
#   'startseq boy rides down slide into small backyard pool endseq',
#   'startseq boy sliding down slide into pool with colorful tubes endseq',
#   'startseq child is falling off slide onto colored balloons floating on pool of water endseq'],
#  '1077931201_1e0bb83105': ['startseq man in wetsuit is throwing baby wearing wetsuit up into the air endseq',
#   'startseq man in wetsuit is throwing toddler up in the air and is ready to catch him endseq',
#   'startseq man in water throwing little boy up in the air and waiting for him to come down so he can catch him endseq',
#   'startseq the man is in the pool and throwing small boy into the air endseq',
#   'startseq while water droplets fly man throws little boy up in the air endseq'],
#  '1079274291_9aaf896cc1': ['startseq little boy sticks his tongue out for the camera another boy looks on endseq',
#   'startseq two boys make faces endseq',
#   'startseq two young boys are looking at the camera one smiling the other sticking his tongue out endseq',
#   'startseq two young boys look up at the camera as one sticks out his tongue endseq',
#   'startseq two young boys making silly faces endseq'],
#  '10815824_2997e03d76': ['startseq blonde horse and blonde girl in black sweatshirt are staring at fire in barrel endseq',
#   'startseq girl and her horse stand by fire endseq',
#   'startseq girl holding horse lead behind fire endseq',
#   'startseq man and girl and two horses are near contained fire endseq',
#   'startseq two people and two horses watching fire endseq'],
#  '1082252566_8c79beef93': ['startseq bulldog sheep dog and boxer standing in yard endseq',
#   'startseq large brown dog is pushing small boston terrier with his face while anouther dog watches endseq',
#   'startseq large skinny dog stands near two smaller dogs int the dirt endseq',
#   'startseq there are three dogs starring at ball in the middle of them endseq',
#   'startseq three dogs of various sizes endseq'],
#  '1082379191_ec1e53f996': ['startseq lady and man with no shirt sit on dock endseq',
#   'startseq man and woman are sitting on dock together endseq',
#   'startseq man and woman sitting on dock endseq',
#   'startseq man and woman sitting on deck next to lake endseq',
#   'startseq shirtless man and woman sitting on dock endseq'],
#  '1084040636_97d9633581': ['startseq closeup of white dog that is laying its head on its paws endseq',
#   'startseq large white dog lying on the floor endseq',
#   'startseq white dog has its head on the ground endseq',
#   'startseq white dog is resting its head on tiled floor with its eyes open endseq',
#   'startseq white dog rests its head on the patio bricks endseq'],
#  '1084104085_3b06223afe': ['startseq woman in yellow shirt and green shorts is climbing an artificial red wall whilst wearing safety harness endseq',
#   'startseq woman in blue shorts and white shirt is indoor rock climbing endseq',
#   'startseq the girl is climbing rock wall endseq',
#   'startseq the girl is in harness climbing rocks endseq',
#   'startseq woman climbing an artificial rock wall endseq'],
#  '1087168168_70280d024a': ['startseq boy is jumping on an inflatable ring and girl is watching him endseq',
#   'startseq boy jumping on water jumphouse endseq',
#   'startseq teenage boy is jumping on an inflatable slide endseq',
#   'startseq young boy jumping and young girl seating in an inflatable pool endseq',
#   'startseq two young kids are playing in the water on an inflated toy endseq'],
#  '1087539207_9f77ab3aaf': ['startseq family playing on tractor on beautiful day endseq',
#   'startseq children ride tractor in field endseq',
#   'startseq several children playing on polaris vehicle outdoors endseq',
#   'startseq the children played on the four wheeler in the field endseq',
#   'startseq the four kids are riding on an atv in field endseq'],
#  '1088767354_2acee738cf': ['startseq woman in red costume to the left of man and woman standing together endseq',
#   'startseq woman wearing red costume looks at two other people standing on street endseq',
#   'startseq young woman in red sequined costume and feather stands on the sidewalk endseq',
#   'startseq the girl in the salmon colored bikini is standing next to two young people one is wearing black outfit and the other is drinking pop endseq',
#   'startseq two young people are approached by flamboyant young woman dressed in red bikini and red feathered headress endseq'],
#  '108898978_7713be88fc': ['startseq skiiers walking up the hill through forest endseq',
#   'startseq two men are skiing in the snow in wooded area endseq',
#   'startseq two people wearing yellow jackets crosscountry skiing endseq',
#   'startseq two skiers are making their way through woodland endseq',
#   'startseq two skiers are sliding down trail in the woods endseq'],
#  '108899015_bf36131a57': ['startseq lone skier is making their way up mountain endseq',
#   'startseq skiiers at the top of snow covered hill endseq',
#   'startseq two hikers climbing snowy hill endseq',
#   'startseq two people are on snowcovered mountain endseq',
#   'startseq two people climbing up snowy mountain endseq'],
#  '1089181217_ee1167f7af': ['startseq brown dog running down paved pathway endseq',
#   'startseq brown dog running next to grass endseq',
#   'startseq dog is running down road endseq',
#   'startseq light brown dog runs down path happily endseq',
#   'startseq energetic brown dog running endseq'],
#  '1089755335_0bfbfd30e6': ['startseq mother and children is fishing on boardwalk at night endseq',
#   'startseq woman and three children stand on deck with fishing pole endseq',
#   'startseq woman stands with children on boardwalk at night overlooking the sea endseq',
#   'startseq some people on pier at night with one girl fishing off it endseq',
#   'startseq woman with three children fishing over boardwalk in the evening endseq'],
#  '109202756_b97fcdc62c': ['startseq woman dressed in blue jacket and blue jeans rides brown horse near frozen lake and snowcovered mountain endseq',
#   'startseq woman in blue jacket rides brown pony near water endseq',
#   'startseq woman rides horse near frozen lake in the wintertime endseq',
#   'startseq young blond woman sitting atop brown draft horse in the snowy mountains endseq',
#   'startseq woman blue jacket sits on daft horse near frozen lake endseq'],
#  '109202801_c6381eef15': ['startseq two draft horses pull cart through the snow endseq',
#   'startseq two golden brown horses pull sleigh driven by woman in blue coat endseq',
#   'startseq two horses are pulling woman in cart endseq',
#   'startseq two horses pull carriage driven by woman over snow covered ground endseq',
#   'startseq two horses pulling sled steered by smiling blond woman endseq'],
#  '109260216_85b0be5378': ['startseq person climbing down sheer rock cliff using rope endseq',
#   'startseq person climbs tall flat mountain while holding onto safety rope endseq',
#   'startseq person is climbing rock while holding onto white rope endseq',
#   'startseq person rappels down steep incline endseq',
#   'startseq person wearing red vest climbs up steep rock endseq'],
#  '109260218_fca831f933': ['startseq people stand inside rock dome endseq',
#   'startseq shaft of light in cave shows three spelunkers endseq',
#   'startseq spelunkers pose inside rock cavern while bathed in sunlight from the surface endseq',
#   'startseq three people sit in cave endseq',
#   'startseq three rock climbers are posing on big rocks endseq'],
#  '1093716555_801aacef79': ['startseq group of backpackers lay on the dry ground endseq',
#   'startseq group of hikers are resting on the ground in front of some mountains endseq',
#   'startseq people camp with the mountains in the background endseq',
#   'startseq several hikers rest with their gear in front of mountain endseq',
#   'startseq the group of hikers is resting in front of mountain endseq'],
#  '1093737381_b313cd49ff': ['startseq woman in blue dress stands with chalk portrait of two children playing by stream endseq',
#   'startseq woman standing in front of chalk drawing endseq',
#   'startseq woman stands next to chalk drawing in front of barnlike structure endseq',
#   'startseq woman stands outside near an elaborate chalk illustration endseq',
#   'startseq woman wearing blue dress is drawing picture of boy and girl on the sidewalk with sidewalk chalk endseq'],
#  '1094462889_f9966dafa6': ['startseq brown dog plays in deep pile of snow endseq',
#   'startseq dog looking at the camera in snow endseq',
#   'startseq dog runs through the snow endseq',
#   'startseq tan dog stand in the snow and looks up endseq',
#   'startseq the brown dog is out in the snow endseq'],
#  '1095476286_87d4f8664e': ['startseq boy jumping in fountain endseq',
#   'startseq boy plays in the fountains endseq',
#   'startseq child plays in fountain endseq',
#   'startseq little boy playing in the water endseq',
#   'startseq young boy is jumping through water being sprayed up from the ground endseq'],
#  '1095580424_76f0aa8a3e': ['startseq corgi runs out of tunnel endseq',
#   'startseq dog runs out of tunnel on course endseq',
#   'startseq dog running out of tunnel on obstacle course endseq',
#   'startseq the dog is running out of the tunnel on dog obedience course endseq',
#   'startseq the small brown and white dog is running out of small tunnel endseq'],
#  '1095590286_c654f7e5a9': ['startseq blond dog and black and white dog run in dirt field endseq',
#   'startseq dog chases another dog endseq',
#   'startseq yellow dog and black and white dog are running in the dirt endseq',
#   'startseq two dogs are running in field endseq',
#   'startseq two dogs running around endseq'],
#  '1095980313_3c94799968': ['startseq little girl in blue swimsuit is walking along wooden fence next to sandy beach endseq',
#   'startseq little girl with arms outstretched is posing at the beach endseq',
#   'startseq young girl walks on railing in front of the beach endseq',
#   'startseq little girl in blue swimsuit standing on handrail near beach endseq',
#   'startseq the little girl in the blue bathing suit is posing at the beach endseq'],
#  '1096097967_ac305887b4': ['startseq black and white dog drinking water from water spray endseq',
#   'startseq black and white dog is being soaked with jet of water in blue paddling pool endseq',
#   'startseq dog sticking its face into the shower from garden hose endseq',
#   'startseq small white dog gets sprayed by water endseq',
#   'startseq white and black dog is jumping into pool endseq'],
#  '1096165011_cc5eb16aa6': ['startseq boy smiles underwater endseq',
#   'startseq redheaded boy swimming underwater endseq',
#   'startseq small boy swimming underwater endseq',
#   'startseq smiling boy swims underwater in pool endseq',
#   'startseq the boys smiles underwater at the pool endseq'],
#  '1096395242_fc69f0ae5a': ['startseq boy with toy gun endseq',
#   'startseq little boy in orange shorts playing with toy endseq',
#   'startseq young boy with his foot outstretched aims toy at the camera in front of fireplace endseq',
#   'startseq young child plays with his new lightup toy endseq',
#   'startseq boy with toy gun pointed at the camera endseq'],
#  '109671650_f7bbc297fa': ['startseq boy in yellow shorts is standing on top of cliff endseq',
#   'startseq boy wearing blue and yellow walking on cliff edge endseq',
#   'startseq little boy standing high in the air on rock endseq',
#   'startseq young child is standing alone on some jagged rocks endseq',
#   'startseq child stands near edge of cliff endseq'],
#  '109738763_90541ef30d': ['startseq person on snowmobile in mid jump endseq',
#   'startseq snowmobiler flies through the air endseq',
#   'startseq snowmobile rider flies through the air on his or her machine in front of tall pine trees endseq',
#   'startseq rider jumps snowmobile high in rural area endseq',
#   'startseq the man is up in the air endseq'],
#  '109738916_236dc456ac': ['startseq people are riding around on snowmobiles endseq',
#   'startseq people pose with helmets and goggles on while riding snowmobiles endseq',
#   'startseq several people are taking break while on snowmobiling ride endseq',
#   'startseq three people and two snowmobiles endseq',
#   'startseq two helmeted men sit on yellow snowmobiles while another man stands behind watching endseq'],
#  '109823394_83fcb735e1': ['startseq three people drive atvs endseq',
#   'startseq three people on atvs in brown field turn their heads to look at the camera endseq',
#   'startseq three people on atv outside endseq',
#   'startseq three people on four wheel atv in field endseq',
#   'startseq three people ride their four wheelers through the field endseq'],
#  '109823395_6fb423a90f': ['startseq four wheeler jumping in an empty field endseq',
#   'startseq man on four wheeler is flying through the air endseq',
#   'startseq person is riding an orange atv in large empty field endseq',
#   'startseq man jumping with all terrain vehicle endseq',
#   'startseq man on an atv catching air endseq'],
#  '109823397_e35154645f': ['startseq man jumps gin the air while riding an atv endseq',
#   'startseq man on fourwheeler jumps near small building endseq',
#   'startseq an atv is airborne over field in front of white structure endseq',
#   'startseq person dressed in tan jacket jumps quad over harvested cornfield in front of small out building endseq',
#   'startseq man on four wheeler in the air endseq'],
#  '1100214449_d10861e633': ['startseq boy in striped shirt is jumping in front of water fountain endseq',
#   'startseq boy is jumping off the side of running stone water fountain in front of building endseq',
#   'startseq happy boy is jumping in front od city fountain endseq',
#   'startseq little boy is jumping in front of fountain endseq',
#   'startseq little boy is playfully jumping off the side of fountain endseq'],
#  '1104133405_c04a00707f': ['startseq boy carrying soccer ball endseq',
#   'startseq boy walks with ball tucked under his arm endseq',
#   'startseq boy walks with soccer ball near fence endseq',
#   'startseq boy wearing white tshirt walks on the grass and carries soccer ball endseq',
#   'startseq small boy carries soccer ball on field endseq'],
#  '1105959054_9c3a738096': ['startseq child painting picture endseq',
#   'startseq an artist paints clouds onto canvas endseq',
#   'startseq young girl painting picture endseq',
#   'startseq young girl with braids is painting with water colors on white paper on the wall endseq',
#   'startseq the child paints on large paper with water colors endseq'],
#  '110595925_f3395c8bd6': ['startseq cyclist is riding bicycle on curved road up hill endseq',
#   'startseq man in aerodynamic gear riding bicycle down road around sharp curve endseq',
#   'startseq man on mountain bike is pedaling up hill endseq',
#   'startseq man bicycle up road while cows graze on hill nearby endseq',
#   'startseq the biker is riding around curve in the road endseq'],
#  '1107246521_d16a476380': ['startseq black dog jumping to catch rope toy endseq',
#   'startseq black dog playing fetch with ball of rope endseq',
#   'startseq black dog pounces to get rope toy endseq',
#   'startseq black dog running after his rope toy endseq',
#   'startseq large black dog is playing in grassy yard endseq'],
#  '1107471216_4336c9b328': ['startseq little girl is holding cine camera in front of her face endseq',
#   'startseq young girl is looking through an old fashioned video camera endseq',
#   'startseq young girl steadies her aim with camera endseq',
#   'startseq girl with rosy cheeks and lips holding black toy gun endseq',
#   'startseq there is kid with gun endseq'],
#  '1110208841_5bb6806afe': ['startseq black and white border collie catches frisbee in front of an audience endseq',
#   'startseq brown and white dog catches frisbee in it mouth in front of group of people endseq',
#   'startseq brown and white dug jumping up to catch frisbee while an audience watches endseq',
#   'startseq dog jumps to catch frisbee while many people watch endseq',
#   'startseq an agile dog catches frisbee while crowd of onlookers watches closely endseq'],
#  '1112212364_0c48235fc2': ['startseq baby is sitting on and playing with smooth rocks endseq',
#   'startseq baby is stacking rocks on the beach endseq',
#   'startseq small boy is playing with rocks endseq',
#   'startseq toddler sitting on pile of rocks holding rock at beach endseq',
#   'startseq toddler sits on pile of rocks endseq'],
#  '111497985_38e9f88856': ['startseq kid rock climbing against the backdrop of green valley endseq',
#   'startseq woman in striped shirt climbs up mountain endseq',
#   'startseq young man climbs rocky hill endseq',
#   'startseq the person has striped shirt on and is holding on to rope on mountain endseq',
#   'startseq the person in the striped shirt is mountain climbing endseq'],
#  '111537217_082a4ba060': ['startseq man climbing rock wall endseq',
#   'startseq man climbing the side of cliff endseq',
#   'startseq man is rock climbing endseq',
#   'startseq man with red shoes white shirt and grey pants climbing endseq',
#   'startseq the young man with the white tshirt and jeans is rappeling up the rock wall endseq'],
#  '111537222_07e56d5a30': ['startseq climber wearing blue helmet and headlamp is attached to rope on the rock face endseq',
#   'startseq man climbs rocky wall endseq',
#   'startseq rock climber climbs large rock endseq',
#   'startseq woman in purple snakeskin pants climbs rock endseq',
#   'startseq person with blue helmet and purple pants is rock climbing endseq'],
#  '1115565519_d976d4b1f1': ['startseq child playing with fountain at the beach endseq',
#   'startseq child plays with fountain endseq',
#   'startseq girl looks at fountain that sprays water endseq',
#   'startseq little girl playing in water on frog sculpture endseq',
#   'startseq the little girl is playing with toy in public fountain endseq'],
#  '1115679311_245eff2f4b': ['startseq black dog is jumping over log along beach endseq',
#   'startseq black dog runs along the beach and jumps over wood barrior endseq',
#   'startseq dog is running on the beach endseq',
#   'startseq dog jumping over small wall at beach near the water endseq',
#   'startseq an animal is running on the beach endseq'],
#  '111766423_4522d36e56': ['startseq black and white bird eating seeds out of someone hand endseq',
#   'startseq black and white bird standing on hand endseq',
#   'startseq small bird sits in person hand and eats seeds endseq',
#   'startseq black and white bird standing on hand of someone holding sunflower seeds endseq',
#   'startseq the small bird is clinging to finger of the hand holding the seeds endseq'],
#  '1117972841_2b9261f95f': ['startseq brown dog is running in the sand endseq',
#   'startseq brown dog playing in the sand endseq',
#   'startseq brown dog plays at the beach endseq',
#   'startseq dog is standing in the sand endseq',
#   'startseq dog running fast in the sand endseq'],
#  '1118557877_736f339752': ['startseq little boy stands in the surf endseq',
#   'startseq small child wades through the water while being guided by another person endseq',
#   'startseq young boy laughs while splashing in the ocean endseq',
#   'startseq young boy wearing colorful bathing suit splashing in the ocean endseq',
#   'startseq young child splashing in water endseq'],
#  '1119015538_e8e796281e': ['startseq little tan dog with large ears running through the grass endseq',
#   'startseq playful dog is running through the grass endseq',
#   'startseq small dogs ears stick up as it runs in the grass endseq',
#   'startseq the small dog is running across the lawn endseq',
#   'startseq this is small beige dog running through grassy field endseq'],
#  '1119418776_58e4b93eac': ['startseq black and white dog is running through the field endseq',
#   'startseq black brown and white dog running through field endseq',
#   'startseq brown black and white dog is running through large field with its mouth open endseq',
#   'startseq dog running in field endseq',
#   'startseq dog with its mouth open running through field torwards the camera endseq'],
#  '1119463452_69d4eecd08': ['startseq girl in pink swimsuit in pool endseq',
#   'startseq girl swimming in pool endseq',
#   'startseq little girl in pink bathing suit swimming in pool endseq',
#   'startseq little girl swimming in pool endseq',
#   'startseq smiling little girl swimming in outdoor pool endseq'],
#  '1121416483_c7902d0d49': ['startseq child is standing on her head endseq',
#   'startseq little girl standing on her head endseq',
#   'startseq small child doing handstand on bed endseq',
#   'startseq young girl does handstand on bed with blue sheets endseq',
#   'startseq the girl is upside down on bed endseq'],
#  '112178718_87270d9b4d': ['startseq guy stands in the sand with snowboard behind him endseq',
#   'startseq man holds surfboard on the beach endseq',
#   'startseq man holds his snowboard in the sand endseq',
#   'startseq man with his surfboard stands in the sand endseq',
#   'startseq man is standing on white sand and holding snowboard endseq'],
#  '112243673_fd68255217': ['startseq people on atvs and dirt bikes are traveling along worn path in field surrounded by trees endseq',
#   'startseq three people are riding around on atv and motorcycles endseq',
#   'startseq three people on motorbikes follow trail through dry grass endseq',
#   'startseq three people on two dirtbikes and one fourwheeler are riding through brown grass endseq',
#   'startseq three people ride offroad bikes through field surrounded by trees endseq'],
#  '1122944218_8eb3607403': ['startseq baby in white garment holds flag with crescent moon and star endseq',
#   'startseq baby is holding small black flag with moon and star on it endseq',
#   'startseq baby wearing white gown waves muslim flag endseq',
#   'startseq little toddler dressed in white is smiling while lady helps him wave flag endseq',
#   'startseq baby in white outfit holding black and white flag endseq'],
#  '1124448967_2221af8dc5': ['startseq half naked man is sleeping on his chair outdoors endseq',
#   'startseq an older man sits back and relaxes on patio outside an adobe building where many bicycles are propped endseq',
#   'startseq shirtless man in white cap relaxes in deck chair close to three parked bicycles endseq',
#   'startseq man relaxing in folding chair on the street endseq',
#   'startseq topless old man wearing slippers navy blue pants and white hat while reclining in chair outside endseq'],
#  '1129704496_4a61441f2c': ['startseq brown and white and black and white dog hauling in floating toy from the ocean endseq',
#   'startseq both dogs retrieve the play toy from the water endseq',
#   'startseq two dogs in the ocean playing with toy endseq',
#   'startseq two dogs run through the water with rope in their mouths endseq',
#   'startseq two dogs tug at chew toy in the surf endseq'],
#  '1130017585_1a219257ac': ['startseq there are three young people one dark haired holding bottled drink one with head tilted back and finger in her mouth and one with spiked hair endseq',
#   'startseq the young people party in the streets endseq',
#   'startseq three girls make faces as one takes drink while they stand in busy street endseq',
#   'startseq three women on the street drinking and posing endseq',
#   'startseq three young women pose for the camera at parade endseq'],
#  '1130369873_d80a1aa59c': ['startseq brown dog is running through neckdeep water carrying tennis ball endseq',
#   'startseq brown dog splashes in the water while carrying ball in its mouth endseq',
#   'startseq brown dog swims through water outdoors with tennis ball in its mouth endseq',
#   'startseq red dog holding ball splashes through vegetation filled water endseq',
#   'startseq brown dog with tennis ball in mouth in water and bushes endseq'],
#  '1130401779_8c30182e3e': ['startseq two brown dogs are creating large splashes as they run in river endseq',
#   'startseq two brown dogs in the water endseq',
#   'startseq two brown dogs running through water endseq',
#   'startseq two brown dogs runs through the water endseq',
#   'startseq two dogs splash through the water endseq'],
#  '1131155939_b4b457b05e': ['startseq black dog runs into the ocean next to pile of seaweed endseq',
#   'startseq black lav runs into the water on the beach with swimmers in the distance and sea kelp in the foreground endseq',
#   'startseq dog at the shore of an ocean with seaweed in foreground endseq',
#   'startseq dog is running in the waves at the beach endseq',
#   'startseq pile of seaweed sits on the sand behind it big black dog is running in the water endseq'],
#  '1131340021_83f46b150a': ['startseq young boy runs while wearing sandals endseq',
#   'startseq little boy in striped shirt and brown shorts is running endseq',
#   'startseq the little boy in short sleeved shirt and shorts is running outside endseq',
#   'startseq the little boy is wearing black pinstripe shirt and walking on deck endseq',
#   'startseq young boy running outside on the pavement endseq'],
#  '1131800850_89c7ffd477': ['startseq brown and white dog stands outside while it snows endseq',
#   'startseq dog is looking at something near the water endseq',
#   'startseq furry dog attempts to dry itself by shaking the water off its coat endseq',
#   'startseq white and brown dog shaking its self dry endseq',
#   'startseq the large brown and white dog shakes off water endseq'],
# ...
#   'startseq man smiles in his blue and green kayak endseq',
#   'startseq man wearing helmet in pyranha kayak floats down some river rapids endseq'],
#  '2087640654_1a84577a44': ['startseq blonde dog is digging deep hole in the ground and its tail is up in the air endseq',
#   'startseq dog half way in hole in the ground endseq',
#   'startseq dog is digging large hole in yard to find something endseq',
#   'startseq dog is digging in the ground and half of his body is under the ground endseq',
#   'startseq the rear end of an animal whose front end is underground endseq'],
#  '2088120475_d6318364f5': ['startseq person dressed up as snowman is walking through crowd of people endseq',
#   'startseq five cold people in the snowstorm one wearing snowman head endseq',
#   'startseq people pose for picture in the snow endseq',
#   'startseq three young people pose by snowman in red tie endseq',
#   'startseq two couples pose with snowman endseq'],
#  '2088460083_42ee8a595a': ['startseq broken down hummer gets towed on truck bed endseq',
#   'startseq damaged vehicle is carried by repair truck in nighttime scene endseq',
#   'startseq flat bed truck in parking lot with an army vehicle on its bed endseq',
#   'startseq an old beatup jeep being towed away endseq',
#   'startseq dirty suv sits on the bed of tow truck at night endseq'],
#  '2088532947_c628e44c4a': ['startseq the girl in the white shirt has bracelet on and has her arm around the girl in the peach shirt endseq',
#   'startseq the two girls laid on the grass together endseq',
#   'startseq two little girls are laying on the grass smiling endseq',
#   'startseq two young girls holding each other on the grassy ground endseq',
#   'startseq two young girls hug each other in the grass endseq'],
#  '2088910854_c6f8d4f5f9': ['startseq large man is wearing headband with mistletoe attached to it endseq',
#   'startseq man in sweatshirt and cap wears flower on his head endseq',
#   'startseq man wearing black knit cap with red and white striped headband with flower on top endseq',
#   'startseq an man with black ski cap and red and white headband looks into the distance endseq',
#   'startseq man wearing black hat with christmas theme endseq'],
#  '2089122314_40d5739aef': ['startseq dog running with newspaper in its mouth endseq',
#   'startseq dog runs down the street carrying newspaper endseq',
#   'startseq dog with newspaper in his mouth runs down paved path endseq',
#   'startseq fluffy tricolored dog is running down the road with paper in its mouth endseq',
#   'startseq an australian shepherd dog carrying newspaper in his mouth endseq'],
#  '2089350172_dc2cf9fcf6': ['startseq three black dogs are swimming through some murky brown water one with yellow object in its mouth endseq',
#   'startseq three black dogs swimming in dirty water endseq',
#   'startseq three dark dogs swimming and one of them has ball endseq',
#   'startseq three dogs are up to their necks in water endseq',
#   'startseq three dogs swim in the water endseq'],
#  '2089426086_7acc98a3a8': ['startseq girl in hooded jacket presents cake with candles endseq',
#   'startseq girl in hood jacket holds birthday cake with many candles endseq',
#   'startseq girl in winter coat with birthday cake endseq',
#   'startseq girl is holding birthday cake endseq',
#   'startseq young girl holding cake with candles dressed in heavy coat endseq'],
#  '2089442007_6fc798548c': ['startseq brown dog is walking in the water endseq',
#   'startseq brown dog takes cautious steps in the calm waters with sandy bottom endseq',
#   'startseq brown dog wades in the water endseq',
#   'startseq dog with red fur stands in body of water endseq',
#   'startseq large golden colored dog is walking through water endseq'],
#  '2089539651_9e518ec7de': ['startseq hiker with two hiking poles stands on hillside with view of the city below him endseq',
#   'startseq hiker with two sticks is standing on path that is high up on hill endseq',
#   'startseq hiking man stands on cliff overlooking city endseq',
#   'startseq man hikes on dirt path high above city endseq',
#   'startseq person holding poles is standing on rock ledge with bushes on each side overlooking mountains endseq'],
#  '2089542487_b4c1ee7025': ['startseq hiker is ready to take on rugged outdoor trail endseq',
#   'startseq lone hiker on dirt hiking trail with hat and sunglasses on with trees in the background endseq',
#   'startseq man in shorts is hiking in dry region endseq',
#   'startseq man stops for picture with the scenery during his hike endseq',
#   'startseq the man is posing for picture in the desert wearing green shirt and hat and holding metal detector endseq'],
#  '2089555297_95cf001fa7': ['startseq man in hat with long sleeves and long pants stands overlooking city endseq',
#   'startseq man stands on cliff overlooking city endseq',
#   'startseq man with backpack and hat is standing by high cliff where you can see for miles endseq',
#   'startseq hiker standing on top of rock overlooking town endseq',
#   'startseq the man wearing backpack and hat stands on ledge overlooking city endseq'],
#  '2090327868_9f99e2740d': ['startseq woman little boy and tiny baby are standing in front of cow statue endseq',
#   'startseq woman and two small children posing in front of large cow statue endseq',
#   'startseq woman gives baby to small child to hold as they stand in front of cow statue endseq',
#   'startseq woman stands with two children near decorated bull statue endseq',
#   'startseq the woman and children are standing next to statue of cow endseq'],
#  '2090339522_d30d2436f9': ['startseq man in green hat is someplace up high endseq',
#   'startseq man in green hat is taking self portrait endseq',
#   'startseq man in hat at scenic overlook endseq',
#   'startseq man wearing green canvas hat with distnat city in the background endseq',
#   'startseq man with green hate and sunglasses on high up peak endseq'],
#  '2090386465_b6ebb7df2c': ['startseq woman and man in winter gear stand endseq',
#   'startseq three adults wearing cold weather gear endseq',
#   'startseq two people are wearing heavy clothing endseq',
#   'startseq two people in winter clothing endseq',
#   'startseq two women bundled up on snowy day endseq'],
#  '2090387793_274ab4cf7d': ['startseq boy wearing black walks down the street with his hands in fists endseq',
#   'startseq teenage boy dressed in black stands on snowy street endseq',
#   'startseq teenage boy wearing all black tries to look tough with cheap jewelry on endseq',
#   'startseq young man wearing black hat and jacket is walking outside endseq',
#   'startseq punk rock teenager walks with mean look on his face endseq'],
#  '2090545563_a4e66ec76b': ['startseq the boy laying face down on skateboard is being pushed along the ground by another boy endseq',
#   'startseq two girls play on skateboard in courtyard endseq',
#   'startseq two people play on long skateboard endseq',
#   'startseq two small children in red shirts playing on skateboard endseq',
#   'startseq two young children on skateboard going across sidewalk endseq'],
#  '2090723611_318031cfa5': ['startseq dogs walking in the grassy field endseq',
#   'startseq large fluffy grey dog standing in grass in front of brown dog endseq',
#   'startseq one dog standing in some grass with his tongue hanging out and tan dog in the background endseq',
#   'startseq two dogs of different breeds are standing in pasture endseq',
#   'startseq two dogs stand in the grass endseq'],
#  '2090997177_76d482b158': ['startseq black dog bounds across the sand endseq',
#   'startseq dog walking across the desert endseq',
#   'startseq short black dog is walking over barren landscape endseq',
#   'startseq small black dog running across the sand endseq',
#   'startseq small black dog walks in the sand endseq'],
#  '2091171488_c8512fec76': ['startseq female wearing pink gloves and brown jacket is smiling in the snow endseq',
#   'startseq woman standing in the snow with people in the background endseq',
#   'startseq young woman in spring coat and purple gloves stands in falling snow endseq',
#   'startseq young woman looks happy in winter clothes while it snows endseq',
#   'startseq young asian woman with pink gloves stands in the snow endseq'],
#  '2092177624_13ab757e8b': ['startseq boy in african clothing runs across concrete wall endseq',
#   'startseq little boy with green shirt is running on rock ledge endseq',
#   'startseq an african boy in large green shirt is running barefoot along wall endseq',
#   'startseq young boy dressed in green running along smooth stone wall near wooded area endseq',
#   'startseq boy in green tunic on rock wall endseq'],
#  '2092419948_eea8001d0f': ['startseq long haired man walking away beside canal whist holding onto railing endseq',
#   'startseq man walks down path next to waterway endseq',
#   'startseq person walks by some bluegreen water while holding rail endseq',
#   'startseq person with long ponytail walks along waterway under tunnel endseq',
#   'startseq the man with long hair is walking along storm drain endseq'],
#  '2092870249_90e3f1855b': ['startseq man lies on street with his head and shoulders under parked car that is jacked up endseq',
#   'startseq man looks under car on wet street endseq',
#   'startseq man works on car endseq',
#   'startseq person lies half under car facedown endseq',
#   'startseq person underneath car with jack endseq'],
#  '2094323311_27d58b1513': ['startseq dog places his head on man face endseq',
#   'startseq dog snuggles with man in sunglasses endseq',
#   'startseq dog with blue collar is licking man who wearing large tinted sunglasses endseq',
#   'startseq large brown dog with blue collar is resting his chin on man face endseq',
#   'startseq an orange dog is licking man wearing red sunglasses endseq'],
#  '2094543127_46d2f1fedf': ['startseq girl holding crocodile mouth closed endseq',
#   'startseq girl is posed over statue of dangerous animal endseq',
#   'startseq girl sits on what appears to be crocodile endseq',
#   'startseq girl sitting on top of crocodile endseq',
#   'startseq girl with red hair is sitting on crocodile holding its jaw endseq'],
#  '2094810449_f8df9dcdf7': ['startseq boy stands in the ocean lifting up his shorts endseq',
#   'startseq child in blue shorts is standing ankle deep in the water endseq',
#   'startseq little boy in blue shorts glasses and coat stands in the surf endseq',
#   'startseq the kid is wearing blue jacket and standing in shallow beach water endseq',
#   'startseq the small child wades ankle deep in the water on the shoreline endseq'],
#  '2095007523_591f255708': ['startseq baby looks through his crib endseq',
#   'startseq baby surrounded by some toys looks out of playpen endseq',
#   'startseq baby in playpen with wide eyes endseq',
#   'startseq baby looking through playpen bars at camera endseq',
#   'startseq the infant is laying on its stomach in crib looking up at the camera endseq'],
#  '2095078658_c14ba89bc2': ['startseq dog runs through snow in front of the woods endseq',
#   'startseq large dog running in snow endseq',
#   'startseq the dog runs through the snow endseq',
#   'startseq the german shepherd dog is running through the snow endseq',
#   'startseq the german shepherd is running through the white snow endseq'],
#  '2095435987_1b7591d214': ['startseq dog lying on its back in the sand endseq',
#   'startseq white and brown dog rolls on its back in the sand endseq',
#   'startseq the dog rolls over to scratch its back in the sand endseq',
#   'startseq the white and brown dog is rolling in the sand endseq',
#   'startseq the white dog is on its back in the sand with paws in the air endseq'],
#  '2095444126_201ff9f222': ['startseq dog is shaking off water endseq',
#   'startseq dog shakes his head endseq',
#   'startseq dog shakes off water endseq',
#   'startseq dog shakes off water and gets contorted endseq',
#   'startseq the dog is shaking water off of his body endseq'],
#  '2095478050_736c4d2d28': ['startseq man and boy play music as little girls watch endseq',
#   'startseq man is playing guitar with child playing harmonica while three young girls watch endseq',
#   'startseq three children watch man onstage playing guitar endseq',
#   'startseq three little girls look on as boy plays the harmonica with an adult guiutarist sitting beside him endseq',
#   'startseq three little girls watch band endseq'],
#  '209605542_ca9cc52e7b': ['startseq climber wearing red headband is pulling himself up some grey rocks high above some green foliage endseq',
#   'startseq man in headband climbing rock endseq',
#   'startseq man with red headband climbing rock cliff looming over greenery endseq',
#   'startseq man climbing sheet rock face endseq',
#   'startseq man in red headband climbing rock endseq'],
#  '2096771662_984441d20d': ['startseq man looks through his binoculars while another man holds drink endseq',
#   'startseq man with thermos is standing next to man who is gazing through binoculars endseq',
#   'startseq two men are standing together while one looks through binoculars endseq',
#   'startseq two men look out as one is holding binoculars endseq',
#   'startseq two people standing next to each other with mountains in the distance endseq'],
#  '2097398349_ff178b3f1b': ['startseq hiker waves to the camera as he standing in front of snowcapped mountains endseq',
#   'startseq man stands on the snow near the mountains endseq',
#   'startseq person poses in the snow endseq',
#   'startseq person stands in the snow at the top of mountian arms raised endseq',
#   'startseq skier in the mountains endseq'],
#  '2097403787_77a154f5b9': ['startseq lone person standing on some rocks with large snowy mountains in the background endseq',
#   'startseq man is standing on the rocky ground in front of the mountain endseq',
#   'startseq man standing in front of an icy mountain endseq',
#   'startseq the person is standing by the water in front of the snow topped mountains endseq',
#   'startseq the traveller pauses in front of the mountain view endseq'],
#  '2097407245_c798e0dcaf': ['startseq man in winter jacket and knit cap stand with his arms up at his side in snow landscape endseq',
#   'startseq man is standing on dirt with his hands in the air with mountains and snow behind him endseq',
#   'startseq man raises his arms on rocky beach endseq',
#   'startseq one lone man with fist in the air with large rocky mountains in the background endseq',
#   'startseq man with outstretched arms standing on snowcovered rocks endseq'],
#  '2097420505_439f63c863': ['startseq male hiker wearing green jacket is posing next to large glacier endseq',
#   'startseq man with camera and an ice structure behind him endseq',
#   'startseq man with camera crouching on ice endseq',
#   'startseq man with camera kneels in front of giant hill of snow endseq',
#   'startseq the mountain climber prepares to take photo endseq'],
#  '2097489021_ca1b9f5c3b': ['startseq girl in ballet fairy costume is touched by wand endseq',
#   'startseq young girl performing the nutcracker endseq',
#   'startseq the little girl is standing on stage dressed up as pink fairy endseq',
#   'startseq the tiny girl dressed in butterfly ballet costume waves her wand near nutcracker statue endseq',
#   'startseq young girl waving turquiose leotard and pink tutu with wings waving wand endseq'],
#  '2098174172_e57d86ea03': ['startseq hiker is posing in front of snowy mountains endseq',
#   'startseq hiker is standing in before the mountain holding two walking sticks endseq',
#   'startseq man stands in front of snow covered mountains endseq',
#   'startseq man with two ski poles stands near mountaintop endseq',
#   'startseq the man wears green hat and jacket while standing in front of mountain endseq'],
#  '2098418613_85a0c9afea': ['startseq brown chow mix dog is standing in front of van with euro plats in the middle of messy yard endseq',
#   'startseq brown dog standing in muddy yard endseq',
#   'startseq brown dogs walks near green van and some junk endseq',
#   'startseq large brown dog stands in front of green van in the yard of house endseq',
#   'startseq yellow dog is standing in front of green car and next to toilet endseq'],
#  ...}

# %% [markdown]
# ## **Training**

# %%
image_ids = list(mapping.keys())
split = int(len(image_ids) * 0.80)
train = image_ids[:split]
test = image_ids[split:]

# %%
# train the model
epochs = 15
batch_size = 32
steps = len(train) // batch_size

for i in range(epochs):
    # create data generator
    generator = data_generator(train, mapping, features, tokenizer, max_length, vocab_size, batch_size)
    # fit for one epoch
    model.fit(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# Out:
# 202/202 [==============================] - 1262s 6s/step - loss: 5.3350
# 202/202 [==============================] - 1241s 6s/step - loss: 4.1134
# 202/202 [==============================] - 1250s 6s/step - loss: 3.6464
# 202/202 [==============================] - 1226s 6s/step - loss: 3.3531
# 202/202 [==============================] - 1233s 6s/step - loss: 3.1408
# 202/202 [==============================] - 1221s 6s/step - loss: 2.9806
# 202/202 [==============================] - 1231s 6s/step - loss: 2.8545
# 202/202 [==============================] - 1245s 6s/step - loss: 2.7602
# 202/202 [==============================] - 1235s 6s/step - loss: 2.6770
# 202/202 [==============================] - 1229s 6s/step - loss: 2.6077
# 202/202 [==============================] - 1225s 6s/step - loss: 2.5434
# 202/202 [==============================] - 1221s 6s/step - loss: 2.4797
# 202/202 [==============================] - 1222s 6s/step - loss: 2.4265
# 202/202 [==============================] - 1237s 6s/step - loss: 2.3779
# 202/202 [==============================] - 1237s 6s/step - loss: 2.3343

# %% [markdown]
# ## **Save model**

# %%
model.save('/content/best_model_15_02_2023_15Epoches.h5')

# %%
! mkdir '/content/gdrive/MyDrive/Đồ án/Machine learning/Image captioning/model'
# Out:
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/Đồ án/Machine learning/Image captioning/model’: File exists

# %%
! cp '/content/best_model_15_02_2023_15Epoches.h5' '/content/gdrive/MyDrive/Đồ án/Machine learning/Image captioning/model'

# %% [markdown]
# ## **Make backup/recovery file**

# %%
! mkdir '/content/gdrive/MyDrive/Đồ án/Machine learning/Image captioning/model/Backup files'
! cp '/content/best_model_15_02_2023_15Epoches.h5' '/content/gdrive/MyDrive/Đồ án/Đồ án Thị giác máy tính nâng cao/Final/model/Backup files'
# Out:
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/Đồ án/Machine learning/Image captioning/model/Backup files’: File exists
